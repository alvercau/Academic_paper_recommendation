# %% [markdown]
# # Inserting the data in MongoDB
#
# What I have so far:
# * a directory with downloaded pdfs
# * a .txt file with all the urls to the pdfs that I am actually using
# * a all2.json file with the additional information of the following format:
#         {'title': title,
#         'authors': authors,
#         'published': published,
#         'keywords': keywords,
#         'url': url}
#
# What I need:
# * put everything in MongoDB, by matching the additional information on the converted pdfs. The problem is that I do not have much to match it on: the original pdfs' name is a part of the url and got cut of at a different point as the url in the db.

# %%
import json
import os
from pymongo import MongoClient
import codecs
import pandas as pd

# %% [markdown]
# The metadata contains data for all papers that are available on Lingbuzz. I only selected a subset of them.
# To do: match pdfs to url in db, insert new field 'paper' with the converted file (which is one huge string).
#
# ## Create db and insert meta data

# %%
with open('../all2.json') as f:
    meta_data = json.load(f)

# %%
meta_data
# Out:
# [{'authors': ['Yusuke Imanishi'],
#   'keywords': ['resumption, possessor wh phrases, the clause-mate condition on resumptive chains, island (in)sensitivity, kaqchikel (mayan), syntax'],
#   'published': ['To appear in Studia Linguistica'],
#   'title': 'The clause-mate condition on resumption: Evidence from Kaqchikel',
#   'url': '/lingbuzz/003606'},
#  {'authors': ['Prakash Mondal'],
#   'keywords': ['natural language; cognition; possible minds; mentality; organisms; machines; computation, semantics, syntax'],
#   'published': ['Leiden/Boston: Brill (2017)'],
#   'title': "The Preliminary Material of 'Natural Language and Possible Minds: How Language Uncovers the Cognitive Landscape of Nature'",
#   'url': '/lingbuzz/003607'},
#  {'authors': ['Lida Veselovska'],
#   'keywords': ['czech passives, passive vs. past participles, czech clitics, past czech auxiliary, grammatical morphemes, instrumental case, post-syntactic insertion, post-syntactic derivation, semantics, morphology, syntax, morphology, syntax'],
#   'published': ['Zeitschrift für Slawistik 49 (2) 2004: 163–235'],
#   'title': 'Analytic Passives in Czech',
#   'url': '/lingbuzz/003608'},
#  {'authors': ['Halldor Armann Sigurdsson'],
#   'keywords': ['expletive insertion, extended projection principle, google search, impersonal clauses, stylistic fronting, relative clauses, timarit.is, verb-initial adverbial clauses, word order frequencies, syntax, phonology'],
#   'published': ['In Syntactic Variation in Insular Scandinavian, ed. by Höskuldur Thráinsson, Caroline Heycock, Hjalmar P. Petersen & Zakaris Svabo Hansen, 307–338 [Studies in Germanic Linguistics 1]. Amsterdam: John Benjamins.'],
#   'title': 'Stylistic Fronting in corpora',
#   'url': '/lingbuzz/002635'},
#  {'authors': ['Halldor Armann Sigurdsson'],
#   'keywords': ['null arguments, narrative inversion, topicality, icelandic, semantics, syntax'],
#   'published': ['To appear in Verner Egerland, Valéria Molnár & Susanne Winkler: Architecture of Topic. Berlin: De Gruyter Mouton.'],
#   'title': 'Topicality in Icelandic: Null arguments and Narrative Inversion',
#   'url': '/lingbuzz/003611'},
#  {'authors': ['Lida Veselovska'],
#   'keywords': ['czech dp; universal dp, determiners; functional domain; word order in dps, semantics of dp, modifiers of n, semantics, morphology, syntax'],
#   'published': ['Nominal Structures: All in Complex DPs, edited by Ludmila Veselovská and Markéta Janebová, 12–28. Olomouc: Palacký University Press'],
#   'title': 'The Universal DP Analysis in Articleless Languages: A Case Study in Czech',
#   'url': '/lingbuzz/003609'},
#  {'authors': ['Aaron Doliana', 'Sandhya Sundaresan'],
#   'keywords': ['proxy control, (non) obligatory control, agree, centered worlds, modality, syntax-semantics interface, semantics, morphology, syntax'],
#   'published': ['submitted'],
#   'title': 'Proxy control: extending the typology of control in grammar',
#   'url': '/lingbuzz/003612'},
#  {'authors': ['Lida Veselovska'],
#   'keywords': ['english possessive; czech possessive; postnominal genitive; of-genitive, double genitive; thematic hierarchy; nominal arguments, morphology, syntax'],
#   'published': ['Nominal Structures: All in Complex DPs, edited by Ludmila Veselovská and Markéta Janebová, 110–33. Olomouc: Palacký University Press'],
#   'title': 'POSSESSIVES AND THEIR EQUIVALENTS IN ENGLISH AND CZECH: A COMPARATIVE STUDY',
#   'url': '/lingbuzz/003610'},
#  {'authors': ['Philippe Schlenker'],
#   'keywords': ['sign language, strong pronouns, pointing, focus, semantics, morphology, syntax'],
#   'published': [],
#   'title': 'Strong Pronominals ASL and LSF (squib)',
#   'url': '/lingbuzz/003613'},
#  {'authors': ['Itamar Kastner', 'Vera Zu'],
#   'keywords': ['competition, morphology, syntax, hebrew, latin, paradigm gaps, voice, passive'],
#   'published': [],
#   'title': 'Blocking and Paradigm Gaps',
#   'url': '/lingbuzz/002394'},
#  {'authors': ['Kyle Gorman', 'Charles Yang'],
#   'keywords': ['gaps, inflectional gaps, defectivity, productivity, morphology, phonology'],
#   'published': ['Competition in inflection and word formation.'],
#   'title': 'When nobody wins',
#   'url': '/lingbuzz/003614'},
#  {'authors': ['Guilherme Duarte Garcia'],
#   'keywords': ['phonology, stress, weight, probabilistic grammar, portuguese, english, phonology'],
#   'published': ['McGill University'],
#   'title': 'Weight effects on stress: lexicon and grammar (PhD Thesis)',
#   'url': '/lingbuzz/003615'},
#  {'authors': ['Dominique Sportiche'],
#   'keywords': ['double object, intensionality, double object alternations, frozen scope, syntax'],
#   'published': [],
#   'title': '(Im)possible Intensionality (or why Deep Double Objects underlie all Alternations)',
#   'url': '/lingbuzz/003479'},
#  {'authors': ['Norbert Francis'],
#   'keywords': ['tonality, bilingualism, cross-language interaction, convergence, faculty of music, phonology'],
#   'published': ['The Linguistic Review'],
#   'title': 'Music contact and language contact',
#   'url': '/lingbuzz/003616'},
#  {'authors': ['Georg Höhn'],
#   'keywords': ['person, nominal structure, adnominal pronouns, pronominal determiner, unagreement, demonstratives, morphology, syntax'],
#   'published': ['University of Cambridge'],
#   'title': 'Non-possessive person in the nominal domain',
#   'url': '/lingbuzz/003618'},
#  {'authors': ['Dave Kush', 'Terje Lohndal', 'Jon Sprouse'],
#   'keywords': ['island constraints, norwegian, experimental syntax, scandinavian, syntax'],
#   'published': ['Natural Language and Linguistic Theory'],
#   'title': 'Investigating Variation in Island Effects: A Case Study of Norwegian Wh-Extraction',
#   'url': '/lingbuzz/003617'},
#  {'authors': ['Asia Pietraszko'],
#   'keywords': ['syntax, morphology, extended projections, selection, agreement, multi-verbal constructions, auxiliaries, light verbs, ndebele, bantu'],
#   'published': ['PhD thesis, University of Chicago'],
#   'title': 'Inflectional Dependencies. A study of complex verbal expressions in Ndebele',
#   'url': '/lingbuzz/003619'},
#  {'authors': ['William Merrill'],
#   'keywords': ['lambda calculus, tense, aspect, computational linguistics, compositional semantics, semantics, morphology, ccg'],
#   'published': [],
#   'title': 'A Haskell implementation of English tense and aspect semantics',
#   'url': '/lingbuzz/003620'},
#  {'authors': ['Jonathan Bobaljik', 'Uli Sauerland'],
#   'keywords': ['features, morphology, combinatorics, syncretism, typology, morphology'],
#   'published': [],
#   'title': '*ABA and The Combinatorics of Morphological Features',
#   'url': '/lingbuzz/003320'},
#  {'authors': ['Holden Härtl', 'Heiko Seeliger'],
#   'keywords': ['not-at-issue content, irony, quotation, pragmatics, semantics'],
#   'published': ['Submitted.'],
#   'title': 'Is a so-called "beach" a beach? An empirically based analysis of secondary content induced by ironic name use',
#   'url': '/lingbuzz/003622'},
#  {'authors': ['Philippe Schlenker'],
#   'keywords': ['sign language semantics, anaphora, loci, locative shift, agreement, ellipsis, semantics, morphology, syntax'],
#   'published': [],
#   'title': 'Locative Shift',
#   'url': '/lingbuzz/003482'},
#  {'authors': ['Maren Berg Grimstad',
#    'Brita Ramsevik Riksem',
#    'Terje Lohndal',
#    'Tor Anders Aafarli'],
#   'keywords': ['agreement, american norwegian, exoskeletal, language mixing, lexicalism, morphology, syntax'],
#   'published': ['The Linguistic Review'],
#   'title': 'Lexicalist vs. exoskeletal approaches to language mixing',
#   'url': '/lingbuzz/003621'},
#  {'authors': ['Juliet Stanton'],
#   'keywords': ['environmental shielding, contrast, nasality, phonotactics, phonology'],
#   'published': ['to appear in Phonology'],
#   'title': 'Environmental shielding is contrast preservation',
#   'url': '/lingbuzz/003623'},
#  {'authors': ['Richard Breheny',
#    'Nathan Klinedinst',
#    'Jacopo Romoli',
#    'Yasutada Sudo'],
#   'keywords': ['alternatives, scalar implicatures, symmetry problem, semanticsarchive, semantics'],
#   'published': [],
#   'title': 'The symmetry problem: current theories and prospects',
#   'url': '/lingbuzz/repo/semanticsArchive/article/001636'},
#  {'authors': ['Philipp Weisser'],
#   'keywords': ['case marking, conjunction, coordination, agreement, case clitics, suspended affixation, allomorphy, morphology, syntax'],
#   'published': ['submitted'],
#   'title': 'On the Symmetry of Case in Conjunction',
#   'url': '/lingbuzz/003603'},
#  {'authors': ['Mandy Simons'],
#   'keywords': ['grice, convention, communicative intention, conversational scoreboard, semanticsarchive, semantics'],
#   'published': [],
#   'title': 'Convention, Intention and the Conversational Record: A reply to Lepore and Stone 2015',
#   'url': '/lingbuzz/repo/semanticsArchive/article/001637'},
#  {'authors': ['Nicholas Longenbaugh'],
#   'keywords': ["tough movement, a/a'-distinction, composite movement, dinka, reconstruction, syntax"],
#   'published': [],
#   'title': "Composite A/A'-movement: Evidence from English tough-movement",
#   'url': '/lingbuzz/003604'},
#  {'authors': ['James N. Collins'],
#   'keywords': ['tagalog, austronesian, philippine, syntax-semantics interface, type-shifting, definiteness, bare nps, quantification, semantics, syntax'],
#   'published': ['Submitted'],
#   'title': 'Definiteness determined by syntax: A case study in Tagalog',
#   'url': '/lingbuzz/003570'},
#  {'authors': ['Hadas Kotek', 'Matthew Barros'],
#   'keywords': ['sluicing, ellipsis licensing, pair-list readings, scope, parallelism, semantics, syntax'],
#   'published': ['Linguistic Inquiry'],
#   'title': 'Multiple Sluicing, Scope, and Superiority: Consequences for Ellipsis Identity',
#   'url': '/lingbuzz/003549'},
#  {'authors': ['Joseph Emonds'],
#   'keywords': ['initial adjuncts, -ly adverbs, complement stress, pre-modifiers, economy of representation, suffixal head, null inflection, morphology, syntax'],
#   'published': ['Structure preserved: syntactic squibs for Jan Koster. Mark de Vries and Jan-Wouter Zwart (eds.). John Benjamins, Amsterdam'],
#   'title': 'Little words don’t lie: X’ have initial X0',
#   'url': '/lingbuzz/003605'},
#  {'authors': ["Roberta D'Alessandro"],
#   'keywords': ['agreement, romance, topic, adverbs, gerunds, prepositions, morphology, syntax'],
#   'published': ['submitted'],
#   'title': 'Agreement stacking and topic oriented agreement: how to agree with adverbs, gerunds and prepositions ',
#   'url': '/lingbuzz/003563'},
#  {'authors': ['Klaus Abels'],
#   'keywords': ['ellipsis, sluicing, in-situ theory of ellipsis, contrastive left dislocation, german, english, move-and-delete theory of ellipsis, syntax'],
#   'published': ['under review'],
#   'title': 'On “Sluicing” with apparent massive pied-piping',
#   'url': '/lingbuzz/003585'},
#  {'authors': ['Klaus Abels', 'Veneeta Dayal'],
#   'keywords': ['syntax, locality, sluicing, ellipsis, multiple sluicing, syntax-semantics interface, wh-scope, covert movement, wh-in-situ, multiple wh-questions, semantics, syntax'],
#   'published': ['under review'],
#   'title': 'On the syntax of multiple sluicing and what it tells us about wh scope taking',
#   'url': '/lingbuzz/003584'},
#  {'authors': ['Ana Ojea'],
#   'keywords': ['core intentional features; discourse analysis; categorical/thetic statements; subject position;, syntax'],
#   'published': ['Lingua '],
#   'title': 'Core intentional features in the syntactic computation: deriving the position of the subject in Spanish',
#   'url': '/lingbuzz/003590'},
#  {'authors': ['Andrew Ira Nevins'],
#   'keywords': ['conjunct agreement, slavic, default vs resolution, bantu, concord/index, crossmodular structural parallelism, animacy/humanness, morphology, syntax'],
#   'published': ["In Petrosino (ed.) 'Beyond the Veil of Maya'"],
#   'title': 'Copying and Resolution in South Slavic and South Bantu Conjunct Agreement',
#   'url': '/lingbuzz/003589'},
#  {'authors': ['Chris Collins'],
#   'keywords': ['quantifier domain restriction, ellipsis, inverse scope, semantics, syntax'],
#   'published': [],
#   'title': 'Quantifier Domain Restriction as Ellipsis',
#   'url': '/lingbuzz/002616'},
#  {'authors': ['Chris Collins', 'Paul Postal'],
#   'keywords': ['interclausal neg raising, excluded middle assumption, strict npis, horn clauses, semantics, syntax'],
#   'published': ['none'],
#   'title': 'Disentangling Two Distinct Notions of NEG Raising',
#   'url': '/lingbuzz/003595'},
#  {'authors': ['Yimei Xiang'],
#   'keywords': ['semantics, mandarin, dou, even, logical particles, exhaustification, free choice, minimizer, alternative semantics, semantics'],
#   'published': ['Submitted'],
#   'title': 'Alternations of logical functions: Mandarin particle dou as a pre-exhaustification exhaustifier',
#   'url': '/lingbuzz/003598'},
#  {'authors': ['Oriana Kilbourn-Ceron'],
#   'keywords': ['speech production planning, corpus phonology, phonological variation, french liaison, high vowel devoicing, japanese, flapping, external sandhi, phonology'],
#   'published': ['PhD Thesis, McGill University'],
#   'title': 'Speech production planning affects variation in external sandhi [PhD Thesis]',
#   'url': '/lingbuzz/003601'},
#  {'authors': ['Brian Buccola', 'Andreas Haida'],
#   'keywords': ['ignorance inferences, scalar implicatures, exhaustivity, gricean maxims, modified numerals, universal density of measurement, semantics'],
#   'published': ['Submitted'],
#   'title': 'Obligatory irrelevance and the computation of ignorance inferences',
#   'url': '/lingbuzz/003600'},
#  {'authors': ['Yuta Sakamoto'],
#   'keywords': ['syntax, ellipsis, movement, phase, syntax'],
#   'published': ['Ph.D. dissertation at the University of Connecticut'],
#   'title': 'Escape from Silent Syntax',
#   'url': '/lingbuzz/003573'},
#  {'authors': ['Michael Yoshitaka Erlewine'],
#   'keywords': ['disjunction, alternative questions, wh-quantification, alternative semantics, mandarin chinese, semantics'],
#   'published': ['submitted'],
#   'title': 'Two disjunctions in Mandarin Chinese',
#   'url': '/lingbuzz/003575'},
#  {'authors': ['Tal Linzen', 'Gillian Gallagher'],
#   'keywords': ['phonotactics, artificial language, generalization, phonology'],
#   'published': ['Accepted to Laboratory Phonology'],
#   'title': 'Rapid generalization in phonotactic learning',
#   'url': '/lingbuzz/002656'},
#  {'authors': ['Linmin Zhang', 'Jia Ling'],
#   'keywords': ['mandarin chinese, qud, jiu, partial answer, answerhood, semanticsarchive, semantics'],
#   'published': [],
#   'title': 'Mandarin Chinese particle jiu: A current question restrictor',
#   'url': '/lingbuzz/repo/semanticsArchive/article/001626'},
#  {'authors': ['Friederike Moltmann'],
#   'keywords': ['number words, singular terms, proper names, semanticsarchive, semantics'],
#   'published': [],
#   'title': 'Number Words as Number Names (LP)',
#   'url': '/lingbuzz/repo/semanticsArchive/article/001625'},
#  {'authors': ['Gasper Begus'],
#   'keywords': ['phonological typology, probabilistic models, analytic bias, channel bias, maxent, sound change, naturalness, phonology'],
#   'published': ['To appear in Proceedings of the 35th West Coast Conference on Formal Linguistics'],
#   'title': 'A Formal Model of Phonological Typology',
#   'url': '/lingbuzz/003574'},
#  {'authors': ['Ryoichiro Kobayashi'],
#   'keywords': ['labeling algorithm, transfer, multiple nominatives, scrambling, japanese, syntax'],
#   'published': ['to appear in Proceedings of WAFL 13'],
#   'title': 'Parametrizing the Timing of Transfer in Japanese and English and its Consequences',
#   'url': '/lingbuzz/003581'},
#  {'authors': ['Ryoichiro Kobayashi'],
#   'keywords': ['labeling, categorial features, feature-sharing, anti-labeling features, syntax'],
#   'published': ['to appear in the Proceedings of SICOGG 19'],
#   'title': 'On Some Symmetric Constituents in Japanese',
#   'url': '/lingbuzz/003582'},
#  {'authors': ['Evelina Leivada', 'Elena Papadopoulou', 'Natalia Pavlou'],
#   'keywords': ['variation, universal grammar, falsifiability, syntax'],
#   'published': ['Frontiers in Language Sciences'],
#   'title': 'Functionally Equivalent Variants in a Non-standard Variety and Their Implications for Universal Grammar: A Spontaneous Speech Corpus',
#   'url': '/lingbuzz/003583'},
#  {'authors': ['Nicholas Longenbaugh'],
#   'keywords': ['relative-clause, agreement, matching, partitives'],
#   'published': [],
#   'title': 'Agreement mismatch in partitive relatives',
#   'url': '/lingbuzz/003587'},
#  {'authors': ['Luisa Marti'],
#   'keywords': ['inclusive and exclusive plurals, general number, dual, paucal, semantics, morphology'],
#   'published': ['submitted'],
#   'title': 'Inclusive plurals and the theory of number',
#   'url': '/lingbuzz/003528'},
#  {'authors': ['Abdelkader Fassi Fehri'],
#   'keywords': ['constructional gender, unit classifier, group classifier, quantity, perspective, evaluation, performativity, semantics, morphology, syntax'],
#   'published': ['to appear'],
#   'title': 'Multiple facets of constructional Arabic Gender and ‘functional universalism’ in the DP*',
#   'url': '/lingbuzz/003529'},
#  {'authors': ['Alex Djalali', 'Stefan Kaufmann'],
#   'keywords': ['in proceedings of lola10 (2009), semanticsarchive, semantics'],
#   'published': [],
#   'title': 'Probabilistic inference in dynamic semantics',
#   'url': '/lingbuzz/repo/semanticsArchive/article/001630'},
#  {'authors': ['Maria Polinsky'],
#   'keywords': ['agreement, binding, generic pronouns, morphology, syntax'],
#   'published': [],
#   'title': 'When person agreement and binding go their separate ways',
#   'url': '/lingbuzz/003532'},
#  {'authors': ['Quentin Dabouis'],
#   'keywords': ['english, stress, accent, faithfulness, preservation, clash, frequency, cyclicity, lexical access, phonology'],
#   'published': ['English Language and Linguistics'],
#   'title': 'When Accent Preservation Leads to Clash',
#   'url': '/lingbuzz/003530'},
#  {'authors': ['Sherry Yong Chen'],
#   'keywords': ['tenseless, lifetime effects, tense, psycholinguistics, mandarin chinese, english, structural universals, semantics, syntax, semanticsarchive'],
#   'published': [],
#   'title': 'Processing Tenses for the Living and the Dead: A Psycholinguistic Investigation of Lifetime Effects in Tensed and \x93Tenseless\x94 Languages',
#   'url': '/lingbuzz/repo/semanticsArchive/article/001631'},
#  {'authors': ['Sherry Yong Chen'],
#   'keywords': ['gqt, most, men, mandarin chinese, collectivity, plurality, universal quantification, semanticsarchive, semantics'],
#   'published': [],
#   'title': 'Covert (Universal) Quantification: A Generalised Quantifier Theory Analysis of -men',
#   'url': '/lingbuzz/repo/semanticsArchive/article/001632'},
#  {'authors': ['Julie Jiang'],
#   'keywords': ['mandarin, -men, plurality, numerals, classifiers, kind terms, (in)definiteness, semantics, syntax'],
#   'published': ['accepted. International Journal of Chinese Linguistics'],
#   'title': 'Mandarin associative plural -men and NPs with -men ',
#   'url': '/lingbuzz/003074'},
#  {'authors': ['Philippe Schlenker'],
#   'keywords': ['sign language, gestures, iconicity, presuppositions, supplements, cosuppositions, co-speech gestures, post-speech gestures, post-speech gestures, semantics'],
#   'published': ['Accepted with minor revisions in Natural Language & Linguistic Theory'],
#   'title': 'Iconic Pragmatics',
#   'url': '/lingbuzz/003215'},
#  {'authors': ['Nikos Angelopoulos', 'Dominique Sportiche'],
#   'keywords': ['clitics, clitic left dislocation, scrambling, reconstruction, french, syntax'],
#   'published': ["to appear in Romance Languages and Linguistic Theory 2016. Selected papers from 'Going Romance' Frankfurt 2016  (Martin Elsig, Ingo Feldhausen, Imme Kuchenbrandt, and Mareike Neuhaus, eds.) John Benjamins"],
#   'title': 'Scrambling(s) + Clitics = CLLD (The case of French)',
#   'url': '/lingbuzz/003486'},
#  {'authors': ['Alexandra Simonenko', 'Benoît Crabbé', 'Sophie Prévost'],
#   'keywords': ['language change, null subjects, pro-drop, rich agreement, morphological syncretism, historical french, constant rate hypothesis, variational learning, morphology, syntax, phonology'],
#   'published': ['manuscript under review'],
#   'title': 'Agreement syncretisation and the loss of null subjects: quantificational models for Medieval French',
#   'url': '/lingbuzz/003491'},
#  {'authors': ['Chris Collins'],
#   'keywords': ['passive, implicit arguments, depictive secondary predicates, ultra-indefinites, voice, syntax'],
#   'published': ['not published'],
#   'title': 'On the Implicit Argument in the Short Passive',
#   'url': '/lingbuzz/003492'},
#  {'authors': ['Lucas Champollion', 'Dylan Bumford', 'Robert Henderson'],
#   'keywords': ['donkey sentences, trivalence, weak/strong (existential/universal) ambiguity, extension gaps, pragmatics, semantics'],
#   'published': ['Submitted'],
#   'title': 'Homogeneity in donkey anaphora',
#   'url': '/lingbuzz/003333'},
#  {'authors': ['Nina Topintzi', 'Andrew Ira Nevins'],
#   'keywords': ['moraic onsets, arrernte, syllable, typology, allomorphy, stress, reduplication, phonology'],
#   'published': ['To appear in Phonology'],
#   'title': 'Moraic Onsets in Arrernte',
#   'url': '/lingbuzz/003490'},
#  {'authors': ['Cleo Condoravdi', 'Sven Lauer'],
#   'keywords': ['imperatives, conditionals, bouletic, teleological, advice, endorsement, semanticsarchive, semantics'],
#   'published': [],
#   'title': 'Conditional imperatives and endorsement',
#   'url': '/lingbuzz/repo/semanticsArchive/article/001627'},
#  {'authors': ['Peter Staroverov'],
#   'keywords': ['buriat, buryat, mongolic, epenthesis, insertion, markedness, naturalness, learning bias, morphology, phonology'],
#   'published': ['Ms. Submitted'],
#   'title': 'Buriat dorsal epenthesis is not reproduced with novel morphemes',
#   'url': '/lingbuzz/002609'},
#  {'authors': ['Nicholas Longenbaugh', 'Itai Bassi'],
#   'keywords': ['focus, focus movement, tanglewood, covert pied-piping, binding, vp ellipsis, islands, e-type, semantics, syntax'],
#   'published': [],
#   'title': "Against 'Tanglewood' by focus movement: a reply to Erlewine and Kotek (to appear)",
#   'url': '/lingbuzz/003494'},
#  {'authors': ['Emma Nguyen', 'Lisa Pearl'],
#   'keywords': ['passives, acquisition, english, lexical semantics, corpus analysis, meta-analysis, semantics, syntax'],
#   'published': ['WCCFL 2017 proceedings'],
#   'title': 'Do You Really Mean It? Linking Lexical Semantic Profiles and the Age of Acquisition for the English Passive',
#   'url': '/lingbuzz/003496'},
#  {'authors': ['Marwan Jarrah'],
#   'keywords': ['arabic: phase theory: subject extraction: temporal/locative inversion, syntax'],
#   'published': ['submitted '],
#   'title': 'Temporal/locative inversion in Arabic',
#   'url': '/lingbuzz/003375'},
#  {'authors': ['Magdalena Kaufmann'],
#   'keywords': ['modality, japanese, non-logical conditionals, semanticsarchive, semantics'],
#   'published': [],
#   'title': "What `may' and `must' may be in Japanese",
#   'url': '/lingbuzz/repo/semanticsArchive/article/001628'},
#  {'authors': ['Itamar Kastner'],
#   'keywords': ['allomorphy, hebrew, roots, templatic morphology, morphology, syntax, phonology'],
#   'published': ['Submitted, comments welcome'],
#   'title': 'Templatic morphology as an emergent property: Roots and functional heads in Hebrew',
#   'url': '/lingbuzz/003103'},
#  {'authors': ['Robert Berwick'],
#   'keywords': ['syntactic structures, poverty of the stimulus, competence, performance, grammaticality, syntax'],
#   'published': ['MIT'],
#   'title': 'Revolutionary New Ideas Appear Infrequently',
#   'url': '/lingbuzz/003471'},
#  {'authors': ['Ivano Ciardelli', 'Linmin Zhang', 'Lucas Champollion'],
#   'keywords': ['counterfactuals, disjunctive antecedents, minimal change semantics, inquisitive semantics, web survey, causal reasoning, semantics'],
#   'published': ['Submitted'],
#   'title': 'Two switches in the theory of counterfactuals: A study of truth conditionality and minimal change',
#   'url': '/lingbuzz/003200'},
#  {'authors': ['Omer Preminger'],
#   'keywords': ['filtration, non-generation, case, agreement, interfaces, (falsehood of the) strong minimalist thesis, syntax'],
#   'published': [],
#   'title': 'Back to the Future: Non-generation, filtration, and the heartbreak of interface-driven minimalism',
#   'url': '/lingbuzz/003447'},
#  {'authors': ['Anna Szabolcsi'],
#   'keywords': ['strict negative concord, non-strict negative concord, hybrid negative concord, hungarian, italian, russian, implicature, exhaustification, scope, disjunction, negation, too (even), disembodied operator, semantics, syntax'],
#   'published': ['to appear in: Zoltán Bánréti, Huba Bartos, Marcel den Dikken & Tamás Váradi (eds.), Boundaries crossed, at the crossroads of morphosyntax, phonology, pragmatics and semantics, Dordrecht: Springer (2017).'],
#   'title': 'Strict and non-strict negative concord in Hungarian: A unified analysis',
#   'url': '/lingbuzz/003498'},
#  {'authors': ['Ivona Kucerova', 'Adam Szczegielniak'],
#   'keywords': ['roots, syntactic features, typology of features, morphology, syntax'],
#   'published': ['Proceedings of WCCFL 35 (2017)'],
#   'title': 'A dual theory of roots: Evidence from gender-marking languages',
#   'url': '/lingbuzz/003506'},
#  {'authors': ['Michael Yoshitaka Erlewine', 'Theodore Levin'],
#   'keywords': ['argument ellipsis, kaqchikel, mayan, agent focus, syntax'],
#   'published': ['Proceedings of Form and Analysis in Mayan Linguistics (FAMLi) 4'],
#   'title': 'On the unavailability of argument ellipsis in Kaqchikel',
#   'url': '/lingbuzz/003503'},
#  {'authors': ['Marcello Modesto', 'Marcus Maia'],
#   'keywords': ['generative syntax; sentence processing; nonfinite control; inflected infinitives; brazilian portuguese; eye-tracking, syntax'],
#   'published': ['RELIN Revista de Estudos da Linguagem, UFMG'],
#   'title': 'Representation and Processing of the Inflected Infinitive in Brazilian Portuguese: an eye-tracking study',
#   'url': '/lingbuzz/003389'},
#  {'authors': ['Ollie Sayeed'],
#   'keywords': ['phonology, string, substance-free, diachrony, formal, mathematical, model, phonology'],
#   'published': ['University of Cambridge'],
#   'title': 'String Phonology',
#   'url': '/lingbuzz/003508'},
#  {'authors': ['Noam Chomsky', 'Ángel J. Gallego', 'Dennis Ott'],
#   'keywords': ['generative grammar, faculty of language, basic properties, operations, interfaces, syntax'],
#   'published': ['Catalan Journal of Linguistics'],
#   'title': 'Generative Grammar and the Faculty of Language: Insights, Questions, and Challenges',
#   'url': '/lingbuzz/003507'},
#  {'authors': ['Jeffrey Lidz', 'Aaron Steven White', 'Rebecca Baier'],
#   'keywords': ['language acquisition, parsing, prediction, thematic role, subcategorization frame, semantics, syntax'],
#   'published': ['Cognitive Psychology'],
#   'title': 'The role of incremental parsing in syntactically conditioned word learning',
#   'url': '/lingbuzz/003145'},
#  {'authors': ['Jacopo Garzonio', 'Silvia Rossi'],
#   'keywords': ['locative adpositions, pp, italian dialects, dpplace, syntax'],
#   'published': [],
#   'title': 'AxParts and Case in Complex PPs: Microvariation in Italian dialects',
#   'url': '/lingbuzz/003515'},
#  {'authors': ['Philippe Schlenker'],
#   'keywords': ['gestures, co-speech gestures, pro-speech gestures, sign language, loci, iconicity, locative shift, plurality, unpunctuated repetitions, punctuated repetitions, telicity, semantics, syntax'],
#   'published': [],
#   'title': 'Gestural Grammar',
#   'url': '/lingbuzz/003497'},
#  {'authors': ['Shigeto Kawahara'],
#   'keywords': ["rendaku, lyman's law, japanese, orthotactics, devoicing, opacity, underspecification, phonology"],
#   'published': ['Under review'],
#   'title': 'The orthographic characterization of rendaku and Lyman’s Law',
#   'url': '/lingbuzz/002935'},
#  {'authors': ['Christer Platzack', 'Inger Rosengren'],
#   'keywords': ['modularity, clause types, morphology, syntax, semantics. speech acts, semantics, morphology, syntax'],
#   'published': ['Lund University'],
#   'title': 'What makes the imperative clause type autonomous. A comparative study in a modular perspective',
#   'url': '/lingbuzz/003516'},
#  {'authors': ['Andrés Saab'],
#   'keywords': ['nominal ellipsis, empty nouns, null arguments, identity, licensing, syntax'],
#   'published': ['To appear in Temmerman, Tanja and Jeroen van Craenenbroeck (eds.)  The Oxford Handbook of Ellipsis, OUP'],
#   'title': 'Nominal ellipses',
#   'url': '/lingbuzz/002216'},
#  {'authors': ['Anna Szabolcsi'],
#   'keywords': ['strict negative concord, non-strict negative concord, hungarian, italian, russian, implicature, scope, disjunction, negation, too (even), disembodied operator, semanticsarchive, semantics'],
#   'published': [],
#   'title': 'Strict and non-strict negative concord in Hungarian: A unified analysis',
#   'url': '/lingbuzz/repo/semanticsArchive/article/001615'},
#  {'authors': ['Henry Fominyam', 'Radek Simik'],
#   'keywords': ['awing, grassfields bantu, exhaustive focus, focus encoding, verbal morphosyntax, interface of syntax and information structure, semantics, morphology, syntax'],
#   'published': ['Natural Language & Linguistic Theory (https://doi.org/10.1007/s11049-017-9363-2)'],
#   'title': 'The morphosyntax of exhaustive focus: A view from Awing (Grassfields Bantu)',
#   'url': '/lingbuzz/003291'},
#  {'authors': ['Alexandru Nicolae'],
#   'keywords': ['v-to-c movement; clausal negation; full word vs. affix; romanian, morphology, syntax'],
#   'published': ['Festschrift in honour of Professor Emil Ionescu (in preparation)'],
#   'title': 'Syntactic effects of the morphological status of the negative marker: negative imperatives vs. negative gerunds',
#   'url': '/lingbuzz/003387'},
#  {'authors': ['Jacopo Romoli', 'Matthew Mandelkern'],
#   'keywords': ['local contexts, hierarchical order, linear order, presuppositions, redundancy, semanticsarchive, semantics'],
#   'published': [],
#   'title': 'Hierarchical structure and local contexts',
#   'url': '/lingbuzz/repo/semanticsArchive/article/001616'},
#  {'authors': ['Paolo Acquaviva'],
#   'keywords': ['morphology semantics number plural kinds nouns nominality countability count mass, semantics, morphology, syntax'],
#   'published': [],
#   'title': 'Categorization as noun construction. Gender, number, and entity types.',
#   'url': '/lingbuzz/003317'},
#  {'authors': ['Guido Vanden Wyngaerd'],
#   'keywords': ['latex, tree diagrams, forest, morphology, syntax'],
#   'published': ['CTAN'],
#   'title': 'Forest quickstart guide',
#   'url': '/lingbuzz/003391'},
#  {'authors': ['Jonathan MacDonald', 'Matthew Maddox'],
#   'keywords': ['body parts, passive se, by phrases, romanian, old spanish, modern spanish, linguistic cycles, syntax'],
#   'published': ['Journal of Linguistics'],
#   'title': 'Passive se in Romanian and Spanish: a subject cycle',
#   'url': '/lingbuzz/003366'},
#  {'authors': ['Gerrit Kentner'],
#   'keywords': ['prosodic morphology, reduplication, german, lexicon, optimality theory, phonology, morphology, morphology, phonology'],
#   'published': ['to appear in Zeitschrift für Sprachwissenschaft 36(2), 2017'],
#   'title': 'On the emergence of reduplication in German morphophonology',
#   'url': '/lingbuzz/001810'},
#  {'authors': ['Yimei Xiang'],
#   'keywords': ['focus, focus movement, only, negative polarity item, alternative semantics, grammatical view, implicatures, exhaustification, semantics, syntax'],
#   'published': ['Journal of Semantics'],
#   'title': 'ONLY: An NPI-licenser and NPI-unlicenser',
#   'url': '/lingbuzz/003393'},
#  {'authors': ['Michael Barrie'],
#   'keywords': ['noun incorporation, subject/object asymmetry, agreement, iroquoian, syntax'],
#   'published': ['submitted'],
#   'title': 'Subject/Object Asymmetries in Northern Iroquoian Noun Incorporation',
#   'url': '/lingbuzz/003394'},
#  {'authors': ['Wm. G. Bennett'],
#   'keywords': ['phonology, nasality, universal, clicks, airstream, phonetics, typology'],
#   'published': ['Submitted. Comments welcome!'],
#   'title': 'Pulmonic venting and the typology of click nasality',
#   'url': '/lingbuzz/003408'},
#  {'authors': ["Stanislao Zompi'"],
#   'keywords': ['*aba, dependent case, syncretism, suppletion, case hierarchy, distinctness, morphology, syntax'],
#   'published': ['MA thesis, University of Pisa'],
#   'title': 'Case decomposition meets dependent-case theories',
#   'url': '/lingbuzz/003421'},
#  {'authors': ['William Merrill'],
#   'keywords': ['sense, reference, intensional semantics, alternative semantics, predicate abstraction, binding, type theory, lambda calculus, semantics'],
#   'published': [],
#   'title': 'Sense abstraction: a unified framework of intensionality, predicate abstraction, and alternative semantics',
#   'url': '/lingbuzz/003487'},
#  {'authors': ['Aaron Steven White', 'Valentine Hacquard', 'Jeffrey Lidz'],
#   'keywords': ['propositional attitude verbs, syntactic bootstrapping, verb learning, syntax-semantics interface, lexical semantics, projection rules, semantics, syntax'],
#   'published': ['Cognitive Science'],
#   'title': 'Semantic information and the syntax of propositional attitude verbs',
#   'url': '/lingbuzz/003510'},
#  {'authors': ['Ercan Solak', 'Razieh Ehsani'],
#   'keywords': ['relative clause, turkish, morphology, syntax'],
#   'published': [],
#   'title': 'A unifying analysis of Turkish relative clause',
#   'url': '/lingbuzz/003531'},
#  {'authors': ["Roberta D'Alessandro"],
#   'keywords': ['syntax, history, generative grammar, references'],
#   'published': ['draft'],
#   'title': 'The achievements of Generative Syntax: a time chart',
#   'url': '/lingbuzz/003392'},
#  {'authors': ['Itamar Francez', 'Andrew J. Koontz-Garboden'],
#   'keywords': ['semantics, morphology, syntax'],
#   'published': ['Oxford University Press.  (Oxford Studies in Theoretical Linguistics).  PDF available for free thanks to an RCUK grant under CC BY-NC-ND 4.0 terms.'],
#   'title': 'Semantics and Morphosyntactic Variation:  Qualities and the Grammar of Property Concepts',
#   'url': '/lingbuzz/003396'},
#  {'authors': ['Benjamin Storme'],
#   'keywords': ['french, mid vowels, loi de position, syllable, closed-syllable vowel laxing, undershoot, phonology'],
#   'published': ['To appear in Glossa: a journal of general linguistics'],
#   'title': 'The loi de position and the acoustics of French mid vowels',
#   'url': '/lingbuzz/003395'},
#  {'authors': ['Karen De Clercq', 'Guido Vanden Wyngaerd'],
#   'keywords': ['comparative, adjectives, negation, suppletion, nanosyntax, morphology, syntax'],
#   'published': [],
#   'title': 'Splitting up the comparative: evidence from Czech',
#   'url': '/lingbuzz/003171'},
#  {'authors': ['Edoardo Cavirani', 'Marc Van Oostendorp'],
#   'keywords': ['empty positions, markedness, licensing, phonology'],
#   'published': [],
#   'title': 'On silent markedness',
#   'url': '/lingbuzz/003337'},
#  {'authors': ['Javier Ormazabal', 'Juan Romero'],
#   'keywords': ['passive se, impersonal se, quirky subjects, montalbetti effects, syntax'],
#   'published': ['manuscript'],
#   'title': 'The formal properties of non paradigmatic SE',
#   'url': '/lingbuzz/003402'},
#  {'authors': ['Jan Wiślicki'],
#   'keywords': ['quotation, quotes, enquotation, phases, zwart, top-down derivation, split merge, syntax'],
#   'published': ['Submitted'],
#   'title': 'An Argument for Zwart’s Merge. Quotation as a Challenge for Feature-Driven Phases.',
#   'url': '/lingbuzz/003399'},
#  {'authors': ['Sasson  Margaliot'],
#   'keywords': ['minimalist, syntax, semantics, semantics, syntax'],
#   'published': ['syntax'],
#   'title': 'Minimalist Semantics and Pre-Linguistic Intelligence',
#   'url': '/lingbuzz/003409'},
#  {'authors': ['Luisa Marti', 'Tania Ionin'],
#   'keywords': ['scope, indefinites, functional readings, non-functional readings, semantics'],
#   'published': ['under review'],
#   'title': 'Functional and non-functional wide scope indefinites in Russian',
#   'url': '/lingbuzz/003410'},
#  {'authors': ['Daniel Goodhue'],
#   'keywords': ['epistemic modality, indirect, evidential, knowledge, presupposition, implicature, context dependency, semantics, pragmatics, semantics'],
#   'published': [],
#   'title': 'On the felicity conditions of epistemic modals',
#   'url': '/lingbuzz/003023'},
#  {'authors': ['Alessandra Giorgi'],
#   'keywords': ['surprise questions, counter-expectational, adversative, discourse, left-periphery, gestures, syntax'],
#   'published': ['Proceedings LSRL46, pre-print version'],
#   'title': 'Ma non era rosso? (But wasn’t it red?): On counter-expectational questions in Italian',
#   'url': '/lingbuzz/003412'},
#  {'authors': ['Ryan Bennett', 'Boris Harizanov', 'Robert Henderson'],
#   'keywords': ['prosody, subcategorization, clitics, macedonian, kaqchikel, morphology, syntax, phonology'],
#   'published': ['linguistic inquiry'],
#   'title': 'Prosodic smothering in Macedonian and Kaqchikel',
#   'url': '/lingbuzz/003413'},
#  {'authors': ['Alexandru Nicolae', 'Adina DRAGOMIRESCU'],
#   'keywords': ['interpolation, scrambling, old romance, old romanian, istro-romanian, low verb movement, syntactic archaisms, language contact, syntax'],
#   'published': ['Romance Syntax: Comparative and Diachronic Perspectives'],
#   'title': 'SYNTACTIC ARCHAISMS PRESERVED IN A CONTEMPORARY ROMANCE VARIETY: INTERPOLATION AND SCRAMBLING IN OLD ROMANIAN AND ISTRO-ROMANIAN',
#   'url': '/lingbuzz/003415'},
#  {'authors': ['Asia Pietraszko'],
#   'keywords': ['clause nominalization, relative clauses, syntax, morphology, phonology, bantu, ndebele'],
#   'published': ['Ms.'],
#   'title': 'Relative clauses and CP nominalization in Ndebele',
#   'url': '/lingbuzz/003273'},
#  {'authors': ['Lisa Pearl'],
#   'keywords': ['syntax, acquisition, modeling, computational models, bayesian, parametric, non-parametric, syntax'],
#   'published': [],
#   'title': 'Modeling syntactic acquisition',
#   'url': '/lingbuzz/003416'},
#  {'authors': ['Ivano Ciardelli', 'Floris Roelofsen'],
#   'keywords': ['modality, quantification, inquisitive semantics, semanticsarchive, semantics'],
#   'published': [],
#   'title': 'An inquisitive perspective on modals and quantifiers',
#   'url': '/lingbuzz/repo/semanticsArchive/article/001617'},
#  {'authors': ['Petr Biskup'],
#   'keywords': ['case, atb, movement, haplology, non-identity reading, syntax'],
#   'published': ['To appear in: W. Browne, M. Despić, N. Enzinna, R. Karlin, S. De Lemos & D. Zec (eds.), Proceedings of the 25th Meeting of Formal Approaches to Slavic Linguistics. The Cornell Meeting 2016. Ann Arbor, MI: Michigan Slavic Publications, 418-437.'],
#   'title': 'Case Syncretism in Russian, Polish and Czech ATB Constructions',
#   'url': '/lingbuzz/003554'},
#  {'authors': ['Lida Veselovska', 'Joseph Emonds'],
#   'keywords': ['agreement, inflection, derivation, post-syntactic insertion, righ hand head rule, alternative realization, agglutinative ideal, morphology'],
#   'published': [' Linguistica Brunensia 64(1), 143-162'],
#   'title': 'Morphology: Divided and Conquered?',
#   'url': '/lingbuzz/003580'},
#  {'authors': ['Joseph Emonds'],
#   'keywords': ['borer’s conjecture, clitic ordering, french clitics, lexical notation, person-case constraint, clause-mate condition, morphology, syntax'],
#   'published': ['Proceedings of the Third Olomouc Linguistics Conference. Marketa Janebová  and Joseph Emonds (eds.), 109-134'],
#   'title': 'Formal lexical entries for French Clitics: PF dissociations of single marked features',
#   'url': '/lingbuzz/003578'},
#  {'authors': ['Floris Roelofsen', 'Wataru Uegaki'],
#   'keywords': ['wonder, ignorance, inquisitive semantics, exhaustivity, semanticsarchive, semantics'],
#   'published': [],
#   'title': 'The distributive ignorance puzzle',
#   'url': '/lingbuzz/repo/semanticsArchive/article/001605'},
#  {'authors': ['Adina Camelia Bleotu'],
#   'keywords': ['negation, scope, prefixation, spanning'],
#   'published': ['first draft'],
#   'title': 'Verbs derived with negative prefixes in English and Romanian. A spanning account',
#   'url': '/lingbuzz/003301'},
#  {'authors': ['Simon Charlow'],
#   'keywords': ['indefinites, islands, scope, alternatives, alternative semantics, monads, pied piping, questions, binding, dynamic semantics, semantics'],
#   'published': ['Accepted at Linguistics and Philosophy'],
#   'title': 'The scope of alternatives: Indefiniteness and islands',
#   'url': '/lingbuzz/003302'},
#  {'authors': ['Radek Simik', 'Marta Wierzba'],
#   'keywords': ['information structure, givenness, given before new, *stress given, acceptability rating experiments, modeling, multiple regression, slavic, czech, polish, slovak, semantics, syntax, phonology'],
#   'published': ['To appear in Language'],
#   'title': 'Expression of information structure in West Slavic: Modeling the impact of prosodic and word order factors',
#   'url': '/lingbuzz/003304'},
#  {'authors': ['Eman Al-Khalaf'],
#   'keywords': ['closest conjunct agreement, conjunct agreement, coordination, linear order, little pro'],
#   'published': ['submitted'],
#   'title': 'First Conjunct Agreement is an Illusion: Evidence from Arabic',
#   'url': '/lingbuzz/003250'},
#  {'authors': ['Philippe Schlenker', 'Jonathan Lamberton'],
#   'keywords': ['sign language semantics, iconicity, plurals, mass terms, unpunctuated repetitions, punctuated repetitions, continuous repetitions, semantics'],
#   'published': [],
#   'title': 'Iconic Plurality',
#   'url': '/lingbuzz/003306'},
#  {'authors': ['Brian Buccola', 'Andreas Haida'],
#   'keywords': ['modified numerals, free-choice inferences, exhaustivity, recursive exhaustification, semantics'],
#   'published': ['Proceedings of Sinn und Bedeuting 21'],
#   'title': 'A surface-scope analysis of authoritative readings of modified numerals',
#   'url': '/lingbuzz/003307'},
#  {'authors': ['Oriana Kilbourn-Ceron'],
#   'keywords': ['speech production planning, corpus phonology, french liaison, phonology, lexical frequency, external sandhi'],
#   'published': ['Proceedings of the Annual Meeting on Phonology 2016'],
#   'title': 'Speech production planning affects phonological variability: a case study in French liaison',
#   'url': '/lingbuzz/003309'},
#  {'authors': ['Hans Broekhuis'],
#   'keywords': ["object shift, a-scrambling, a'-scrambling, effect-on-output, information structure, intonation, holmberg's generalization, order preservation, vp-topicalization, semantics, syntax, phonology"],
#   'published': [],
#   'title': 'Object movement (object shift and scrambling)',
#   'url': '/lingbuzz/003217'},
#  {'authors': ['Norbert Francis'],
#   'keywords': ['russian formalism, marxism, poetics, socialist realism, science, art, semantics'],
#   'published': ['International Journal of Russian Studies'],
#   'title': 'The Trotsky-Shklovsky debate: Formalism versus Marxism',
#   'url': '/lingbuzz/003310'},
#  {'authors': ['Shanti Ulfsbjorninn'],
#   'keywords': ['quantity sensitivity, metathesis, hawu, schwa, lenition, fortition, language universals, phonology-phonetics interface, phonetic interpretation, empty nuclei, strict cv, syllable structure, diachronic phonology, phonology'],
#   'published': ['comments welcome s.ulfsbjorninn a t ucl dot ac do t uk'],
#   'title': 'Lenition and Metathesis in Hawu (now understood as a quantity sensitive language)',
#   'url': '/lingbuzz/003296'},
#  {'authors': ['Theresa Biberauer'],
#   'keywords': ['word order, extended projection, final-over-final condition, morphology, syntax'],
#   'published': ['The Final-over-Final Condition: A Syntactic Universal (to appear with MIT Press in 2017)'],
#   'title': 'The Final-over-Final Condition and Particles',
#   'url': '/lingbuzz/003313'},
#  {'authors': ['Ava Creemers', 'Jan Don', 'Paula Fenger'],
#   'keywords': ['derivational affixes, distributed morphology, stress-behaviour, categorial flexibility, phasal spell-out, morphology, phonology'],
#   'published': ['Accepted, NLLT'],
#   'title': 'Some affixes are roots, others are heads',
#   'url': '/lingbuzz/003258'},
#  {'authors': ['Irene Heim'],
#   'keywords': ['semanticsarchive, semantics'],
#   'published': [],
#   'title': 'Towards a unified semantics of definite and indefinite noun phrases',
#   'url': '/lingbuzz/repo/semanticsArchive/article/001606'},
#  {'authors': ['Daniel Goodhue', 'Michael Wagner'],
#   'keywords': ['polar particles, yes, no, intonation, prosody, contradiction contour, negative questions, semantics, syntax, phonology'],
#   'published': [],
#   'title': 'Intonation, yes and no',
#   'url': '/lingbuzz/003082'},
#  {'authors': ['Elan Dresher', 'Andrew Ira Nevins'],
#   'keywords': ['vowel harmony, oroqen, manchu, morpheme-structure constraints, loanwords., phonology'],
#   'published': ['submitted'],
#   'title': 'Conditions on Iterative Rounding Harmony in Oroqen',
#   'url': '/lingbuzz/003315'},
#  {'authors': ['Wei-Tien Dylan Tsai'],
#   'keywords': ['theory of grammaticalization, cartographic approach, affective constructions, chinese syntax, dialect grammar, syntax'],
#   'published': ['Tsing Hua Journal of Chinese Studies'],
#   'title': 'On Split Affectivity in Chinese',
#   'url': '/lingbuzz/003316'},
#  {'authors': ['Michael Yoshitaka Erlewine'],
#   'keywords': ['that-trace effect, english, anti-locality, cyclic linearization, syntax'],
#   'published': ['Halpert, Kotek, and Van Urk (eds.) A Pesky Set: Papers for David Pesetsky. MITWPL 2017'],
#   'title': 'Why the null complementizer is special in the English that-trace effect',
#   'url': '/lingbuzz/002029'},
#  {'authors': ['Antonio Fábregas', 'Raquel González-Rodríguez'],
#   'keywords': ['negation, negative events, situations, events, modality, auxiliaries, tense, scope, semantics, syntax'],
#   'published': ['Tromsø / Castilla-La Mancha'],
#   'title': 'Building negative events',
#   'url': '/lingbuzz/003321'},
#  {'authors': ['Linmin Zhang'],
#   'keywords': ['modified numerals, distributivity, collectivity, maximality, post-supposition, semanticsarchive, semantics'],
#   'published': [],
#   'title': 'Modified numerals revisited: The cases of fewer than 4 and between 4 and 8',
#   'url': '/lingbuzz/repo/semanticsArchive/article/001607'},
#  {'authors': ['Zheng Shen'],
#   'keywords': ['fragment answer, superlatives, syntax, semantics, ellipsis, movement, semantics, syntax'],
#   'published': ['accepted. Natural Language and Linguistic Theory'],
#   'title': 'Fragment answers: a superlative argument',
#   'url': '/lingbuzz/003323'},
#  {'authors': ['Mayumi Hosono'],
#   'keywords': ['criterial position, labeling algorithm, scandinavian object shift, icelandic stylistic fronting, syntax, phonology'],
#   'published': ['Working Papers in Scandinavian Syntax 97 (2016) 23-39'],
#   'title': 'Exceptional Movement from/into the Criterial Position',
#   'url': '/lingbuzz/003324'},
#  {'authors': ['Idan Landau'],
#   'keywords': ['control, adjunct clauses, passive, syntax'],
#   'published': ['A Pesky Set: Papers for David Pesetsky, ed. by Halpert, C., H. Kotek and C. van Urk, Cambridge, MA: MITWPL'],
#   'title': 'Adjunct Control Depends on Voice',
#   'url': '/lingbuzz/003322'},
#  {'authors': ['Aaron Steven White', 'Valentine Hacquard', 'Jeffrey Lidz'],
#   'keywords': ['syntactic bootstrapping, word learning, verb learning, propositional attitude verbs, main clause syntax, labeling problem, semantics, syntax'],
#   'published': ['To appear in Semantics in Acquisition. Trends in Language Acquisition Research (TiLAR).'],
#   'title': 'Main clause syntax and the labeling problem in syntactic bootstrapping',
#   'url': '/lingbuzz/002917'},
#  {'authors': ['Linmin Zhang'],
#   'keywords': ['modified numerals, distributivity, collectivity, maximality, post-supposition, semantics'],
#   'published': ['Proceedings of Sinn und Bedeutung 21'],
#   'title': 'Modified numerals revisited: The cases of fewer than 4 and between 4 and 8',
#   'url': '/lingbuzz/003325'},
#  {'authors': ['Aaron Steven White', 'Kyle Rawlins'],
#   'keywords': ['lexical aspect, clause embedding, change of state, factivity, veridicality, semantics'],
#   'published': ['Proceedings of Sinn und Bedeutung 21'],
#   'title': 'Question agnosticism and change of state',
#   'url': '/lingbuzz/003326'},
#  {'authors': ['Marieke Olthof',
#    'Maud Westendorp',
#    'Jelke Bloem',
#    'Fred Weerman'],
#   'keywords': ['verb clusters, dutch, language change, language variation, apparent time, corpus gesproken nederlands, syntax'],
#   'published': ['Tijdschrift voor Nederlandse Taal- & Letterkunde (2017/01)'],
#   'title': 'Synchronic variation and diachronic change in Dutch two-verb clusters',
#   'url': '/lingbuzz/003328'},
#  {'authors': ['Aaron Steven White', 'Kyle Rawlins', 'Benjamin Van Durme'],
#   'keywords': ['linking theory, thematic role, protorole, generative model, computational model, semantics, syntax'],
# ...
#   'title': 'Recursive Compounds and Word-Stress Location',
#   'url': '/lingbuzz/001467'},
#  {'authors': ['Liching Livy Chiu'],
#   'keywords': ['ellipsis, sluicing, np ellipsis, vp ellipsis, tag question, chinese syntax'],
#   'published': ['2011, PhD dissertation, National Tsing Hua University'],
#   'title': 'The Phrasal Empty Categories in Mandarin Chinese',
#   'url': '/lingbuzz/001557'},
#  {'authors': ['Thomas Wier'],
#   'keywords': ['morphosyntax, unaccusativity, telicity, aktionsart, aspect, nominalization, megrelian, svan, old georgian, laz, causative constructions, georgian, features, case, grammatical relations, amorphous morphology, inversion, grammatical functions, agreement, paradigm-function morphology, feature theory, person-role constraint, person-case constraint, feature hierarchies, hierarchical alignment, distributed morphology, appositives, feature geometry, semantics, morphology, syntax'],
#   'published': ['University of Chicago PhD dissertation'],
#   'title': 'Georgian Morphosyntax and Feature Hierarchies in Natural Language',
#   'url': '/lingbuzz/002030'},
#  {'authors': ['Giorgio Magri'],
#   'keywords': ['online algorithms, phonotactics, convergence, constraint promotion, phonology, computation, learnability, ot, roa'],
#   'published': [],
#   'title': 'A computational perspective on OT online models of the early stage of the acquisition of phonotactics. Part 1: convergence',
#   'url': '/lingbuzz/repo/ROA/article/001038'},
#  {'authors': ['Ad Neeleman', 'Hans Van De Koot'],
#   'keywords': ['(direct) causation, events, agents, instruments, stative causatives, syntax, semantics'],
#   'published': ['(Revised version) To appear in M. Everaert, M. Marelj and T. Siloni (eds.) The Theta System: Argument Structure at the Interface. OUP.'],
#   'title': 'The linguistic expression of causation',
#   'url': '/lingbuzz/001137'},
#  {'authors': ['Maria Gouskova'],
#   'keywords': ['russian, stress, compounds, voicing, vowel reduction, yers, prosodic word, phonology, morphology, ot, roa'],
#   'published': [],
#   'title': 'The Phonology of Boundaries and Secondary Stress in Russian Compounds',
#   'url': '/lingbuzz/repo/ROA/article/001027'},
#  {'authors': ['Paul Roger Bassong'],
#   'keywords': ["basa'a, cartography, left periphery, syntax"],
#   'published': ['University of Yaounde 1; Yaounde'],
#   'title': "The structure of the Left Periphery in Basa'a",
#   'url': '/lingbuzz/001692'},
#  {'authors': ['Halldor Armann Sigurdsson'],
#   'keywords': ['epp, expletives, movement, person, stylistic fronting'],
#   'published': ['Studia Linguistica 64:159-\x96189'],
#   'title': 'On EPP effects',
#   'url': '/lingbuzz/000508'},
#  {'authors': ['Michelle Sheehan'],
#   'keywords': ['ced, extraction, adjuncts, subjects, word order, fofc, head-parameter, labelling, syntax'],
#   'published': ['In S. Kan, C. Moore-Cantwell & R. Staubs (eds.), Proceedings of the 40th Annual Meeting of the North East Linguistic Society (NELS 40). Amherst, Mass.: GLSA, 135-150.'],
#   'title': 'The resuscitation of CED',
#   'url': '/lingbuzz/002125'},
#  {'authors': ['Philippe Schlenker'],
#   'keywords': ['semantics, semantics'],
#   'published': ['Proceedings of NELS 2009, Special Session on Pronouns'],
#   'title': 'Donkey Anaphora in Sign Language II: The presuppositions of Pronouns  (2010)',
#   'url': '/lingbuzz/002584'},
#  {'authors': ['Adina Camelia Bleotu'],
#   'keywords': ['root nn compounds, productivity, acquisition, semantics, morphology, syntax'],
#   'published': ['unpublished '],
#   'title': 'The Productivity of NN Compounds in English and Romanian (MA dissertation)',
#   'url': '/lingbuzz/003144'},
#  {'authors': ['Robert Staubs',
#    'Michael Becker',
#    'Christopher Potts',
#    'Patrick Pratt',
#    'John J. Mccarthy',
#    'Joe Pater'],
#   'keywords': ['harmonic serialism, harmonic grammar, typology, formal analysis, ot, roa, phonology'],
#   'published': [],
#   'title': 'OT-Help 2',
#   'url': '/lingbuzz/repo/ROA/article/001088'},
#  {'authors': ['Dennis Ott'],
#   'keywords': ['syntax, free relatives, relative clauses, transfer, spell-out, phases'],
#   'published': ['Linguistic Inquiry 42(1):183-192'],
#   'title': 'A note on free relative clauses in the theory of phases',
#   'url': '/lingbuzz/000950'},
#  {'authors': ['Joe Pater'],
#   'keywords': ['harmonic grammar, harmonic serialism, syllabification, berber, sonority, phonology, ot, roa'],
#   'published': [],
#   'title': 'Serial Harmonic Grammar and Berber Syllabification',
#   'url': '/lingbuzz/repo/ROA/article/001016'},
#  {'authors': ['Eric Bakovic'],
#   'keywords': ['opacity, counterfeeding, counterbleeding, blocking, feeding, bleeding, phonology'],
#   'published': ['The Handbook of Phonological Theory, 2nd ed.'],
#   'title': 'Opacity deconstructed',
#   'url': '/lingbuzz/000926'},
#  {'authors': ['Anastasia Giannakidou', 'Suwon Yoon'],
#   'keywords': ['npi licensing, rescuing, comparatives, greek, korean, english, semanticsarchive, semantics'],
#   'published': [],
#   'title': 'No NPI licensing in comparatives',
#   'url': '/lingbuzz/repo/semanticsArchive/article/000884'},
#  {'authors': ['Anastasia Giannakidou', 'Suwon Yoon'],
#   'keywords': ['npi-licensing, npi-rescuing, comparatives, greek, korean, english, semantics'],
#   'published': ['Chicago Linguistic Society 46, 2010'],
#   'title': 'No NPI licensing in comparatives',
#   'url': '/lingbuzz/001070'},
#  {'authors': ['Bridget Copley', 'Heidi Harley'],
#   'keywords': ['event semantics, frustratives, non-culminating accomplishments, progressive, inertia, force dynamics, semanticsarchive, semantics'],
#   'published': [],
#   'title': 'An ontology for a force-dynamic treatment of events',
#   'url': '/lingbuzz/repo/semanticsArchive/article/001207'},
#  {'authors': ['Dennis Ott', 'Andreea Nicolae'],
#   'keywords': ['topicalization, fronting, split topicalization, information structure, antisymmetry, german, syntax, semantics'],
#   'published': ['Proceedings of CLS 46 (to appear)'],
#   'title': 'The syntax and semantics of Genus-species Splits in German',
#   'url': '/lingbuzz/001071'},
#  {'authors': ['Jessica Coon'],
#   'keywords': ['ergativity, nominalization, aspect, split, mayan, morphology, syntax'],
#   'published': ['PhD thesis, MIT, Cambridge, MA'],
#   'title': 'Complementation in Chol (Mayan): A Theory of Split Ergativity',
#   'url': '/lingbuzz/001072'},
#  {'authors': ['Louise McNally'],
#   'keywords': ['gradability, adjectives, sorites paradox, semanticsarchive, semantics'],
#   'published': [],
#   'title': 'The relative role of property type vs. scale structure in explaining  the behavior of gradable adjectives',
#   'url': '/lingbuzz/repo/semanticsArchive/article/000885'},
#  {'authors': ['Katrin Skoruppa', 'Sharon Peperkamp'],
#   'keywords': ['speech perception, phonological learning, dialects, accents, features, phonology'],
#   'published': ['Cognitive Science'],
#   'title': 'Adaptation to novel accents:  Feature-based learning of context-sensitive phonological regularities',
#   'url': '/lingbuzz/001073'},
#  {'authors': ['Shigeto Kawahara', 'Kelly Garvey'],
#   'keywords': ['the p-map, perceptual similarity, similarity judgments, too-many-solutions-problem, laboratory phonology, phonology, phonetics, psycholinguistics, ot, roa'],
#   'published': [],
#   'title': 'Testing the P-map hypothesis: Coda devoicing',
#   'url': '/lingbuzz/repo/ROA/article/001078'},
#  {'authors': ['Shigeto Kawahara'],
#   'keywords': ['japanese, accent, preaccentuation, experimental phonology, phonology, psycholinguistics, ot, roa'],
#   'published': [],
#   'title': 'The productivity of an initial accenting suffix, [-zu]: Judgement studies',
#   'url': '/lingbuzz/repo/ROA/article/001017'},
#  {'authors': ['Ricardo Bermudez-Otero'],
#   'keywords': ['cycle, level, stratal ot, lexical phonology, opacity, prosody, oo-correspondence, transderivational, base, sandhi, categorical, gradient, analogy, diachrony, ambisyllabicity, intrusive r, morphophonology, phonology'],
#   'published': ['In Marc van Oostendorp, Colin Ewen, Elizabeth Hume, and Keren Rice (eds) (2011). The Blackwell companion to phonology (vol. 4: Phonological interfaces), 2019-2048. Malden, MA: Wiley-Blackwell.'],
#   'title': 'Cyclicity',
#   'url': '/lingbuzz/000965'},
#  {'authors': ['Florian Schwarz'],
#   'keywords': ['situation pronouns, transparent interpretations, intensionality, domain restriction, semanticsarchive, semantics'],
#   'published': [],
#   'title': 'Situation pronouns where you need them',
#   'url': '/lingbuzz/repo/semanticsArchive/article/000886'},
#  {'authors': ['Jon Sprouse', 'Diogo Almeida'],
#   'keywords': ['acceptability judgments, linguistic theory, linguistic methodology, quantitative standards, experimental syntax, syntax'],
#   'published': [],
#   'title': 'A quantitative defense of linguistic methodology',
#   'url': '/lingbuzz/001075'},
#  {'authors': ['John J. Mccarthy'],
#   'keywords': ['agreement by correspondence, abc, harmony, phonology, ot, roa'],
#   'published': [],
#   'title': 'Agreement By Correspondence Without Corr Constraints',
#   'url': '/lingbuzz/repo/ROA/article/001018'},
#  {'authors': ['Claudia Pons'],
#   'keywords': ['manner alternations, manner assimilation, rhotacism, gliding, syllable contact, relational alignment, stringency, sonority scale, romance languages, phonology, ot, roa'],
#   'published': [],
#   'title': 'It is all downhill from here: a typological study of the role of Syllable Contact in Romance languages',
#   'url': '/lingbuzz/repo/ROA/article/001020'},
#  {'authors': ['Maria Ohannesian', 'Claudia Pons'],
#   'keywords': ['paradigms, subparadigms, overapplication, inclusion, optimal paradigms model, transderivational correspondence theory, gender, number, productive derivation, phonology, morphology, ot, roa'],
#   'published': [],
#   'title': 'Shattering Paradigms. An Attempt to Formalize Pressures within Subparadigms',
#   'url': '/lingbuzz/repo/ROA/article/001085'},
#  {'authors': ['Claudia Pons'],
#   'keywords': ['vowel reduction, underapplication, inflectional (sub)paradigms, derivational (sub)paradigms, transderivational correspondence theory, optimal paradigms model, positional faithfulness, phonology, morphology, ot, roa'],
#   'published': [],
#   'title': 'Underapplication of vowel reduction to schwa in Majorcan Catalan. Some evidence for the left syllable of the stem as a prominent position and for subparadigms',
#   'url': '/lingbuzz/repo/ROA/article/001021'},
#  {'authors': ['Claudia Pons'],
#   'keywords': ['analogy, paradigmatic pressures, markedness, inflectional and derivational paradigms, overapplication, underapplication, optimal paradigms, subparadigms, romance languages, phonology, morphology, ot, roa'],
#   'published': [],
#   'title': 'When diachrony meets synchrony. Phonological change, phonological variation and Optimal Paradigms',
#   'url': '/lingbuzz/repo/ROA/article/001019'},
#  {'authors': ['Elizabeth Ritter', 'Martina Wiltschko'],
#   'keywords': ['infl, tense, infinitives, imperatives, counterfactuals, functional category, syntax'],
#   'published': [],
#   'title': 'The composition of INFL. An exploration of tense, tenseless languages and tenseless constructions',
#   'url': '/lingbuzz/001078'},
#  {'authors': ['Norman Yeo'],
#   'keywords': ['optional wh-movement, epp, question particle, syntax'],
#   'published': ['York'],
#   'title': 'Explaining and Unifying Optional Wh-Movement',
#   'url': '/lingbuzz/001082'},
#  {'authors': ['Andrea Moro'],
#   'keywords': ['multiple wh-, wh-in situ, left periphery, clause structure, syntax'],
#   'published': ['Linguistic Inquiry (accepted; to be published in 2011)'],
#   'title': 'Clause structure folding and the wh-in situ effect',
#   'url': '/lingbuzz/001112'},
#  {'authors': ['Michael Barrie'],
#   'keywords': ['noun incorporation, dynamic antisymmetry, iroquoian, morpho-syntax, roll-up, syntax'],
#   'published': ['Canadian Journal of Linguistics'],
#   'title': 'Noun Incorporation as Symmetry Breaking',
#   'url': '/lingbuzz/001115'},
#  {'authors': ['Ángel L. Jiménez-Fernández'],
#   'keywords': ['topic fronting, feature inheritance, multiple topics, cp-domain, tp-system, multiple specifiers, syntax'],
#   'published': ['Dilbilim Araştırmaları'],
#   'title': 'On the Order of Multiple Topics and Discourse-feature Inheritance',
#   'url': '/lingbuzz/001216'},
#  {'authors': ['Matthew Reeve'],
#   'keywords': ['clefts, relative clauses, copular sentences, russian, specificational sentences, syntax'],
#   'published': ['UCL PhD thesis (revised version published by John Benjamins, 2012)'],
#   'title': 'Clefts',
#   'url': '/lingbuzz/001019'},
#  {'authors': ['Luis Alonso-Ovalle', 'Paula Menendez-Benito'],
#   'keywords': ['indefinites, domain widening, free choice, implicatures, semanticsarchive, semantics'],
#   'published': [],
#   'title': 'Plural Epistemic Indefinites',
#   'url': '/lingbuzz/repo/semanticsArchive/article/001218'},
#  {'authors': ['Dorian Roehrs'],
#   'keywords': ['dp, extended adjective construction, syntax'],
#   'published': [],
#   'title': 'Toward Explaining the Head-Final Filter',
#   'url': '/lingbuzz/001020'},
#  {'authors': ['Dennis Ott'],
#   'keywords': [],
#   'published': ['to appear in a festschrift'],
#   'title': 'Varieties of VP-fronting',
#   'url': '/lingbuzz/001024'},
#  {'authors': ['Antonio Fábregas'],
#   'keywords': ['prefix, preposition, figure-ground, cartography, spanish, morphology, syntax'],
#   'published': ['Catalan Journal of Linguistics'],
#   'title': 'On Spanish Prepositional Prefixes and the Cartography of Prepositions',
#   'url': '/lingbuzz/001025'},
#  {'authors': ['Luis Umali Stuart'],
#   'keywords': ['cognitive semantics, tagalog, natural language processing, psycholinguistics, universal grammar, basic strings'],
#   'published': ['http://www.lulu.com/content/e-book/the-secret-grid-of-language/8537171'],
#   'title': 'THE GRID OF LANGUAGE: A Deep Structure Surfaces in Tagalog (Part 1)',
#   'url': '/lingbuzz/000996'},
#  {'authors': ['Pavel Caha'],
#   'keywords': ['case, movement, phrasal spell out, morphology, nanosyntax, syntax'],
#   'published': [],
#   'title': 'The parameters of case marking and spell out driven movement',
#   'url': '/lingbuzz/001026'},
#  {'authors': ['Liliane Haegeman'],
#   'keywords': ['particles, speech act layer, antisymmetry, discourse markers, syntax'],
#   'published': [],
#   'title': 'West Flemish verb-based discourse markers and the articulation of the speech act layer',
#   'url': '/lingbuzz/001027'},
#  {'authors': ['Daniel Altshuler'],
#   'keywords': ['aspect, imperfective, progressive, narrative progression, russian, semanticsarchive, semantics'],
#   'published': [],
#   'title': 'A birelational analysis of the Russian imperfective',
#   'url': '/lingbuzz/repo/semanticsArchive/article/000875'},
#  {'authors': ['Julia Horvath', 'Tal Siloni'],
#   'keywords': ['causative, unaccusative, external argument, experiencer verb, lexicon, decomposition, syntax'],
#   'published': ['NLLT (submitted)'],
#   'title': 'Causatives across Components',
#   'url': '/lingbuzz/001029'},
#  {'authors': ['Alexander Letuchiy'],
#   'keywords': ['polysynthesis, semantic ordering, scope of operators, causative, negation, agentivity, event structure, valency'],
#   'published': ['Unpublished ms.'],
#   'title': 'Semantic properties of participants and ordering of derivations in Adyghe',
#   'url': '/lingbuzz/001015'},
#  {'authors': ['Thomas Leu'],
#   'keywords': ['germanic - verb second - adjectival agreement - complementizer - definite article - extended projection  - syntax/morphology, morphology, syntax'],
#   'published': ['submitted'],
#   'title': 'Generalized x-to-C in Germanic',
#   'url': '/lingbuzz/001030'},
#  {'authors': ['Peter Staroverov'],
#   'keywords': ['too-many-solutions, harmonic serialism, ps-constraints, phonological position, phonology, ot, roa'],
#   'published': [],
#   'title': 'Too-many-solutions and Reference to Position in Serial OT',
#   'url': '/lingbuzz/repo/ROA/article/001009'},
#  {'authors': ['Vincent Homer'],
#   'keywords': ['epistemic modals, root modals, negation, tense, polarity, ppi, syntax, semantics'],
#   'published': ['To appear in the Proceedings of NELS 40'],
#   'title': 'Epistemic Modals: High ma non troppo',
#   'url': '/lingbuzz/001086'},
#  ...]

# %%
client = MongoClient()
db = client.lingbuzz
#db.create_collection("papers")
papers = db.get_collection('papers')
#papers.insert_many(meta_data)

# %%
for _ in papers.find()[:5]:
    print(_)
# Out:
# {'_id': ObjectId('598b44c407d7df07719383e0'), 'title': 'The clause-mate condition on resumption: Evidence from Kaqchikel', 'authors': ['Yusuke Imanishi'], 'published': ['To appear in Studia Linguistica'], 'keywords': ['resumption, possessor wh phrases, the clause-mate condition on resumptive chains, island (in)sensitivity, kaqchikel (mayan), syntax'], 'url': '/lingbuzz/003606'}
# {'_id': ObjectId('598b44c407d7df07719383e1'), 'title': "The Preliminary Material of 'Natural Language and Possible Minds: How Language Uncovers the Cognitive Landscape of Nature'", 'authors': ['Prakash Mondal'], 'published': ['Leiden/Boston: Brill (2017)'], 'keywords': ['natural language; cognition; possible minds; mentality; organisms; machines; computation, semantics, syntax'], 'url': '/lingbuzz/003607'}
# {'_id': ObjectId('598b44c407d7df07719383e2'), 'title': 'Analytic Passives in Czech', 'authors': ['Lida Veselovska'], 'published': ['Zeitschrift für Slawistik 49 (2) 2004: 163–235'], 'keywords': ['czech passives, passive vs. past participles, czech clitics, past czech auxiliary, grammatical morphemes, instrumental case, post-syntactic insertion, post-syntactic derivation, semantics, morphology, syntax, morphology, syntax'], 'url': '/lingbuzz/003608'}
# {'_id': ObjectId('598b44c407d7df07719383e3'), 'title': 'Stylistic Fronting in corpora', 'authors': ['Halldor Armann Sigurdsson'], 'published': ['In Syntactic Variation in Insular Scandinavian, ed. by Höskuldur Thráinsson, Caroline Heycock, Hjalmar P. Petersen & Zakaris Svabo Hansen, 307–338 [Studies in Germanic Linguistics 1]. Amsterdam: John Benjamins.'], 'keywords': ['expletive insertion, extended projection principle, google search, impersonal clauses, stylistic fronting, relative clauses, timarit.is, verb-initial adverbial clauses, word order frequencies, syntax, phonology'], 'url': '/lingbuzz/002635'}
# {'_id': ObjectId('598b44c407d7df07719383e4'), 'title': 'Topicality in Icelandic: Null arguments and Narrative Inversion', 'authors': ['Halldor Armann Sigurdsson'], 'published': ['To appear in Verner Egerland, Valéria Molnár & Susanne Winkler: Architecture of Topic. Berlin: De Gruyter Mouton.'], 'keywords': ['null arguments, narrative inversion, topicality, icelandic, semantics, syntax'], 'url': '/lingbuzz/003611'}

# %% [markdown]
# ## Insert papers
#
# Due to bad scraping, I have to match the pdfs that I actually downloaded on the metadata in the DB through a txt file containg the urls that I downloaded.

# %%
# put urls that I downloaded in df to easily find the files that match
with open('../papers/urls.txt') as f:
    urls = [url.strip() for url in f.readlines()]
splitted_urls = []
for url in urls:
    splitted = url.split('/')
    for_match = ['/'.join(splitted[:3]), '/'+'/'.join(splitted[3:5]), splitted[5]]
    splitted_urls.append(for_match)
url_df = pd.DataFrame(splitted_urls)

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import HTMLConverter,TextConverter,XMLConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
import io
import os

# %%
## stolen and adapted from https://stackoverflow.com/questions/5725278/how-do-i-use-pdfminer-as-a-library/8325135#8325135
def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = io.StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    maxpages = 0
    caching = True
    pagenos=set()
    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, caching=caching, check_extractable=True):
        interpreter.process_page(page)
    fp.close()
    device.close()
    string = retstr.getvalue()
    retstr.close()
    return string

# %%
# find matching pdfs, convert and insert in db
for doc in papers.find()[:5]:
    if url_df.iloc[:,1].str.contains(doc['url']).any():
        to_match = doc['url']
        url = url_df[url_df.iloc[:,1]==to_match].iloc[:,2].iloc[0]
        text = convert_pdf_to_txt('../papers/'+url)
        text = text.replace('\n', ' ').replace('\r', ' ')
        print(doc['url'] == to_match)
        papers.update_one({"url": to_match},{"$set": {"paper": text}})
# Out:
# True

# %%
for doc in papers.find()[:5]:
    print(doc)
# Out:
# {'_id': ObjectId('598b44c407d7df07719383e0'), 'title': 'The clause-mate condition on resumption: Evidence from Kaqchikel', 'authors': ['Yusuke Imanishi'], 'published': ['To appear in Studia Linguistica'], 'keywords': ['resumption, possessor wh phrases, the clause-mate condition on resumptive chains, island (in)sensitivity, kaqchikel (mayan), syntax'], 'url': '/lingbuzz/003606'}
# {'_id': ObjectId('598b44c407d7df07719383e1'), 'title': "The Preliminary Material of 'Natural Language and Possible Minds: How Language Uncovers the Cognitive Landscape of Nature'", 'authors': ['Prakash Mondal'], 'published': ['Leiden/Boston: Brill (2017)'], 'keywords': ['natural language; cognition; possible minds; mentality; organisms; machines; computation, semantics, syntax'], 'url': '/lingbuzz/003607'}
# {'_id': ObjectId('598b44c407d7df07719383e2'), 'title': 'Analytic Passives in Czech', 'authors': ['Lida Veselovska'], 'published': ['Zeitschrift für Slawistik 49 (2) 2004: 163–235'], 'keywords': ['czech passives, passive vs. past participles, czech clitics, past czech auxiliary, grammatical morphemes, instrumental case, post-syntactic insertion, post-syntactic derivation, semantics, morphology, syntax, morphology, syntax'], 'url': '/lingbuzz/003608', 'paper': "ANALYTIC PASSIVES IN CZECH  \n\nLudmila Veselovská & Petr Karlík \n\nINTRODUCTION: DEFINING THE PROBLEM \n\nLike other languages, Czech also has pairs of sentences clearly related both in their \nform and in their meaning. The example (1) illustrates the phenomena of passivisation  \nwhich is the topic of our paper.  According to the traditional terminology  (1a) \ndemonstrates an active structure and (1b) the related passive structure. \n  \n(1) \n\n(b)  \n \n\nPavel je chválen Petrem \nPaul   is praised  by Peter \n\n(a)  \n \n\nPetr chválí Pavla \uf0de    \nPeter praises Paul \uf0de   \n\nThe semantic relation between (1a) and (1b) can be stated as an intuition that both \nexamples describe the same extralinguistic situation and have ‘similar truth values” \n(each implies the other). The formal similarity between (1a) and (1b) follows from the \nfact that both examples contain close to identical lexical material. The distinctions \nbetween (1a) and (1b) can be summarised as follows.  \n \n(2) \n\n(a)  Morphology:  \n\n(i)  \n(ii) \n(iii) \n\n(b) \n\n(c) \n\nthe constituent which is in Nominative in (1a) is in Instrumental in (1b),  \nthe constituent which is in Accusative in  (1a) is in Nominative in (1b),   \nthe verb which is finite in (1a) is non-finite in (1b);  \n\nLexical material: (1b) contains an additional lexical item, namely a \nfinite form of a verb být (‘be’), which is not present in (1a);  \n\nChange in neutral (unmarked) linear order: the constituent which is \npreverbal in (1a) is postverbal in (1b), and the constituent which is \npostverbal in (1a) is preverbal in (1b).  \n\n \nBecause of time and space reasons we are not going to refer to all works which have \ndealt with the process of passivisation. The analysis of passive structures is a \nnecessary part of any scientific linguistic framework and it often represents a hallmark \nfor general theoretical concepts and overall methodology. Thus Czech linguistics in \nthe second half of the 20th century approaches the topic accentuating the functional \naspects of the passive.1  \n\n \n                                                 \n1   In more contemporary frameworks, studies by Ivan Poldauf (1940, 1969) give a \n\nrepresentative Prague School structuralist approach and a detail comparison of Czech and \nEnglish passive structures. A related functional generative linguists (Encyklopedický \nslovník češtiny, 2002: 146) analyse Czech passive in terms of the functional sentence \nperspective, e.g. as a means of de-thematisation / de-topicalisation of the agent and/or \nthematisation of the patient (see e.g. Petr Sgall, 1972). On the other hand, the  proponents \nof the multilevel valency theory ( see e.g. Encyklopedický slovník češtiny, 2002: 118) refer \n(see the next page) \n\n \n\n1 \n\n\x0cPresent transformational generative grammar of a Chomskian type concentrates \n\non formal properties and characteristics of passive structures which have not yet been \nin the centre of attention of Czech linguistics.  In the following paper we are going to \ndiscuss the formal properties of the Czech analytic passive structures in (1b) using the  \ncontemporary stage of development of the Chomskyan framework.  Our analysis of \npassives is thus also meant to show that even languages with rich inflection and \nrelatively free constituent order, like Czech, can successfully be described in terms of \ngenerative grammar, and that such an analysis can contribute to the development of \nthe general linguistic theory ...
# {'_id': ObjectId('598b44c407d7df07719383e3'), 'title': 'Stylistic Fronting in corpora', 'authors': ['Halldor Armann Sigurdsson'], 'published': ['In Syntactic Variation in Insular Scandinavian, ed. by Höskuldur Thráinsson, Caroline Heycock, Hjalmar P. Petersen & Zakaris Svabo Hansen, 307–338 [Studies in Germanic Linguistics 1]. Amsterdam: John Benjamins.'], 'keywords': ['expletive insertion, extended projection principle, google search, impersonal clauses, stylistic fronting, relative clauses, timarit.is, verb-initial adverbial clauses, word order frequencies, syntax, phonology'], 'url': '/lingbuzz/002635'}
# {'_id': ObjectId('598b44c407d7df07719383e4'), 'title': 'Topicality in Icelandic: Null arguments and Narrative Inversion', 'authors': ['Halldor Armann Sigurdsson'], 'published': ['To appear in Verner Egerland, Valéria Molnár & Susanne Winkler: Architecture of Topic. Berlin: De Gruyter Mouton.'], 'keywords': ['null arguments, narrative inversion, topicality, icelandic, semantics, syntax'], 'url': '/lingbuzz/003611'}

# %%
for doc in papers.find()[:5]:
    try: 
        print(doc['paper'])
    except:
        pass
# Out:
# ANALYTIC PASSIVES IN CZECH
#
# Ludmila Veselovská & Petr Karlík
#
# INTRODUCTION: DEFINING THE PROBLEM
#
# Like other languages, Czech also has pairs of sentences clearly related both in their
# form and in their meaning. The example (1) illustrates the phenomena of passivisation
# which is the topic of our paper.  According to the traditional terminology  (1a)
# demonstrates an active structure and (1b) the related passive structure.
#
# (1)
#
# (b)
#
#
# Pavel je chválen Petrem
# Paul   is praised  by Peter
#
# (a)
#
#
# Petr chválí Pavla 
# Peter praises Paul 
#
# The semantic relation between (1a) and (1b) can be stated as an intuition that both
# examples describe the same extralinguistic situation and have ‘similar truth values”
# (each implies the other). The formal similarity between (1a) and (1b) follows from the
# fact that both examples contain close to identical lexical material. The distinctions
# between (1a) and (1b) can be summarised as follows.
#
# (2)
#
# (a)  Morphology:
#
# (i)
# (ii)
# (iii)
#
# (b)
#
# (c)
#
# the constituent which is in Nominative in (1a) is in Instrumental in (1b),
# the constituent which is in Accusative in  (1a) is in Nominative in (1b),
# the verb which is finite in (1a) is non-finite in (1b);
#
# Lexical material: (1b) contains an additional lexical item, namely a
# finite form of a verb být (‘be’), which is not present in (1a);
#
# Change in neutral (unmarked) linear order: the constituent which is
# preverbal in (1a) is postverbal in (1b), and the constituent which is
# postverbal in (1a) is preverbal in (1b).
#
#
# Because of time and space reasons we are not going to refer to all works which have
# dealt with the process of passivisation. The analysis of passive structures is a
# necessary part of any scientific linguistic framework and it often represents a hallmark
# for general theoretical concepts and overall methodology. Thus Czech linguistics in
# the second half of the 20th century approaches the topic accentuating the functional
# aspects of the passive.1
#
#
#
# 1   In more contemporary frameworks, studies by Ivan Poldauf (1940, 1969) give a
#
# representative Prague School structuralist approach and a detail comparison of Czech and
# English passive structures. A related functional generative linguists (Encyklopedický
# slovník češtiny, 2002: 146) analyse Czech passive in terms of the functional sentence
# perspective, e.g. as a means of de-thematisation / de-topicalisation of the agent and/or
# thematisation of the patient (see e.g. Petr Sgall, 1972). On the other hand, the  proponents
# of the multilevel valency theory ( see e.g. Encyklopedický slovník češtiny, 2002: 118) refer
# (see the next page)
#
#
#
# 1
#
# Present transformational generative grammar of a Chomskian type concentrates
#
# on formal properties and characteristics of passive structures which have not yet been
# in the centre of attention of Czech linguistics.  In the following paper we are going to
# discuss the formal properties of the Czech analytic passive structures in (1b) using the
# contemporary stage of development of the Chomskyan framework.  Our analysis of
# passives is thus also meant to show that even languages with rich inflection and
# relatively free constituent order, like Czech, can successfully be described in terms of
# generative grammar, and that such an analysis can contribute to the development of
# the general linguistic theory as well.
#
# 1  THE DESCRIPTION OF THE PASSIVE STRUCTURES
#
# 1.1  Passive transformation
#
# The traditional analysis (based on the intuitive classical theories) describes the
# distinctions summarised in (2) as the surface distinction in syntactic structure caused
# by the change of the verbal element in (1a/b). In this sense classical grammar
# perceives the formal distinctions between (1a) and (1b) as a kind of transformation,
# though it does not use the terminology.2  The following (3) gives a schematic
# description of such a transformation starting as a structure (1a) and resulting in (1b).3
#
# (3)
#
# Transformation T1
#
# (a)
# (b)
#
# [NP1]NOM – [V1
# [NP2]NOM – [V2
#
# lex]fin – [NP2]ACC        (b)
# be]fin – [V1
#
# lex]part – [NP1]INSTR
#
#
#
# The description of T1 in (3) is obviously neither precise nor full formalisation of all
# possible structures; e.g. it does not cover the cases in which the active variant contains
# a subordinate clause in the position of the ACC constituent. Because clauses are not
# morphologically case marked, the passive variant of this constituent is identical.
#
#
#
# (see previous page)
#
# back to Bohumil Havránek (1928: 15), stating that the main function of passive is to
# influence the propositional hierarchy. This idea dates back to František Daneš (1968) and
# Miroslav Grepl (1973). All the above  authors  take the passive deagentisation for a kind of
# agent backgrounding / anonymising / generalisation. In their view, moreover, the process
# of passivisation results in lowering the level of activity (bringing out a level of stative
# interpretation of the verb). Within Czech linguistics there is no detailed discussion of the
# pragmatic and stylistic aspects of passivisation but it is widely accepted that the passive is
# a multi-functional structure.  Full bibliography of all the studies will be provided at the end
# of Part 2.
#
# 2   The term transformation is used in this section only with a general meaning of ‘structural
#
# change’, because it is exactly the theoretical concept of transformation which
# differentiates many analyses of the passive structures. In section 2.2 we are going to define
# the notion of transformation with respect to the framework used in our analysis.
#
# 3   The features of verbal tense and agreement are described only schematically in (3). For a
#
# detailed discussion of the  morphology of V1 and V2 in (3) see section 1.5.4.
#
#
#
# 2
#
# We are also going to ignore all the possible changes in the linear order, one of
#
# which is illustrated in (4).
#
# (4)
#
#
# (a)
#
#
# Petr         sliboval   Pavlovi,  že    přijde    (b)
# PeterNOM promised  PaulDAT  that arrives3SM  (b)
# ‘Peter promised to Paul that he arrives.’
#
# (b)
#
#
#
#
# Pavlovi bylo slibováno (Petrem),     že   přijde
# PaulDAT was promised  (PeterINSTR) that arrives3SN
# ‘It was promised to Peter (by Paul) that he arrives.’
#
#
# Nor does the transformation T1  in (3)  reflect the cases like (5), with an additional
# infinitive,  or (6), in which the active variant (a) contains (apart from NPNOM and
# NPACC) another NP or prepositional phrase PP.  The case of such additional NP or NP
# within PP remains unchanged in the passive structures in (b).4
#
# (5)
#
#
# Petr         nutil   Pavla     k  odchodu
# PeterNOM forced PaulACC to leave
#
# ‘Peter forced Paul to leave.’
#
#  (b)
#  (b)
#
# (a)
#
#
#
#
#
#
#
# (6)
#
#
#
# (b)
#
#
#
# (a)
#
#
#
# Pavel     byl    nucen (Petrem)      k  odchodu
# PaulNOM was forced  (PeterINSTR) to leave
# ‘Paul was forced to leave.’
#
# Petr         sliboval   Pavlovi  žvýkačku
# PeterNOM promised PaulDAT chewing-gumACC
# ‘Peter promised a chewing gum to Paul.’
#
#
#
#  (b)
#  (b)
#
# (b)
#
#
#
#
# žvýkačka               byla slibována (Petrem)      Pavlovi
# chewing-gumNOM was  promised  (PeterINSTR) PaulDAT
# ‘The chewing gum was promised to Paul by Peter.’
#
#
#
#
# Importantly, the trivial formalisation of T1 in  (3) is not able to capture the process in
# which the active variant  does not contain a transitive verb and some kind of process
# of passivisation still takes place. The examples of the so called impersonal passive in
# (7) and (8) have verbs selecting at least one complement in some some other than
# nominative/Accusative case, i.e. NPGEN/DAT/INSTR in Czech or PP .5
#
#  (7)
#
# (a)   Učitel           nadržuje   děvčatům    (b)
#
# teacherNOM favours3SM  girlsDAT     (b)
# ‘The teacher favours girls.’
#
#
#
#
# (b)
#
# Je    nadržováno děvčatům (učitelem)
# is3S favoured3SN  girlsDAT     (teacherINSTR)
#
#
#
# 4   Similar examples are discussed here in section 5.4 below.
# 5   For more detailed analysis of the impersonal passive see section 6.2 below.
#
#
#
# 3
#
#
#
# ‘Girls are favoured (by the teacher).’
#
#
# (8)
#
#
#
#
#
# (a)
#
#
#
# (b)
#
#
# Členové         hlasují   o      stanovách    (b)
# membersNOM vote3P   about statutesLOC    (b)
# ‘The members vote about the statutes’
#
# Je   hlasováno  o       stanovách  (členy).
# is3S voted3SN    about statusesLOC (membersINSTR)
# ‘The statutes are  voted about (by the members).’
#
#
#
#
#
#
# To capture the examples (7)/(8) we introduce a description of a transformation T2 in
# (9) where the label [NP]OBL markes  [NP]GEN/DAT/INSTR.
#
# (9)
#
# Transformation T2
#
# (a)
# (b)
#
#
# [NP1]NOM – [V1
# [NP1]INSTR– [V2
#
# lex]fin – [NP2]OBL / PP      (b)
# be]fin – [V1
# lex]part – [NP2]OBL / PP
#
#
#
# In the partial transformation T2 the NPNOM constituent in (a)  behaves like in (T1) – i.e.
# it becomes NPINSTR in (b). The NPOBL or PP in (a), however, remains unchanged and
# the unmarked word order remains unchanged, too.6
#
# 1.2  Some Problems of the Notation
#
# The formalisation of transformations T1  and T2 in (3) and (9) signal the need for
# double valency of the active verb. This requirement seems to be supported by the
# examples in (10) which demonstrate that a verb without an external (left-side)
# Argument  cannot have a passive counterpart (impersonal T2)  in Czech.
#
# (10)
#
# Petrovi   pomalu otrnuje    (b)
# PeterDAT slowly   forgets3SN    (b)
# ‘Peter has slowly forgotten about the pain.’
#
#
#
# (a)
#
#
#
# (b)
#
#
#
# * Je     pomalu otrnováno    Petrovi
# * is3SN slowly   forgotten3SN PeterDAT
#
#
#
#
# The following example (11) demonstrates the impossibility of  transformations T1 /T2
# with verbs which do not have any internal (right-side) Argument NP or PP. Notice
# that although the verb can have an adverbial adjunct, contrary to (7) and (8) the
# transformation T2 cannot take place either.
#
# (11)
#
# Petr spí  (v posteli)
#
#  (b)
#
# (a)
#
#
#
#
#
# 6   The transformation  T1 and  T2 are distinct also with respect to the verbal morphology
#
# showing the agreement with subject (AGR). While the passive structures arising according
# to  T1  have an overt surface subject and this subject is reflected by verbal morphology, the
# passive structures arising via  T2  do not seem to be able to have any overt subject, and the
# verbal morphology signals a default 3rd person singular neuter.
#
#
#
# 4
#
#
#
#
#
#
# PeterNOM sleeps (in bed).   (b)
# ’Peter sleeps in bed.’
#
# (b)
#
#
# *(Petrem)     je   spáno     v  posteli.
# *(PeterINSTR) is3S slept3SN in bed.
#
#
#
#
# The distinction between subcategorised vs. free complements of the verb, which
# seems to be the reason for the distinction between (7)/(8) and (11), is not expressed in
# the description of the transformation T2 in (9).7
#
# Thus  the formalisations of the passive transformation T1 / T2 in (3) / (9) are far
#
# from ideal representations of the relevant language process. On one side it would be
# superior to conflate both of them into one more general formula, but on the other side,
# even in their more detailed form they are not able to capture adequately the
# complexity of the process.
#
# 1.3  Base Structures  of the Passive Transformation
#
# The T1 / T2 formulas cannot either express a number of restrictions on passivisation
# and considering the Czech data, the theoretical nature of transformation is endangered,
# too, especially if it is to be understood as a derivation of some secondary structure (b)
# from a primary/basic/initial structure (a).
#
# However, though it is usually possible to derive the passive (b) from the active
#
# (a), the contrary is more problematic. It is because the active structure must have an
# (Agent) subject, and this is not obligatorily present in the passive (b). The following
# (12) shows again that according to the descriptive transformation T1 in (3) the NPNOM
# subject of (a) becomes NPINSTR  in (b).
#
# (12)
#
# (b)
#
#
#
# Petr         byl   operován dr. Crhou
# PeterNOM was operated   dr.CrhaINSTR
#
#   (a)
#   (a)
#
# (a)
#
# Dr. Crha      operoval Petra
# Dr. CrhaNOM operated PeterACC
#
#
# If the passive structure does not contain the NPINSTR , as is the case in e.g. (13), the
# assumed base (active) structure can be derived only in some general (unmarked/
# default) format with at best some kind of perhaps predictable semantic features.8
#
#
#
# 7   A different selection (a complement vs. adjunct distinction for a specific item) by individual
#
# lexical items within distinct languages (or dialects/idiolects of a language) can result in a
# different level of acceptability of (11b). As the following example shows, its English
# translation is grammatical.
# (i)  Peter slept in a bed.   A bed was slept in (by Peter).
#
# 8   The morphology on active verb has to be marked for some generic subject in any case, in
# (13) we use the generic 3rdplural[+HUMAN].  Notice, moreover, that with some idiomatic
# passive sentences the active counterparts with non-metaphorical reading cannot be
# logically reconstructed.
# (i)    Blbci jsou rovnoměrně rozeseti po celém světě     ??  rozesel    blbce po celém světě
# idiots are equally spread over whole world    ?? spread idiots over whole world
# (see the next page)
#
#
#
#
#
# 5
#
# (13)
#
# (b)
#
# Petr         byl  operován včera     (a)
# PeterNOM was operated   yesterday
#   (a)
#
# (a)
#
# Včera        operovali            Petra
# yesterday operated3P[+HUM?] PeterACC
# ‘Yesterday they operated on Peter.’
#
# 1.3.1 Active and Passive Verb Forms
#
#
#
#
#
#
#
#
#
# Still, if relation between sentences (1a) and (1b) in the descriptive transformation T1 in
# (3) is understood as a mechanical algorithm, each passive structure has to have some
# perhaps only formal active counterpart. This is not true in Czech either. Compare the
# following examples in (14) and (15),  which demonstrate Czech verbal morphology
# used to express a complex of temporal features in combination with the features of
# aspect. (14) gives a full paradigm of the imperfective [-PERF] verb chválit ‘to praise’
# in which each tense has its active and passive forms.
#
# (14)       chválit (‘to praise’) = [-PERF]
#
#
#
# Petr        chválí         Pavla
# PeterNOM praisesPRES PaulACC
# ‘Peter praises Paul.’
#
#
#    
#
# (a’)
#
#
#
# Pavel     je       chválen Petrem
# PaulNOM isPRES praised  PeterINSTR
# ‘Paul is praised by Peter.’
#
# Petr        chválil        Pavla
# PeterNOM praisedPAST PaulACC
#
#    
#
# (b’)  Pavel    byl         chválen Petrem
#
#
# PaulNOM wasPAST praised PeterINSTR
#
# (a)
#
# (b)
#
#
# (c)
#
# Petr        bude     chválit Pavla     (c’)
# PeterNOM willFUT praise PaulACC
#
#
#
#
# Pavel     bude  chválen Petrem
# PaulNOM beFUT praised  PeterINSTR
#
#
# The examples in (15) show the same active vs. passive couples for the [+PERF]ective
# pochválit ‘to have praised’. As schematically demonstrated in(15a) Czech perfective
# verbs do not have a present tense.9  The Czech finite AUX (used to form the analytic
# passive), however, is not perfective, and it can have a full paradigma of three tenses,
# including the present. Given this, the Czech passive sentences with a perfective verb
# as in (15a) have no active counterpart which could be taken for a base structure
# (15a) for the transformation T1. Alternatively, the process of passivisation is to be
# redefined or deprived of the ability to refer to temporal and aspectual features.
#
# (15)     pochválit (‘to have praised’) = [+PERF]
#
#
#
# (a)
#
# *Petr     pochvál-??    Pavla    
# *PeterNOM praisePRES
# ‘Peter praises Paul.’
#
#   PaulACC
#
#
# Pavel      je pochválen Petrem
# PaulNOM isPRES praised PeterINSTR
# ‘Paul is praised by Peter.’
#
#
#
# (see previous page)
#       ‘Idiots are equally spread all over the world.’
#
#
#
# 6
#
# (b)
#
# (c)
#
# Petr         pochválil   Pavla   
# PeterNOM praisedPAST PaulACC
#
# Pavel       byl pochválen   Petrem
# PaulNOM  wasPAST praised PeterINSTR
#
# Petr        pochválí  Pavla   
# PeterNOM praiseFUT PaulACC
#
#
#
# Pavel     bude pochválen Petrem
# PaulNOM beFUT praised  PeterINSTR
#
#
# Traditional grammar takes the structures in (14) or (15) for parallel structures,
# considering that the verbal forms differ in one grammatical category, namely the
# category of voice: the (a/b/c) forms in the left column, i.e. chválím, chválíš… (’I
# praise’ ’you praise’...) express an active voice and jsem chválen, jsi chválen… (’I am
# praised’, ’you are praised’...) in () express a passive voice.10
#
# It is probably also the parallelism between the structures in (14)/(15) that
#
# suggest taking voice for a morphological category of verb. Apart from that, however,
# the reason for this concept is the analogy rooted in Latin classical tradition, i.e. it is
# based on the following deduction:
#
#
# (16)(a)  The semantic anf functional relation between the Czech expressions chválím /
#
# jsem chválen (’I praise’ / ’I am praised’) is the same as the relation between the
# Latin laudo / laudor;
#
#     (b)  one member of the couple, namely  the active Czech chválím and Latin laudo
#
# are formed with a bound morpheme;
# the Latin passive laudor is also formed by a suffix, and therefore the Czech
# passive  jsem chválen must be a kind of morphological form (affix), too.
#
#       (c)
#
#
#
# This approach, however, results in some problems even within the traditional
# framework. In the following sections we are going to mention some properties of the
# Czech ’passive voice’ which make this verbal form special and distinct from the other
# parts of the Czech verbal paradigms.11
#
#
# (see previous page)
# 9   The Czech verbal morphology does not have a present for perfectives because as
#
# demonstrated in (14a) compared with (15c), the present tense morphology of [-PERF] is
# interpreted as a future with [+PERF].
#
# 10   We are not going to discuss the complete active and passive paradigms including the
#
# oppositions differing in Tense feature, i.e. chválil bych (‘would praise”) and  byl bych
# chválen (‘would have praised”), imperatives chval (‘praise!”) vs. buď chválen (‘be
# praised!”), and infinitives chválit (‘to praise”) vs.  být chválen (‘to be praised”); such
# discussion would make the material complex without  changing anything in our analysis.
# 11   As for the appropriate morphological form of the passive verb in Czech, the results (b) of
#
# the passive transformations T1 and T2  applied to (a) seem to be similar to (c).
# (a)  Zedníci v   opravují školu 
# Škola        je opravována zedníky
# SchoolNOM is repaired      masonsINSTR
# MasonsNOM repair   schoolACC
#
# Škola         se        opravuje
# SchoolNOM REFL  repairs3S
# Bylo     hlasováno o        zákonu poslanci
# (It) was woted3SN   about law      MPsINSTR
# Hlasovalo     se       o        zákonu.
# (It) woted3SN REFL about law
#
# (a)  Poslanci hlasovali o zákonu   (b)
#
# MPsNOM  woted   about law
#
# (b)
#
# (c)
#
#
#
# (c)
#
# (see the next page)
#
# 7
#
#
#
#
#
# The decision whether the so called passive form jsem chválen (’I am praised’)
#
# really is a morphological variant of a given verb (as is postulated by traditional
# grammar) should be based on an analysis of the whole complex of the verbal
# paradigm.
#
# 1.4  Considering the Verbal Paradigm
#
# In his thorough discussion of the verbal system in Czech František Kopečný
# (1962: 95) analysed the analytical past tense as a ‘morphologically analytic form’
# (MAF), claiming that the past verbal form chválil jsem (‘I praised’) - though it
# superficially consists of two morphemes - [AUX+past participle] - is in fact a simple
# (synthetic) verbal form. In the following sections we accept his arguments together
# with his terminology for this form. However, for the Czech analytic passive we are
# going to use the term ‘analytic form’ (AF), foreseeing thus our conclusion resulting
# from a thorough comparison of past and passive forms.
#
# chválen (‘I am praised’) and the past chválil jsem (‘I praised’) is that both the forms
# consist of two discrete verbal elements: first, a form of an auxiliary být (‘be’) and,
# second, a participle of  a lexical verb.12 This general similarity, however, proves to be
# the only characteristic which a careful comparison of the Czech analytic past and
# passive forms can substantiate/ justify. In the following sections  we are going to
# demonstrate a number of widely known tests which show that the two forms deserve
# distinct analyses.
#
# The initial observation one can make comparing the analytic passive jsem
#
# 1.4.1 The Participles following the Auxiliaries
#
# The distinctions between the Czech past morphological analytic form (MAF)
# and the passive analytic form (AF) are signalled already by a distinction between the
# participles. The past MAF consists of the AUX and L-Participle (active participle13),
# while the passive AF uses the Passive Participle is formed from the infinitival stem
# with the consonant -n-/-t- followed by a gender agreement morphology.14
#
#
#
# (see previous page)
#
# Traditional grammars call (c) the reflexive passive. Comparing (b) and (c), however, one
# can show many syntactic properties which make the so called reflexive passive distinct
# from the analytic passive (see e.g. Karlík, 2003). Therefore we are not going to discuss the
# reflexive passive here.
#
# 12  In his detailed typological study Edward Keenan (1985) shows that a periphrastic
#
# (analytic) passive in all Indo-European languages contains an auxiliary which is identical,
# or similar, to the auxiliary used to form a past Tense.
#
# 13   The Czech L-Participle is formed from the infinitival stem with the consonant -l- followed
#
# by a gender agreement morphology. It originated in Old Slavic as a deverbal adjective and
# it combined with a copula to form nominal predicates. (See also Rudolf Růžička (1963)).
# Synchronically, this L-participle is used in Czech to form the analytic past, conditional and
# past conditional.
#
# 14   In this section we provide a brief comparison of the  L- and Passive Participles. For a
#
# detailed discussion of the latter see below in sections 5 and 7.
#
#
#
# 8
#
# A natural distinction between the verbal complexes comprising the participial
#
# components concerns transitivity. The L-Participles (forming the non-finite
# component of the past MAF) are both transitive (allowing a complement with
# structural ACC) and intransitive. On the other hand, the Passive Participles (see also
# examples (7) and (8) above) are formed from verbs which cannot have an ACC
# complement.15
#
# (17)
#
#
#
# Já      jsem    chváli-l-a Marii        (b)  Marie        je   chvále-n-a
# INOM AUX1S praised   MaryACC
# ‘I praised Mary.’
#
# MaryNOM  is3FS  praised
# ‘Mary was praiased.’
#
# (a)
#
#
#
#
#
#
#
#
#
#
#
#
# (c)
#
# Já      jsem    spa-l-a.
# INOM AUX1S  slept
#
# ‘I slept.’
#
#        (d)
#
#
#
#
# *Bylo spá-n-o.
# .*It was slept
#
#
# Apart from transitivity, the Czech past MAF is formed relatively regularly from all
# verbs, while the passive participle is often idiosyncratic, and its productivity is also
# restricted by some other factors.  As for syntactic characteristics, the following
# examples of ungrammatical co-ordinations in (18b/c) indicate that there can be even a
# categorial distinction between the participles.
#
# (18)
#
#
#
# Já  jsem     šel      a     já  jsem      byl unaven.
# I    AUX1S  went  and  I    AUX1S  was tired.
# ’I went and I was tired.’
#
# (a)
#
#
#
# (b)
#
# (c)
#
#
# *Já   jsem     šel     a    byl  unaven.
# * I    AUX1S  went and was tired
#
# *Já jsem    byl unaven a     přece šel.
# * I  AUX1S was tired   and still    went
# ?? ‘I was tired and still going.’
#
#
#
#
#
# Assuming the generally accepted principle that coordination requires like constituents,
# these examples strongly suggest that the two kinds of participles do not share their
# category.
#
#
#
# 15   With the exception of some few Czech verbs with double Accusatives. Passivisation usually
# shows which Accusative is a structural and which is a kind of a quirky Case used possibly
# as a result of some lexical-semantic fusion – as in the following example a fusion of a
# ‘teach-learn’ verb.
# (i) Petr         učil     Marii matematiku  
#      PeterNOM taught MaryACC mathACC   
#
# Marie byla učena matematiku.
# MaryNOM was taught mathACC
# ‘Mary was taught math.’
#
#
#           ‘Peter taught Mary math.’
#
# (b)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# (c)
#
#
# *Matematika byla učena Marii.
# *MathNOM was taught MaryACC.
#
# 9
#
# 1.5  The Distinction between the Auxiliaries in Analytic Past and Passive
#
# The main distinction between the verbal complexes of the Czech analytic past
#
# and passive is based on the comparison of the AUX components. If both complexes
# were paradigmatic forms of a verb, the AUX would have to be analysed as free
# grammatical morpheme equivalent to e.g. the bound verbal morphology. However, in
# this section we are going to demonstrate that the AUX components of the analytic past
# and passive are far from being the same, in spite of the fact that they are both forms of
# the verb být (’be’) and in most contexts they have identical form.16
#
# 1.5.1 Clitic Position
#
# The finite form of the Czech auxiliary být (’be’) in the past ‘morphologically
#
# analytic form’ (MAF) is a clitic, while the finite form of the auxiliary být (’be’) in the
# passive ‘analytic form’ (AF) is not. The example (19a/ii) illustrate that the past MAF
# is ungrammatical in the sentence initial position which is unavailable for the Czech C2
# clitics but acceptable for the passive AUX být (’be’) in (19b/ii).17
#
# (19)
#
#
#
# Chválil     / unavil         jsem    Petra
# (I) Praised/Exhausted AUX1S PeterACC
# ‘I praised/exhausted Peter.’
#
# (a)
#
#
#
# (i)
#
#
#
#
#
#
#
#
#
#
#
#
# (b)
#
#
#
# (ii)
#
#
# (i)
#
#
#
#  *Jsem  chválil / unavil       Petra.
#  AUX1S praised/exhausted PeterACC
#
# Chválen/Unavený/Studentem/Doma      jsem  stále.
# Praised /Tired     /Student      /At home  AM1S allways
# ‘I am always praised/ tired/a student/ at home.’
#
#
#
#
#
# (ii)
#
#
#
# Jsem   stále   chválen/unavený/studentem/doma.
# AM1S always praised/tired/student/at home
# ‘I am always praised/ tired/ a student/ at home.’
#
#
#
#
#
# Apart from the passive participle chválen (’praised’),  (19b) provides examples of a
# Czech adjective predicate unavený (’tired’), a nominal predicate  studentem (’student’)
# and an Adv/PP doma (’at home’) to demonstrate that with respect to the observed
# criterion the finite auxiliary of the passive behaves exactly like the copula/existential
# verb být (’be’).
#
#
#
# 16   Some of the diagnostics used in the following sections are  used already in Kopečný (1962)
#
# and the works inspired by him, e.g. Miroslav Komárek (1978: 106). In a generative
# framework a detailed discussion of these properties appears in Jindřich Toman (1980) or
# Ludmila Veselovská (1995, Chapter 4).
#
# 17 Descriptive characteristics of various types of clitics (including Czech) can be found in e.g.
# Voss & Veselovská (1998) or Franks & King (2000). For more discussion concerning the
# initial position see also Toman (2000) who discusses apparent exceptions from the
# obligatory pattern.
#
#
#
# 10
#
# 1.5.2 Clitic Reduction
#
# Another property of Czech clitics is their tendency to become phonetically reduced
# and to ‘lean’ (cliticise) on some phonetically prominent element. The following
# example (20) shows that the 2nd person singular form, i.e. jsi (‘are2S’), can be reduced
# to a kind of bound morpheme –s, which can appear on several hosts.
#
# (20)
#
#
#
# Proč  jsi        často chválil  Petra?
# Why AUX2S often   praised PeterACC
# ‘Why did you often praise Peter?’
#
# (a)
#
#
#
#
#
# (b)
#
#
# (c)
# (d)
#
# Proč-s           často chválil Petra?
# Why-AUX2S often   praised PeterACC
#
# Proč často-s chválil Petra?
# Proč často chválil-s Petra?
#
#
# In the above example (20), the AUX was a part of the past MAF. A contrasting (21)
# shows that the same reduction is impossible with the AUX is a component of the
# passive AF.
#
# (21)
#
#
#
#
# Proč  jsi        často chválen/unavený/studentem/doma?
# Why AUX2S often   praised/ tired/ student/ at home
# ‘Why are you often praised/ tired/ a student/ at home?’
#
#
# (a)
#
#
#
# (b)
#
# (c)
# (d)
#
# `
#
# * Proč-s        často chválen/unavený/studentem/doma?
# Why-AUX2S often  praised/ tired/ student/ at home
#
# * Proč často-s chválen/unavený/studentem/doma?
# * Proč často chválen/unavený/studentem/doma -s?
#
# 1.5.3 Colloquial/Dialectal Forms and Zero Morphemes
#
# The distinctions between the AUXs of the past MAF and passive AT include also the
# formal realisation of the paradigm. In  standard Czech, the AUX of the passive AF
# contains an initial prothetic consonant j-.18  The forms without the consonant are
# taken for secondary / colloquial / restricted to certain contexts (e.g. negation).On the
# other hand, with the AUX of past MAF the form without this initial consonant j- is
# taken as standard and the forms with j- are secondary / influenced by spelling (see
# Komárek (1978: 105)).
#
# The acceptable varieties are listed in (22). Apart from the initial prothetic
# consonant j-, notice that in (c) the 3rd singular/plural AUX of past MAF is a zero
#
#
#
# 18   In Old Slavonic the prothetic consonant j- was preposed to the words starting above all
# with an ‘e-’ vowel; compare the Latin est and Czech jest (‘to be’). The process reflects a
# tendency for alternating syllabic sonority (a CV-CV pattern) in Old Slavic: prothetic
# consonants were inserted to prevent hiatic structures  from becoming a part of the
# following words.
#
#
#
# 11
#
# morpheme, while the AUX of the passive AF in (c’) must have an overt form je/jsou
# (‘is3S/P ‘) identical with the forms of the copula/existential be.
#
# (22)   Standard/primary j- and secondary/colloquial (j-) / Zero AUX3S
#
#            Past MAF: (j-), Ø3
#
#          Passive AF: j-, *Ø3
#
# (a)
#
# (b)
#
# Já (j)sem  chválil.
# I   AUX1S praised
# ‘I praised.’
#
# Ty (j)si  chválil.
# You AUX2S praised
# ‘You  praised.’
#
# (c)  On *je/Ø chválil.
# He AUX3S praised
# ‘He praised.’
#
# (a’)  Já jsem  chválen.
# I   AUX1S praised
# ‘I am praised.’
#
# (b’)  Ty jsi chválen.
#
# You AUX2S praised
# ‘You are praised.’
#
# (c’)  On je/*Ø chválen.
# he AUX3S praised
# ‘He is praised.’
#
#
# The following (23b) recalls the possibility of reduction mentioned in the preceding
# section 1.5.2. (23a/c) moreover demonstrate that in those cases where reduction is not
# possible, Moravian dialects use a distinct class of agreement morphology for the
# passive AUX1/2S and copula/existential být (’be’): su (‘am1S’), seš (‘are2S’). The
# examples in the left column show that these dialectal forms are never used with the
# AUX1/2S of a past MAF.19
#
# (23)   Moravian dialectal forms of být (’be’)
#
# Past morphological analytic form   Passive analytic form  (+copula/existential be)
#
# (a)
#
# (b)
#
# (c)
#
# Já jsem/*(j)su chválil
# I   AUX1S        praised
# ‘I praised’
#
# Ty-s               chválil
# you+AUX2S  praised
# ‘You praised’
#
# Ty  jsi/*seš chválil
# you AUX2S praised
# ‘You praised’
#
# (a’)  Já (j)su chválen  / -zlý / -studentem / -doma
#
# I   AUX1S praised /-nasty /-a student /-at home
# ‘I am praised/nasty/a student/at home.’
#
# (b’)  *Ty-s             chválen/ -zlý / -studentem / -doma
#
# *you+AUX2S praised/-nasty /-a student /-at home
# ‘You are  praised/nasty/a student/at home’
#
# (c’)  Ty   seš       chválen / -zlý/ -studentem / -doma
#
# you AUX2S praised /-nasty/-a student /-at home
# ‘You are praised/nasty/a student/at home’
#
#
# In the following examples (24)(a/b) illustrate that Czech is a pro-drop language and
# can thus drop the personal pronoun. (24)(c) shows that in 1st singular, the presence of
# the personal pronoun is able to compensate for the absence of the AUX1S of past
# MAF. The examples on the right give the analogical passive AF forms demonstrating
#
#
#
# 19   Whenever possible in this section, we are going to use the copula/existential ‘be’ together
# with the passive AUX, to demonstrate that with respect to the chosen criteria passive AUX
# (and not the past AUX) patterns together with the more lexical forms.
#
#
#
# 12
#
# in (24)(c’) that the complementarity of AUX1S and personal pronoun does not apply
# with the AF. 20
#
# (24)   AUX / pronoun complementarity
#
# Past morphological analytic form
#
# Passive analytic form
#
#
# (a)
#
# (b)
#
# (c)
#
# Já jsem     chválil Petra
# I   AUX1S praised Peter
# ’I praised Peter.’
#
# Chválil  jsem    Petra
# praised AUX1S Peter
#
# Já chválil Petra
# I    praised Peter
#
# 1.5.4 Morphological Paradigm
#
# (a’)
#
# Já  jsem   chválen od Petra
# I   AUX1S praised by Peter
# ’I am praised by Peter.’
#
# (b’)  Chválen jsem od Petra
# praised AUX1S by Peter
#
# (c’)
#
# *Já chválen od Petra
# *I   praised  by Peter
#
# The following example (25a/b/c) demonstrates that the morphological paradigm of
# AUX in the Czech past MAF (i.e. in combination with the past L-participle) is
# reduced to unmarked present morphology. On the other hand, the finite AUX of the
# passive AF (as well as the copula/existential být ‘be’) can be used in the imperative
# (25a’), the infinitive (25b’) and the future form budu (‘will-be’) (25c’).
#
# (25)
#
# Imperative / Infinitive / Future of AUX být (’be’)
#
# Past morphological analytic form             Passive analytic form  (+copula/existential be)
#
# IMP   (a)   *Chválil buď!
# *praised AUXIMP
#
# (a’)  Chválen buď!
# praised AUXIMP
# ’Be praised!’
#
# INF
#
# (b)  *(Musel) být chválil.
#
# (b’)  (Musel) být      chválen/-zlý/-studentem/-doma.
#
# *(had to)AUXINF praised
#
# (had to) AUXINF praised /-nasty /-a student /-at home
# ’He had to be praised.’
#
# FUT  (c)  *Já budu chválil.
#
# (c’)  Já budu      chválen/-zlý/-studentem/-doma.
#
# *I  AUXFUT  praised
#
# I   AUXFUT  praised /-nasty /-a student /-at home
# ’I will be praised /-tired /-a student /-at home.’
#
# 1.5.5 Iterative Aspect
#
# Another distinction between the two AUXs concerns the morpheme expressing
# progressive aspect. The finite AUX of the Czech passive AF can express progressive
# iteration, as illustrated in (26), by the aspectual suffix -va- on the passive participle
# (26a), as well as on the AUX (26b) or both. The contrasting example (27)
# demonstrates that with the past MAF the aspectual morpheme -va-  can appear only on
# the past participle, i.e. the finite AUX is not able to appear in the progressive form.
#
#
#
# 20 Why this can happen only in the 1st singular form is unknown to us.
#
#
#
# 13
#
# (26)
#
#
#
#
#
#
#
# (27)
#
#
#
#
#
# (a)
#
#
#
# (b)
#
#
#
# (a)
#
#
#
# (b)
#
# Já jsem     chválen   /chválí-vá-n
# I   AUX1S  praised    /praisedPROG
# ‘I am praised (repeatedly).’
#
#
#
#
#
# Já bý-vá-m       chválen  /chválí-vá-n.
# I   AUXPROG/1S praised   /  praised PROG
# ‘I am being praised (repeatedly).’
#
# Já jsem      chválil   /chválí-va-l
# I   AUX1S   praised    /praisedPROG
#
# ‘I praised / was repeatedly praising.’
#
#
#
# *Já bý-vá-m       chválil  /chválí-va-l
# *I   AUXPROG/1S praised   /  praised PROG
#
# 1.5.6 Negation
#
# Another clear distinction between the past and passive finite AUXs  can be found in
# their distinct combinations for expressing negation. In Czech the sentence negation is
# expressed by a negative prefix ne-. As illustrated in (28a), with the past MAF the
# grammatical position of this negative prefix ne- is on the past participle. The
# contrasting (28b) shows that with the passive AF, the sentence negative prefix appears
# on the AUX.21
#
# (28)
#
#
#
# Já jsem     ne-chválil
# I   AUX1S  not-praised
# ‘I did not praise.’
#
# *Já ne-jsem      chválil
# *I    not-AUX1S praised
#
# (a)
#
#
#
# (a’)
#
#
# (b)
#
#
#
#
# Já  ne-jsem      chválen/-unavený/-student/-doma.
# I    not-AUX1S praised /-tired /-a student /-at home
# ‘I am not praised /-tired /-a student /-at home
#
# 1.5.7 Ellipsis
#
# The ability to carry a negative prefix (and perhaps also the clitic characteristics) seem
# to be a source of another distinction between the AUXs. The following example (29a)
# shows that in short answers the AUX of the passive AF can replace the whole verbal
# complex (while  the passive participle cannot). In  the parallel (29b) the AUX of the
# past MAF is illustrated as ungrammatical and the shortest possible answer contains the
# L-participle.22
#
# (29)
#
# (a)
#
#
#
# Jsi        chválen často?
# AUX2S praised often?
# ‘Are you praised often?
#
# - Ano, jsem.   / *Ano, chválen.
# - Yes, AUX1S / *Yes, praisedSM.
# - Yes, I am.’
#
#
#
#
#
#
#
# 21 For the possibility of negating the passive participles see section 7.1.5 below.
# 22 The feature distribution between their AUX and participle components is  identical with
# past  MAF and passive AF. The verbal agreement features are therefore  not crucial for
#
# (see the next page)
#
#
#
# 14
#
# (b)
#
#
#
# Chválil   jsi       Petra?
# Praised AUX2S PeterACC?
# ‘Did you praise Peter?
#
# - *Ano, jsem.     / Ano, chválil.
# - *Yes, AUX1S. / Yes, praisedSM.
# - Yes, I did.’
#
#
#
#
# 1.5.8 A Conclusion based on the Comparison of the Auxiliaries and Participles
#
# The above sections demonstrated a number of distinctions between the AUXs
# involved in forming the past and passive verbal complexes. By all the criteria applied,
# the Czech past AUX showed a higher level of grammaticalisation and lack of
# independence. This past AUX  behaves like a free equivalent of the bound verbal
# morphology - i.e.  it encodes (i) a person-number agreement ending plus (ii) indicative
# characteristics of mood signalled by an initial morpheme (stem) js-. This  feature
# complex is comparable with the feature content of the AUX used to form the Czech
# conditional, as illustrated in  (30). In (30a) we show a past AUX combined with the L-
# Participle to form the past MAF. In (30b)  the same L-Participle combines  with a
# conditional AUX. This conditional AUX signals the combination of (i) agreement
# features together with (ii) conditional morpheme (stem) by-.
#
# (30)
#
#
# (a)
#
#
#
#
# Já by-ch             chválil
# I   AUXCOND-1S praisedL-PRT
# ‘I would praise’
#
# (b)
#
#
#
#
#
# Já js-em       chválil
# I AUXIND-1S praisedL-PRT
# ‘I praised’
#
#
#
#
#
#
#
#
#
# On the other hand, with respect to the tests demonstrated in (19) -(29), the finite AUX
# used to form a Czech passive AF behaved identically with a copula or existential verb
# být (‘be’). In other words, it was repeatedly revealing properties typical for  lexical
# verbs. As for feature characteristics, passive AUX was able to carry the features of (i)
# person/number agreement, (ii) aspect, (iii) tense, (iv) modality.
#
# Given the above clear distinction between the AUX components, it is far from
#
# obvious that the analytic passive represents a kind of verbal paradigm like the analytic
# past tense.  Consequently, if a passive form is not a part of verbal paradigm, the
# analogy in (16c) is incorrect for Czech. Consequently one cannot claim that the
# passive transformation involves only a morphological change within a single (verbal)
# category. The observation stated in (2b) is to be taken more seriously, because the
# properties of the passive AUX demonstrate that the passive structures do contain some
# additional lexical material with respect to their active counterparts.
#
# 2  PASSIVISATION IN TRANSFORMATIONAL GENERATIVE
#
# GRAMMAR
#
# The preceding Section 1 has summarised several imperfections in a traditional
# transformational description and explanation for formating the analytic passive in
# Czech. We mentioned  problems with semantic equivalence and the definition of the
#
#
#
# (see previous page)
#
# grammaticality (in the correct answer in (29b) the participle does not show the features of
# the 1st person singular).
#
#
#
# 15
#
# base (active) structure. Many arguments were presented to demonstrate that active and
# passive verbal forms are not an optional paradigmatic variation in Czech. All those
# data suggest that the passive transformation is not tenable in the form of T1 in (3).
#
# We conclude that, above all, it is not possible to perceive a transformation as a
#
# process which applies a mechanical algorithm (e.g. transformation T1) to an existing
# base structure (a) to derive a new structure (b) using the same lexical repertory and
# with no change of meaning.
# In this paper we want to show an alternative analysis of the Czech analytic passive
# applying a more contemporary concept of transformational process. We want to
# demonstrate that the modern generative framework is able to explain the phenomena
# in more general terms and with a higher degree of explanatory accuracy.
#
# 2.1  Transformational and Lexicalist Theories of Passivisation
#
# A process of passivisation was described as a transformation sui generis in the earlier
# studies by Noam Chomsky (see Chomsky 1957, Chapter 5 and 1965, Chapter 2). In
# the period of the Extended Standard Theory Chomsky divided the original complex
# transformation into two relatively independent processes (see Chomsky, 1972).
# Passive structure was presented as a result of (i) a movement of the active-object NP
# into the position of a passive-subject, and (ii) independent movement of the active-
# subject NP into the position of passive-agent-instrumental PP. 23
#
# Also in the 70s a first influential lexicalist theory arises within a generative
#
# framework represented by a detailed study by Robert Freidin. He discusses above all
# the adjectival properties of passive participles and proposes that active and passive
# verbal forms are independent formatives appearing in the Lexicon (see Freidin, 1975,
# Chapter 2). For Freidin participles are of primarily adjectival character and the
# Lexicon lists them  as a basic form preceding  the related verbal lexemes. Freidin’s
# notion of categorial distinctions, however, is not strict, and he follows Chomsky
# (1970) in allowing lexical items to not in fact always have a full categorial
# specification.  Friedin’s analysis was followed by e.g. Joan Bresnan (1977, 1982) and
# other studies within lexical functional grammar, which does not employ
# transformations at all (e.g. Höhle (1978)).
#
# Lexicalist theories of the passive propose that the active and passive
#
# morphology is already added to the stem in the Lexicon and their projection therefore
# results in autonomous (independent and therefore distinct) syntactic structures. The
# ability of a verb to form a passive, is an information stored in the Lexicon, and there is
# no purely structural restriction on passivisation. In an extreme form such lexicalist
# hypotheses can result in claiming that all the observed similarities between active and
# passive structures are a result of a pure chance.
#
# On the other branch of possible analyses, Freidin’s (1975) lexicalist study was
#
# rejected by e.g. Thomas Wasow  (1977) who provided a number of arguments in
# favour of a transformational approach. This descriptively rich study proposed an
# analysis based on an explicit relation between active and passive structures. The
# author distinguishes between adjectival and verbal passives, provides a wide range of
#
#
#
# 23   In a given period see similar analysis in  e.g. Lakoff and Ross (1976).
#
#
#
# 16
#
# diagnostics to argue for their categorial specificity, and claimes a transformational
# relation only for verbal passives.24
#
# In the following generative era of Government and Binding, Chomsky (see e.g.
#
# Chomsky (1981:48-50)) supplemented his passive transformations (object to subject
# movement and subject to  PPINSTR movement) by a Case Filter, proposing that the
# non-verbal characteristics of passive participles (wrt to ACC Case assignment ) are a
# result of its neutralised verbal character.25
#
# In this period, the transformational theories of the passive assume that in the
#
# process of passivisation the syntactic positions of a base structure are changed and
# consequently also the government relations. The change in government results in the
# change of morphology of the specific lexical items. These analyses usually notice that
# the loss of Argument Θ1 in the passive structure correlates with the loss of a structural
# Accusative case. In elementary form this correlation was stated by Luigi Burzio as
# follows in (31).26
#
# (31)   Burzio’s Generalisation (see Burzio 1986:178-9, 184)
#
# a)  A verb which lacks an external Argument fails to assign Accusative Case.
# b)  A verb which fails to assign Accusative Case fails to theta-mark an
#
# external Argument.
#
# 2.2  Minimalist Transformations
#
# None of the influential contemporary transformational frameworks accept the concept
# of transformation as it was introduced in section 1.1, i.e. as an algorithm expressing a
# linear and morphological change leading from a base (primary, deep) structure to
# some derived (secondary, surface) structure.27 Since the end of the 60s, sentences (1a)
# and (1b) are still taken as related, but the relation is not stated in terms of their mutual
#
#
# 24   Some of Wasow’s diagnostics are going to be applied in this study in sections 4 and 7.3.
# 25   Similar analyses within the G&B framework can be found in e.g. Oswaldo Jaeggli (1986)
# or in the independent study by Paul Postal (1986), who provides a wide range of (English)
# data-based argumentation in favour of the transformational approach.
#
# 26   The possible realisation of the Agent theta role is discussed here in 7.1.3. As for the lack of
#
# Accusative in the passive structures, see  a detailed, cross-linguistic and summarising
# study by Baker, Johnson and Roberts (1989, Chapter 4). The authors claim  that the
# absorption of Accusative is a less general phenomena than the lack of the Agent Theta
# role. We assume that the structural characteristics are language specific and the data are
# obscured by the existence of non-structural quirky Accusatives which are not subject to
# Burzio’s Generalisation (31).
#
# 27   In early Chomskyan grammar the initial (base, kernel) sentence was identified as the
# active structure, alternatively as some active-like semantic structure (see e.g. Charles
# Fillmore, 1968). In the present transformational approach this concept is still possible in
# frameworks referring to the notions of ‘diathesis’, i.e. a mechanism correlating a
# hierarchy of grammatical functions/roles (assuming a subject-object asymmetry) with
# some semantic/thematic hierarchy. Those notions are more frequent in typologically
# oriented studies, for Slavic see e.g. the influential studies by Chrakovski (1974, 1981). For
# Czech a similar concept of transformation is still used in more popular linguistic studies
# and textbooks e.g. Grepl & Karlík (1998) or Příruční mluvnice češtiny (1995).
#
#
#
# 17
#
# relation but in terms of the relation of each of them to some shared more general
# (deeper) structure.
#
# In this study we are going to analyse the passive structures in Czech using the
#
# concept of transformation as it appears in the later period of Principles and
# Parameters, i.e. in the 90s and at the break of the century. From the original
# Government and Binding framework we accept the modular approach to the language
# ...
# The second component of the analytic passive is the passive participle. In
#
# Section 4 we proposed that it is a complex (hybrid) form which consists of two
# categorially distinct parts, namely it is a [AV+A] derivate. In section 4.4.2  we argued
# that the verbal stem V and adjectival suffix A can merge at three distinct levels of
# derivation. The verbal stem is uniformly present in the initial Numeration, but the
# adjectival suffix is a grammatical item and does not need to enter the initial
# Numeration: it can merge with the verbal stem later on, in syntax processing or at PF.
# We proposed that depending on the level of this unification of the complex, the
# resulting three kinds of [AV+A] hybrids will exhibit a number of different predictable
# properties.
#
# As for the passive participle, we proposed that it represents the latest, post-
# syntactic merge of the adjectival head with the verbal stem. The adjectival suffix
# merges with the verbal stem only at the auditory-perception interface, and that is why
# it shows verbal properties both during syntactic processing and at the level of Logical
# Form. In Section 5 we described its derivational process in several levels
# schematically summarised in the following scheme (130).
#
# First the projection of the verbal head V Merges with its internal Argument Θ2
#
# (Patient) creating SPEC(V). Second comes the projection of the head of the light verb
# v* with a strong <+V> feature. The feature of v* is checked by Merging the non-
# thematic AUX být (‘be‘), and this Merge prevents the attraction of V→ v*. The
# resulting structure (a) does not allow generating (merge) of the external Argument Θ1
# (Agent) in a SPEC(v*) and (b) deprives V of its ability to assign structural Accusative.
# The AUX is however able to check the <+V> feature of the finite T and thus license
# the internal Argument Θ2 (Patient) by means of a structural Nominative.100
#
#
#
# 100 In (130) the adjectival suffix (the past participle adjectival morpheme ‘-(e)n/-t)’ is marked
#
# in bold italics. We argue that the suffix is not present during the process of syntactic
# derivation but only at PF, where it has to acquire agreement morphology.
#
#
#
# 78
#
# (130)             Tmax
#
#
# SPEC(T)
# DPNOM
#
#
#
#
#
#
# T0
#
#     TP
#
#
#
#
#
# v*max
#
#                [+D]
#                [+V] SPEC(v*)
#
#
# Argument Θ1
#
#
#
#      v*P
#
#
#
#
#
#
#
#
#
# Pavel
#
#
#                   V max/ A0
#
# v*
#
#
# SPEC(V)
#
#
#         Argument Θ2
#
#            V0 / A0
#
#
#
# by+l
#
#
#
#
#
#
#
#           tby-
#
#
#
#
#
#    tPavel
#
#            V0
#         chvál-
#
# A0
# -en(-Ø)
#
#
#
# Our analysis of the passive shows that the properties of passive structures, namely
#
# Burzio’s Generalisation correlating the lack of Accusative with the lack of an Agent
# Argument Theta role, are in fact both results of the alternative ways a derivation can
# proceed. We argued that the strong <+V> feature of v* can be checked by a V→v*
# movement, which results in projecting an active structure and licensing both internal
# and external Arguments. But the same feature <+V> of v* can alternatively be
# checked by merge of the non-thematic AUX být (‘be’), which results in a passive
# structure with a restricted ability to license Arguments.
#
# The following Sections 6 and 7 have demonstrated in more detail the distinction
#
# between the three kinds of [AV+A] hybrids: (i) post-syntactic derivates (verbal passive
# participles), (ii) syntactic derivates (adjectival passives), and (iii) lexical derivates
# (deverbal adjectives). We demonstrated that these three forms are distinguishable by a
# wide number of properties which reflect a range of distinctions between the categories
# V and A.
#
# We have illustrated that these distinctions among the three structures can be found
#
# in all linguistic levels: In interpretation of the complexes, the meanings range from
# adjectival [+STATE] to a possible verbal [+ACTIVITY] with independent temporal
# and Aspectual frames. At the level of morphology we have demonstrated that different
# types of agreement morpheme signal the derivational level of co-indexation, and so
# does the range of possible verbal agreement morphemes. On the syntactic level the
# distinctions are reflected by distinct distribution and extraction possibilities.
#
# Not all characteristics of the Czech passive structures have been discussed and
#
# properly explained in this paper. We did not address at all e.g. certain restrictions on
# passivisation, distinctions between verbal Theta Roles and semantically related
# Arguments of lexical adjectives or Agent-interpreted Instrumentals. However, our
# paper has proposed a general and uniform approach to a circumscribed phenomenon
#
#
#
# 79
#
# in a contemporary framework which has not been yet sufficiently applied to Czech
# data. We have demonstrated that regardless of the problems resulting from a relatively
# free constituent order in Czech, it is possible to apply general and presumably
# universal morpho-syntactic criteria to the analysis of Czech data and to achieve a
# reasonable level of descriptive and explanatory adequacy.
#
# BIBLIOGRAPHY
#
# AFARLI, TOR  (1992) The Syntax of Norwegian Passive Constructions. John Benjamins
#
# Publishing Company, Amsterdam/Philadelphia.
#
# BABBY, LEONARD (1987) 'Case, Pre-Quantifiers, and discontinuous agreement in Russian.'
#
# Natural Language and Linguistic Theory 5:1987. (91-138)
#
# BAKER, MARK (1985) 'The Mirror Principle and Morphosyntactic  Explanation'. Linguistic
#
# Inquiry 16:1985. (373-416)
#
# ---  (1988) Incorporation. A theory of grammatical function changing. Chicago, University of
#
# Chicago Press.
#
# BAKER, MARK C. & KYLE JOHNSON & IAN ROBERTS  (1989) 'Passive Arguments Raised.'
#
# Linguistic Inquiry 20:1989. (219-251)
#
# BORER, HAGIT & WEXLER KENNETH (1992) 'Bi-Unique Relations and the Maturation of
# Grammatical Principles.' Natural Language and Linguistic Theory 10:92. (147-187).
#
# BORER, HAGIT (1984) Parametric Syntax: Case Studies in Semitic and Romance Languages.
#
# Studies in Generative Grammar. Foris Publications, Dordrecht.
#
# ---  (1993) Parallel Morphology. Manuscript University of Massachusetts at Amherst.
#
# ---  (1997) Parallel Morphology. Seminar  Atelier de Morphologie, Université de Nantes.
#
# BOŠKOVIĆ, ŽELKO (2002) ‘On Multiple Wh-Fronting.”  Linguistic Inquiry 33:351-384.
#
# BRESNAN, JOAN W. (1977) 'Variables in the Theory of Transformations.' In Culicover, P.W.,
#
# Wasow, T., and Akmajian, A.(eds.), Formal Syntax. Academic Press. (157-196) (plus
# comments by Partee)
#
# ---  (1982) Control and complementation. Linguistic Inquiry 13:1982. (97-202) (343-434)
#
# BURZIO, LUIGI (1986) Italian Syntax. D.Reidel Publishing Company.
#
# CHOMSKY, NOAM (1957) Syntactic Structures. The Hague: Mouton.
#
# ---  (1965) Aspects of the Theory of Syntax. Cambridge, Mass., MIT Press.
#
# ---  (1970) ’Remarks on nominalization.’ In: Jacobs, R. – Rosenbaum, P. (eds.), Readings in
#
# English transformational grammar. Waltham/Mass., Ginn and Co. (184-221)
#
# ---  (1972) 'Deep Structure, Surface Structure, and Semantic Interpretation.' In Studies on
#
# Semantics in Generative Grammar. Mouton Publishers, The Hague 1972. (62-119)
#
# ---  (1981) Lectures on Government and Binding. Studies in Generative Grammar. Foris
#
# Publications, Dordrecht.
#
# ---  (1986). Barriers. Cambridge, Mass., MIT Press.
#
# ---  (1995) The Minimalist Program. Cambridge, Mass., MIT Press.
#
# CHRAKOVSKIJ, VLADIMIR. S. (1974) (ed.): Tipologija passivnych konstrukcij (Diatezy i
#
# zalogi). Leningrad.
#
# ---  (1981) (ed.): Zalogovyje konstrukcii v raznostrukiurnych jazykach. Leningrad.
#
# DANEŠ, FRANTIŠEK (1968) ‘Sémantická struktura větného vzorce.’ In: Otázky slovanské
#
# syntaxe II, Brno. (45-49)
#
# DI SCIULLO, ANNE-MARIE – WILLIAMS, EDWIN (1987) On the definition of word. Cambridge,
#
#
#
# 80
#
# Mass., MIT Press.
#
# DRESSLER, WOLFGANG.: Studien zur verbalen Pluralität. Iterativum, Distributivum,
#
# Durativum, Intensivum in der allgemeinen Grammatik, im Lateinischen und Hethitischen.
# Wien, 1968.
#
# EMONDS, JOSEPH E. (2000) Lexicon & Grammar: the English Syntacticon. Mouton de
#
# Gruyter, Berlin.
#
# Encyklopedický slovník češtiny. Praha, Nakladaství Lidové noviny 2002.
#
# FIENGO, ROBERT (1974) Semantic Conditions on Surface Structure. Unpublished doctoral
#
# dissertation MIT, Cambridge, Mass.
#
# FILLMORE, CHARLES (1968) 'Toward a Modern Theory of Case.' In Reibel, D. and Schane, S.
# (ed.), Modern Studies in English. Prentice-Hall, inc., Englewood Cliffs, New Jersey 1969.
# (361-375)
#
# FRANKS, STEVEN & KING TRACY HOLLOWAY (2000) A Handbook of Slavic Clitics. Oxford
#
# University Press.
#
# FRANKS, STEVEN (1995) Parameters of Slavic Morphosyntax. Oxford University Press, New
#
# York Oxford.
#
# FREIDIN, ROBERT (1975) ´The Analysis of Passives.´ Language 51:1975. (385-405)
#
# GREPL, M.IROSLAV – KARLÍK, PETR (1983) Gramatické prostředky hierarchizace sémantické
#
# struktury věty. Brno, UJEP.
#
# ---  (1998) Skladba češtiny. Olomouc, Votobia.
#
# GREPL, MIROSLAV. (1973) ‘Deagentnost a pasivum v slovanských jazycích.’ In: Čs.
#
# přednášky pro VII. mezinárodní sjezd slavistů ve Varšavě, Praha, Academia. (141-149).
#
# GRIMSHAW, JANE (1990) Argument structure. Cambridge, Mass., MIT Press.
#
# HAEGEMANN, LILIANE & GUÉRON, JACQUELINE (1999) English Gramma: A Generative
#
# Perspective. Blackwell, CUP Cambridge.
#
# HALLE, MORRIS A MARANTZ, ALEX (1993) 'Distributed Morphology and the Pieces of
#
# Inflection.' In Hale, K. and Keyser, S.J. (eds.) The View from Building 20. Cambridge,
# Mass., MIT Press. (111-176)
#
# HAVRÁNEK, BOHUMIL (1928) Genera verbi ve slovanských jazycích. Praha, Královská česká
#
# společnost nauk.
#
# HÖHLE, T. (1978) Lexikalistische Syntax: Die Aktiv-Passiv-Relation und andere
#
# Infinitivkonstruktionen im Deutschen. Tübingen, Max Niemeyer Verlag.
#
# JAEGGLI, OSWALDO (1986) Passive. Linguistic Inquiry 17:1986. (587-622)
#
# KARLÍK, PETR  (2003) ’Reflexivum v češtině.’ In Sborník filozofické fakulty Masarykovy
#
# Univerzyity, Masarykova univerzita, Brno.
#
# ---  (2000) ’Hypotéza modifikované valenční teorie.’ Slovo a slovesnost, 61:170-189.
#
# KAYNE, RICHARD S. (1989) 'Facets of Romance Past Participle Agreement,  in P. Beninca,
#
# ed., Dialect Variation and the Theory of Grammar, Foris, Dordrecht. (85-103).
#
# ---  (1994) The Antisymmetry of Syntax. Linguistic Inquiry Monograph 25. Cambridge, Mass.,
#
# MIT Press.
#
# KEENAN, EDWARD (1985) ‘Passive in the World’s Languages.’ In Language Typology and
#
# Syntactic Description I, 243-281. (Ed.) Shopen, T. Cambridge, Cambridge University
# Press. (243-281).
#
# KOMÁREK, MIROSLAV (1978) Příspěvky k české morfologii. Praha, SPN.
#
# KOOPMAN, HILDA & SPORTICHE, DOMINIQUE (1988) Subjects. Ms.  UCLA.
#
# ---  (1991) 'The Position of  Subjects'. In Lingua 85:1991. (211-258)
#
#
#
# 81
#
# KOOPMAN, HILDA (1993) Licensing Heads. Ms. UCLA.
#
# KOPEČNÝ, FRANTIŠEK (1962) Základy české skladby. Praha, SPN.
#
# KOSTA, PETR (2001).: Negace a větná struktura v češtině. In: Hladká, Z. – Karlík, P. (eds.),
#
# Čeština-univerzália  specifika, 3, Brno: Masarykova univerzita. (117-138).
#
# LAKOFF, GEORGE & ROSS, JOHN (1976) 'Is Deep Structure Necessary?’ In Syntax and
#
# Semantics 7, 159-164. (Ed) J. McCawley. New York, Academic Press.
#
# LARSON, RICHARD (1988) 'On the Double Object Construction.' Linguistic Inquiry 19:1988.
#
# (335-391)
#
# ---  (1990) Double Objects Revisited (Reply to Jackendoff) Linguistic Inquiry 21:1990. (589-
#
# 632)
#
# LEFEBVRE, CLAIRE (1988) ‘Past Participle Agreement in French: Agreement = Case.’ In
#
# Advances in Romance Linguistics: Publications in Language Sciences 28, 233-251. (Ed.)
# Biurdsong, D. & Montreuil,
#
# LEVIN, BETH & RAPPAPORT, MALKA (1986) ‘The Formation of Adjectival Passives.’ In
#
# Linguistic Inquiry 17:1986. (623-661)
#
# LIEBER, ROCHELLE (1980) On the Organization of the Lexicon, Unpublished doctoral
#
# dissertation MIT, Cambridge, Mass.
#
# MATEOS, ARANCHA (2000) Unpublished MA Dissretation, University of Durham.
#
# Mluvnice češtiny II. Praha, Academia 1986.
#
# OUHALLA, JAMAL (1991) Functional Categories and Parametric Variation. Routledge,
#
# London.
#
# POLDAUF, IVAN (1940) ‘Podstata anglického pasíva a anglické vazby zájmové účasti.’ In
#
# Časopis pro moderní filologii 26. (358-363)
#
# ---  (1969) ‘The so-called medio-passive in English.’ In Acta Universitatis Carolinae.
#
# Philologica 3,  Prague Studies in English 13. (15-34)
#
# POLLOCK, JEAN-YVES (1989) Verb Movement, Universal Grammar, and the Structure of IP.
#
# Linguistic Inquiry 20:1989. (365-424)
#
# POSTAL, PAUL (1986) Studies of Passive Clauses. Albany: State University of New York
#
# Press.
#
# Příruční mluvnice češtiny. Praha, Nakladatelství Lidové noviny 1995.
#
# RAPP, IRENE (1997) Partizipien und semantische Struktur. Zu passivischen Konstruktionen mit
#
# dem 3. Status. Tübingen, Stauffenburg Verlag.
#
# ROBERTS, IAN (1985) 'Agreement parameters and the development of English modal
#
# auxiliaries.' Natural Language and Linguistic Theory 3:1985. (21-58)
#
# ---  (1991) Verbs and Diachronic Syntax. Dordrecht: Kluwer.
#
# RŮŽIČKA, RUDOLF (1963) Das Syntaktische System der altslawischen Partizipien und sein
#
# Verhältnis zum Griechischen..
#
# SCHOORLEMMER, MAAIKE (1995) Participial Passive and Aspect in Russian. Utrecht:
#
# Onderzoeksinstituut voor Taal en Spraak.
#
# SGALL, PETR (1972) ‘Topic, focus and the ordering of elements of semantic representation.’
#
# Philologica Pragesis, 15:1-14.
#
# SIEGEL, DOROTHY (1973) ‘Nonsources of Unpassives.’ In Syntax and Semantics 2. (Ed.)
#
# Kimball, J. New York: Academic Press.
#
# SPEAS, MARGARET (1990) Phrase Structure in Natural Language. Kluwer, Dordrecht.
#
# ŠTÍCHA, FRANTIŠEK (1984) Utváření a hierarchizace struktury větného znaku. Praha, UK .
#
# TESNIĖRE, LUCIEN (1959) Éléments de syntaxe structurale. Paris.
#
#
#
# 82
#
# TOMAN, JINDŘICH (1980) 'Weak and Strong: Notes on be in Czech.' In Brettschneider, G. and
#
# Lehmann, Ch. (eds.) Wege zur Universalien Forschung, Sprachwwissenschaftliche
# Beitrage zum 60 Geburstag von Hansjacob Seiler. Gynter Narr Verlag Tubingen.
#
# ---  (2000) 'Prosodické spekulace o klitikách v nekanonickch pozicích.' In Hladká, Zdeňka a
#
# Karlík, Petr (ed.) Čeština – univerzália a specifika 2. Brno.
#
# TRAVIS, LISA (1984) Parameters and Effects of Word Order Variation. Unpublished doctoral
#
# dissertation MIT, Cambridge, Mass.
#
# VESELOVSKÁ, LUDMILA (1995) Phrasal Movement and X-Morphology: Word Order
#
# Parallels in Czech and English Nominal and Verbal Projections. PhD diss. Palacký
# University, Olomouc.
#
# ---  (2001a) ‘K analýze českých deverbálních substantiv,' In Hladká & Karlík (eds) Čeština-
#
# univerzália  specifika 3, Masarykova univerzita, Brno. (11-28)
#
# ---  (2001b) ‘Agreement Patterns of Czech Group Nouns and Quantifiers.' In Corver, N. and
#
# Rijemsdijk, H, van (eds.), Semi-Lexical Categories. Studies in Generative Grammar.
# Mouton de Gruyter, Berlin. (273-320)
#
# ---  (2001c) 'Od bariér k minimalismu: Některé aspekty  poslední vývojové změny
#
# chomskyánského modelu jazyka.' Slovo a slovesnost 62:274-292.
#
# ---  (2001d) 'Syntaktické primitivy.' In Acta Universitatis Palackianae Olomucensis, Facultas
#
# Philosophica, Philologica 70:- Anglica II. Universita Palackého, Olomouc. (65-90)
#
# ---  (2002) 'Struktura subjekt-predikátové shody,' In Hladká & Karlík (eds) Čeština-
#
# univerzália  specifika 4, Masarykova univerzita, Brno. (199-212)
#
# ---  (2003) ‘Analytické préteritum a opisné pasivum v češtině:: dvojí způsob saturace silného
# rysu <+V> hlavy v*,' In Sborník filozofické fakulty Masarykovy Univerzyity, Masarykova
# univerzita, Brno. (159-176)
#
# VOS, RIET & VESELOVSKÁ, LUDMILA (1999) 'Clitic Questionnaire.' In Henk van Rijemsdijk
#
# (ed.) Clitics in the Languages of Europe. Mouton de Gruyter , The Hague. (891-1010)
#
# WASOW, THOMAS (1977) 'Transformations and the Lexicon.' In Culicover, P.W., Wasow, T.,
#
# and Akmajian, A.(eds.), Formal Syntax. Academic Press. (327-360)
#
#
#
#
#
# 83
