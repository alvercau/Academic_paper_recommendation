# %%
import pandas as pd
from sklearn.cluster import DBSCAN
from sklearn.externals import joblib
from collections import Counter
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.decomposition import NMF
from pymongo import MongoClient
from sklearn.feature_extraction.text import TfidfVectorizer 
import gensim
from gensim.models import phrases

def to_similarity_matrix(fitted):
    member_list = []
    for doc, topic in enumerate(list(fitted)):
        member_list.append([doc, topic, 1])
    df = pd.DataFrame(member_list, columns = ['doc', 'topic', 'member'])
    return df.pivot_table(df, index=['doc'], columns=['topic']).fillna(0)        

def compute_topic_keyword_correlation(topic_space, keyword_vector):
    sim = to_similarity_matrix(topic_space)
    cs_doc = cosine_similarity(sim)
    cs_key = cosine_similarity(keyword_vector)
    ut_doc = np.triu(cs_doc, k=1).flatten()
    ut_key = np.triu(cs_key, k=1).flatten()
    print(np.corrcoef(ut_doc, ut_key)[0,1])
    
def compute_similarities(doc_pkl, keyword_pkl):
    """ takes doc vectors and keyword vectors, computes cosine similarity and returns pearson correlation 
    between similarities. The higher the correltion, the better the topic model"""
    dtm_doc = joblib.load(doc_pkl)
    dtm_key = joblib.load(keyword_pkl)
    cs_doc = cosine_similarity(dtm_doc)
    cs_key = cosine_similarity(dtm_key)
    # in order to maintain single correlations and eliminate correlations with itself + flatten for calculating pearson
    ut_doc = np.triu(cs_doc, k=1).flatten()
    ut_key = np.triu(cs_key, k=1).flatten()
    return np.corrcoef(ut_doc, ut_key)[0,1]

# %%
dtm_count = joblib.load('countvector.pkl')
dtm_tfidf = joblib.load('tfidf.pkl')
dtm_lda = joblib.load('lda_counts.pkl')
lda_dict = joblib.load('lda_dict.pkl')
count_keywords = joblib.load('countvector_keywords.pkl')
tfidf_keywords = joblib.load('tfidf_keywords.pkl')

# %%
print(compute_similarities('countvector.pkl', 'countvector_keywords.pkl'))
print(compute_similarities('tfidf.pkl', 'tfidf_keywords.pkl'))
# Out:
# 0.612346784837
# 0.408467061703

# %%
client = MongoClient()
db = client.lingbuzz
papers = db.get_collection('papers')
db_with_papers = papers.find({ 'paper': { '$exists': True } })
df = pd.DataFrame(list(papers.find({ 'paper': { '$exists': True } }, {'paper':1, 'title':1, 'keywords':1})))

# %%
indices_to_eliminate = sorted([223, 251, 253, 257, 260, 273, 462], reverse=True)
for index in indices_to_eliminate:
    df.drop(index, inplace=True)
df.head()
# Out:
#                         _id  \
# 0  598b44c407d7df07719383e2
# 1  598b44c407d7df07719383e5
# 2  598b44c407d7df07719383e8
# 3  598b44c407d7df07719383f0
# 4  598b44c407d7df07719383fc
#
#                                             keywords  \
# 0  [czech passives, passive vs. past participles,...
# 1  [czech dp; universal dp, determiners; function...
# 2  [sign language, strong pronouns, pointing, foc...
# 3  [syntax, morphology, extended projections, sel...
# 4  [sluicing, ellipsis licensing, pair-list readi...
#
#                                                paper  \
# 0  ANALYTIC PASSIVES IN CZECH    Ludmila Veselovs...
# 1  UNIVERSAL DP-ANALYSIS IN ARTICLELESS LANGUAGE:...
# 2  Strong Pronominals in ASL and LSF*   Philippe ...
# 3  THE UNIVERSITY OF CHICAGO  INFLECTIONAL DEPEND...
# 4  Multiple Sluicing, Scope, and Superiority: Con...
#
#                                                title
# 0                         Analytic Passives in Czech
# 1  The Universal DP Analysis in Articleless Langu...
# 2             Strong Pronominals ASL and LSF (squib)
# 3  Inflectional Dependencies. A study of complex ...
# 4  Multiple Sluicing, Scope, and Superiority: Con...

# %% [markdown]
# ## 1. DBSCAN

# %%
db = DBSCAN(eps = 0.6, min_samples=2, metric='cosine', algorithm='brute')
fit_db = db.fit_predict(dtm_count)
Counter(fit_db)
# Out:
# Counter({-1: 128, 0: 598, 1: 2, 2: 2, 3: 2, 4: 4, 5: 3, 6: 2, 7: 2})

# %%
compute_topic_keyword_correlation(fit_db, count_keywords)
# Out:
# 0.465488775695

# %%
db2 = DBSCAN(eps = 0.8, min_samples=2, metric='cosine', n_jobs=-1, algorithm='brute')
fit_db2 = db2.fit_predict(dtm_tfidf)
Counter(fit_db2)
# Out:
# Counter({-1: 142,
#          0: 541,
#          1: 9,
#          2: 3,
#          3: 2,
#          4: 3,
#          5: 2,
#          6: 2,
#          7: 3,
#          8: 2,
#          9: 2,
#          10: 6,
#          11: 3,
#          12: 3,
#          13: 3,
#          14: 2,
#          15: 2,
#          16: 2,
#          17: 2,
#          18: 2,
#          19: 3,
#          20: 2,
#          21: 2})

# %%
compute_topic_keyword_correlation(fit_db2, count_keywords)
# Out:
# 0.395949602801

# %% [markdown]
# ## 2. Agglomerative clustering

# %%
hc = AgglomerativeClustering(n_clusters = 4, affinity = 'cosine', linkage='complete')

# %%
fitted = hc.fit_predict(dtm_tfidf.toarray())
Counter(fitted)
# Out:
# Counter({0: 5, 1: 7, 2: 59, 3: 672})

# %%
compute_topic_keyword_correlation(fitted, count_keywords)
# Out:
# 0.58607942071

# %%
fitted2 = hc.fit_predict(dtm_count.toarray())
Counter(fitted2)
# Out:
# Counter({0: 3, 1: 723, 2: 15, 3: 2})

# %%
compute_topic_keyword_correlation(fitted2, count_keywords)
# Out:
# 0.574515079469

# %% [markdown]
# Tfidf gives more balanced topics, but most papers are allocated to the same cluster.

# %% [markdown]
# ## 3. NMF
# 50 topics:

# %%
nmf = NMF(n_components=50)
nmf.fit(dtm_tfidf)
transformed = nmf.transform(dtm_tfidf)

# %%
joblib.dump(transformed, 'nmf.pkl')
# Out:
# ['nmf.pkl']

# %%
nmf = NMF(n_components=20)
nmf.fit(dtm_tfidf)
transformed = nmf.transform(dtm_tfidf)
joblib.dump(transformed, 'nmf_reduced.pkl')
# Out:
# ['nmf_reduced.pkl']

# %%
feature_names = joblib.load('feature_names')

# %%
words = [(i, v) for i, v in enumerate(feature_names)]
for r in nmf.components_:
    a = sorted([(v, i) for i,v in enumerate(r)])[-7:]
    print([words[j[1]] for j in a])
# Out:
# [(19849, 'event'), (49752, 'structure'), (53839, 'unaccusative'), (55733, 'vp'), (10980, 'causative'), (6768, 'argument'), (55101, 'verb')]
# [(40400, 'phonological'), (40433, 'phonology'), (13373, 'consonant'), (49625, 'stress'), (56919, 'word'), (50586, 'syllable'), (55706, 'vowel')]
# [(26023, 'icelandic'), (36912, 'nom'), (22672, 'genitive'), (14936, 'dative'), (4695, 'accusative'), (36986, 'nominative'), (10807, 'case')]
# [(48954, 'spell'), (24564, 'head'), (34229, 'merge'), (55733, 'vp'), (54675, 'v'), (35313, 'movement'), (40270, 'phase')]
# [(49752, 'structure'), (21583, 'form'), (12972, 'compound'), (55101, 'verb'), (41771, 'prefix'), (36959, 'nominal'), (45615, 'root')]
# [(8053, 'bantu'), (5341, 'agreement'), (35782, 'n'), (23427, 'grammatical_gender'), (37332, 'noun'), (20921, 'feature'), (22581, 'gender')]
# [(54545, 'use'), (25649, 'human'), (31972, 'linguistic'), (31268, 'learner'), (34806, 'model'), (4785, 'acquisition'), (11438, 'child')]
# [(41231, 'position'), (37522, 'null_subject'), (42186, 'pro'), (19079, 'ep'), (13634, 'control'), (42487, 'pronoun'), (49956, 'subject')]
# [(33983, 'meaning'), (41697, 'predicate'), (57141, 'x'), (47163, 'sentence'), (19849, 'event'), (59918, '∧'), (47048, 'semantic')]
# [(46607, 'scope'), (36338, 'negative'), (37422, 'npi'), (37426, 'npis'), (36298, 'neg'), (34794, 'modal'), (36334, 'negation')]
# [(39233, 'para'), (19301, 'es'), (46672, 'se'), (18650, 'en'), (30519, 'la'), (12768, 'como'), (43378, 'que')]
# [(55746, 'vp_ellipsis'), (6329, 'antecedent'), (45420, 'rnr'), (34215, 'merchant'), (48259, 'sluicing'), (48252, 'sluice'), (18424, 'ellipsis')]
# [(40871, 'plural'), (40078, 'person'), (5327, 'agree'), (19234, 'ergative'), (12218, 'clitic'), (20921, 'feature'), (5341, 'agreement')]
# [(22851, 'gianni'), (51550, 'tense'), (39593, 'past'), (14855, 'dar'), (19849, 'event'), (48776, 'speaker'), (49987, 'subjunctive')]
# [(33214, 'mandarin'), (12096, 'classifier'), (47491, 'shi'), (32070, 'lisi'), (11996, 'cl'), (57919, 'zhangsan'), (11481, 'chinese')]
# [(53520, 'u'), (24003, 'h_e'), (10263, 'c'), (30440, 'l'), (17594, 'e'), (43585, 'r'), (35782, 'n')]
# [(32627, 'lsf'), (28229, 'ix-1'), (42487, 'pronoun'), (32294, 'loci'), (47751, 'sign'), (28228, 'ix'), (7040, 'asl')]
# [(14079, 'cp'), (43472, 'question'), (48065, 'situ'), (56458, 'wh_phrase'), (21412, 'focus'), (12170, 'cleft'), (56429, 'wh')]
# [(15877, 'determiner'), (24564, 'head'), (37392, 'np'), (17166, 'dp'), (37332, 'noun'), (37553, 'numeral'), (4969, 'adjective')]
# [(40433, 'phonology'), (20202, 'experiment'), (32733, 'lyman'), (55555, 'voice'), (29448, 'kawahara'), (28521, 'japanese'), (44700, 'rendaku')]

# %%
topic_space = [list(in_list).index(max(in_list)) for in_list in transformed]

# %%
Counter(topic_space)
# Out:
# Counter({0: 38,
#          1: 56,
#          2: 34,
#          3: 64,
#          4: 46,
#          5: 13,
#          6: 75,
#          7: 25,
#          8: 63,
#          9: 31,
#          10: 10,
#          11: 30,
#          12: 40,
#          13: 33,
#          14: 24,
#          15: 15,
#          16: 14,
#          17: 54,
#          18: 64,
#          19: 14})

# %% [markdown]
# Looks pretty good. Next step: classify in 4 topics. Then classify again. Look into LDA.

# %%
nmf_super = NMF(n_components=6)
nmf_super.fit(dtm_tfidf)
transformed_super = nmf_super.transform(dtm_tfidf)

# %%
words = [(i, v) for i, v in enumerate(feature_names)]
relevant_words_super = []
for r in nmf_super.components_:
    a = sorted([(v, i) for i,v in enumerate(r)])[-20:]
    print([words[j[1]] for j in a])
    print('\n')
    relevant_words_super.append([words[j[1]] for j in a])
# Out:
# [(18911, 'english'), (10807, 'case'), (46607, 'scope'), (27542, 'interpretation'), (42537, 'property'), (31972, 'linguistic'), (47281, 'set'), (46360, 'say'), (52286, 'time'), (33983, 'meaning'), (19849, 'event'), (36334, 'negation'), (13521, 'context'), (48776, 'speaker'), (42487, 'pronoun'), (31840, 'like'), (54545, 'use'), (34794, 'modal'), (47048, 'semantic'), (47163, 'sentence')]
#
#
# [(17594, 'e'), (49384, 'stem'), (35782, 'n'), (21583, 'form'), (51925, 'theory'), (13413, 'constraint'), (34806, 'model'), (52561, 'tone'), (28521, 'japanese'), (55555, 'voice'), (40373, 'phonetic'), (43585, 'r'), (20202, 'experiment'), (49625, 'stress'), (13373, 'consonant'), (40400, 'phonological'), (50586, 'syllable'), (40433, 'phonology'), (56919, 'word'), (55706, 'vowel')]
#
#
# [(40078, 'person'), (55101, 'verb'), (17166, 'dp'), (4600, 'acc'), (6768, 'argument'), (14898, 'dat'), (37779, 'object'), (54675, 'v'), (5327, 'agree'), (36912, 'nom'), (19234, 'ergative'), (22672, 'genitive'), (20921, 'feature'), (26023, 'icelandic'), (4695, 'accusative'), (14936, 'dative'), (36986, 'nominative'), (5341, 'agreement'), (49956, 'subject'), (10807, 'case')]
#
#
# [(12890, 'complement'), (52726, 'tp'), (12130, 'clause'), (6029, 'analysis'), (18424, 'ellipsis'), (20921, 'feature'), (34229, 'merge'), (20431, 'extraction'), (10263, 'c'), (49752, 'structure'), (49956, 'subject'), (41231, 'position'), (17166, 'dp'), (56429, 'wh'), (14079, 'cp'), (54675, 'v'), (24564, 'head'), (55733, 'vp'), (40270, 'phase'), (35313, 'movement')]
#
#
# [(53839, 'unaccusative'), (33983, 'meaning'), (31603, 'lexical'), (12972, 'compound'), (21583, 'form'), (51880, 'theme'), (49286, 'state'), (44994, 'result'), (47048, 'semantic'), (24564, 'head'), (50654, 'syntactic'), (36959, 'nominal'), (10980, 'causative'), (54675, 'v'), (41771, 'prefix'), (6768, 'argument'), (49752, 'structure'), (19849, 'event'), (45615, 'root'), (55101, 'verb')]
#
#
# [(47968, 'singular'), (10807, 'case'), (37543, 'number'), (31840, 'like'), (49752, 'structure'), (12096, 'classifier'), (15877, 'determiner'), (12060, 'class'), (36959, 'nominal'), (20921, 'feature'), (17166, 'dp'), (24564, 'head'), (40871, 'plural'), (37392, 'np'), (5341, 'agreement'), (35782, 'n'), (37553, 'numeral'), (4969, 'adjective'), (37332, 'noun'), (22581, 'gender')]

# %%
# function for assigning topics to docs:
def assign_topic(df, transformed, fitted):
    doctopic = transformed
    # scale the document-component matrix such that the component values associated with each document sum to one
    doctopic = doctopic / np.sum(doctopic, axis=1, keepdims=True)
    titles = np.array(df.title)
    num_groups = len(set(titles))
    # make matrix with zeros of the right size
    doctopic_grouped = np.zeros((num_groups, len(fitted.components_)))
    for i, title in enumerate(sorted(set(titles))):
        doctopic_grouped[i, :] = np.mean(doctopic[titles == title], axis = 0)
    return doctopic_grouped

# %%
doc_topic = assign_topic(df, transformed_super, nmf_super)

# %%
topic_assignment = []
for i, title in enumerate(df.title):
    topic_assignment.append([title]+ list(doc_topic[i])) 
topic_df = pd.DataFrame(topic_assignment, columns = ['title']+ ['topic'+str(n) for n in range(doc_topic.shape[1])])

# %%
topic_df
# Out:
#                                                  title    topic0    topic1  \
# 0                           Analytic Passives in Czech  0.239846  0.219854
# 1    The Universal DP Analysis in Articleless Langu...  0.050512  0.000000
# 2               Strong Pronominals ASL and LSF (squib)  0.440461  0.000000
# 3    Inflectional Dependencies. A study of complex ...  0.069382  0.002147
# 4    Multiple Sluicing, Scope, and Superiority: Con...  0.276230  0.000000
# 5            Quantifier Domain Restriction as Ellipsis  0.087037  0.033598
# 6                 Two disjunctions in Mandarin Chinese  0.362156  0.031027
# 7                                    Iconic Pragmatics  0.044344  0.164368
# 8                            Moraic Onsets in Arrernte  0.000000  0.000000
# 9          Revolutionary New Ideas Appear Infrequently  0.268715  0.129339
# 10   Back to the Future: Non-generation, filtration...  0.288177  0.000000
# 11   Strict and non-strict negative concord in Hung...  0.543831  0.163211
# 12   On the unavailability of argument ellipsis in ...  0.675986  0.000000
# 13   The role of incremental parsing in syntactical...  0.203060  0.123714
# 14   AxParts and Case in Complex PPs: Microvariatio...  0.251890  0.000000
# 15                                    Nominal ellipses  0.625518  0.373355
# 16   On the emergence of reduplication in German mo...  0.163743  0.000000
# 17            ONLY: An NPI-licenser and NPI-unlicenser  0.335714  0.600973
# 18   The loi de position and the acoustics of Frenc...  0.689791  0.310209
# 19   An Argument for Zwart’s Merge. Quotation as a ...  0.376256  0.196959
# 20   Minimalist Semantics and Pre-Linguistic Intell...  0.082886  0.239903
# 21   Ma non era rosso? (But wasn’t it red?): On cou...  0.000000  0.100669
# 22                      Modeling syntactic acquisition  0.000000  0.031584
# 23                  Morphology: Divided and Conquered?  0.244523  0.000000
# 24   The scope of alternatives: Indefiniteness and ...  0.320102  0.000000
# 25                                    Iconic Plurality  0.179311  0.000000
# 26   Speech production planning affects phonologica...  0.000000  0.261660
# 27   The Trotsky-Shklovsky debate: Formalism versus...  0.236941  0.017664
# 28   Why the null complementizer is special in the ...  0.573531  0.000000
# 29   How real are adjective order constraints? Mult...  0.000000  0.000000
# ..                                                 ...       ...       ...
# 713  What the PCC tells us about "abstract" agreeme...  0.217585  0.000000
# 714  Quotation and the lexicon-pragmatics interface...  0.140911  0.000000
# 715  The Influence of Bilectalism and Non-standardi...  0.218636  0.353280
# 716             'Default' case in gapping reconsidered  0.702075  0.183417
# 717  Quotation, Demonstration, and Attraction in Si...  0.525233  0.288731
# 718  The ban on movement out of moved elements in t...  0.000000  0.197754
# 719  Bare nouns, number, and definiteness in Teotit...  0.186054  0.000000
# 720                 Unmarked case in Estonian nominals  0.000000  0.018566
# 721        On a class of figure reflexives in Romanian  0.121821  0.008998
# 722        Priming methods in semantics and pragmatics  0.000000  0.031179
# 723  Rage against the Machine: Evaluation Metrics i...  0.012428  0.000000
# 724                             On an Impossible Affix  0.796695  0.155920
# 725  Properties of the Extended VP in Spanish: Agre...  0.489815  0.029676
# 726                  The Agreement Hierarchy and Agree  0.166411  0.083431
# 727                             The Autonomy of Syntax  0.042032  0.098013
# 728  Processing Tenses for the Living and the Dead:...  0.592066  0.000000
# 729  The position of case markers relative to posse...  0.090298  0.059148
# 730  Bare numerals, collectivity, and genericity: A...  0.240694  0.064953
# 731  Interpreting Plural Predication: Homogeneity a...  0.849439  0.000000
# 732   Why GIVE Does Not Incorporate in Denominal Verbs  0.000000  0.000000
# 733  Formal analysis of novel morphological process...  0.264369  0.638783
# 734                                   Phy inside psych  0.000000  0.150536
# 735                   On "zero" and semantic plurality  0.264177  0.000000
# 736      Testing OCP-labial effect on Japanese rendaku  0.000000  0.895534
# 737  Arabic stress with no moras, no syllables, no ...  0.000000  1.000000
# 738  The theory of argument formation—A view from M...  0.473827  0.000000
# 739          Ellipsis in the languages of the Caucasus  0.790136  0.023415
# 740  The feature structure of pronouns: a probe int...  0.420772  0.000000
# 741  Within Distributed Morphology, the 3-5-Consona...  0.508650  0.343957
# 742            Fseq zones and Slavic L>T>N participles  0.137568  0.000000
#
#        topic2    topic3    topic4    topic5
# 0    0.000000  0.279531  0.044093  0.216676
# 1    0.623094  0.326395  0.000000  0.000000
# 2    0.086795  0.153694  0.000000  0.319050
# 3    0.013085  0.867917  0.047469  0.000000
# 4    0.430447  0.112341  0.000000  0.180982
# 5    0.094693  0.061134  0.244577  0.478960
# 6    0.000000  0.271608  0.000000  0.335208
# 7    0.000000  0.446883  0.071364  0.273041
# 8    0.000000  0.000000  0.015398  0.984602
# 9    0.080005  0.269500  0.252441  0.000000
# 10   0.135980  0.423458  0.000000  0.152385
# 11   0.035821  0.203629  0.000000  0.053507
# 12   0.000000  0.218234  0.000000  0.105780
# 13   0.317091  0.200545  0.000000  0.155590
# 14   0.202962  0.484347  0.000000  0.060801
# 15   0.000000  0.000000  0.001127  0.000000
# 16   0.641913  0.194344  0.000000  0.000000
# 17   0.000000  0.000000  0.000000  0.063313
# 18   0.000000  0.000000  0.000000  0.000000
# 19   0.000000  0.057752  0.332736  0.036298
# 20   0.000000  0.112058  0.291644  0.273509
# 21   0.053709  0.709592  0.031013  0.105018
# 22   0.281304  0.687112  0.000000  0.000000
# 23   0.000000  0.000000  0.000000  0.755477
# 24   0.013955  0.437738  0.193647  0.034558
# 25   0.000000  0.450142  0.000000  0.370547
# 26   0.451668  0.080364  0.071787  0.134522
# 27   0.000000  0.064910  0.000000  0.680484
# 28   0.033735  0.310066  0.000000  0.082667
# 29   0.622863  0.000000  0.377137  0.000000
# ..        ...       ...       ...       ...
# 713  0.000000  0.782415  0.000000  0.000000
# 714  0.010596  0.848493  0.000000  0.000000
# 715  0.000000  0.428085  0.000000  0.000000
# 716  0.000000  0.000000  0.000000  0.114508
# 717  0.057327  0.128709  0.000000  0.000000
# 718  0.123781  0.343721  0.127349  0.207395
# 719  0.000000  0.400737  0.247728  0.165482
# 720  0.000000  0.981434  0.000000  0.000000
# 721  0.000000  0.869180  0.000000  0.000000
# 722  0.408775  0.355341  0.038642  0.166062
# 723  0.008769  0.608613  0.370190  0.000000
# 724  0.047385  0.000000  0.000000  0.000000
# 725  0.033020  0.000000  0.177597  0.269892
# 726  0.100098  0.404390  0.116787  0.128883
# 727  0.008811  0.000000  0.816733  0.034412
# 728  0.405183  0.000000  0.000000  0.002750
# 729  0.094301  0.510369  0.034518  0.211366
# 730  0.000000  0.694354  0.000000  0.000000
# 731  0.000000  0.000000  0.150561  0.000000
# 732  0.195865  0.048604  0.755531  0.000000
# 733  0.000000  0.000000  0.000000  0.096848
# 734  0.000000  0.000000  0.849464  0.000000
# 735  0.000000  0.301570  0.434253  0.000000
# 736  0.000000  0.019303  0.028817  0.056346
# 737  0.000000  0.000000  0.000000  0.000000
# 738  0.000000  0.330300  0.000000  0.195873
# 739  0.000000  0.090569  0.095880  0.000000
# 740  0.579228  0.000000  0.000000  0.000000
# 741  0.067819  0.000000  0.000000  0.079574
# 742  0.000000  0.000000  0.000000  0.862432
#
# [743 rows x 7 columns]

# %% [markdown]
# Waaaw... This is great! I can recognise fields based on the most relevant words, and the titles match them pretty well...

# %%
joblib.dump(topic_df, 'topic_space_papers')
# Out:
# ['topic_space_papers']

# %% [markdown]
# ## Refining topic 0 and 3
#
# ### Creating the tfidf vectors for topic0 and topic3

# %%
import spacy

nlp = spacy.load('en_core_web_sm')
my_stopwords = joblib.load('stopwords')
bigrams = phrases.Phrases.load('bigrams.pkl', 'rb')
trigrams = phrases.Phrases.load('trigrams.pkl', 'rb')

def punct_space(token):
    """
    helper function to eliminate punctuation, spaces and numbers.
    """
    return token.is_punct or token.is_space or token.like_num

#def remove_stopwords(tigrammized):
#    no_stop = [[term for term in sent if term not in my_stopwords] for sent in trigrammized]
 #   return no_stop
    
def remove_stopwords(stuff):
    # gives list of strings. Vectorizer needs this.
    out = []
    for sent in stuff:
        for term in sent:
            if term not in my_stopwords:
                out.append(term)
    return out


def trigrammer(doc):
    tokens = nlp(doc)
    lemmas = lemmer(tokens)
    tokens_ = bigrams[lemmas]
    trigrammized = trigrams[tokens_]
    return [j for j in trigrammized]

def lemmer(tokens):
    """
    lemmatize words
    """
    word_space = []
    for sent in tokens.sents:
        sentence = []
        for token in sent:
            if not punct_space(token):
                if token.lemma_=='-PRON-':
                    sentence.append(token.lower_)
                else:
                    sentence.append(token.lemma_.strip('-'))
        word_space.append(sentence)
    return word_space

def my_tokenizer(doc):
    trigrammized = trigrammer(doc)
    no_stop = remove_stopwords(trigrammized)
    return no_stop

# %%
topic0 = []
for i, row in topic_df.iterrows():
    max_prob = row[1:].max()
    if row.topic0 == max_prob:
        topic0.append(row.title)

# %%
topic3 = []
for i, row in topic_df.iterrows():
    max_prob = row[1:].max()
    if row.topic3 == max_prob:
        topic3.append(row.title)

# %%
df_topic0 = df[df['title'].isin(topic0)]

# %%
df_topic3 = df[df['title'].isin(topic3)]

# %%
vectorizer = TfidfVectorizer(tokenizer=my_tokenizer)
tfidf_topic0_fit = vectorizer.fit(df_topic0.paper)
feature_names0 = tfidf_topic0_fit.get_feature_names()
tfidf_topic0 = tfidf_topic0_fit.transform(df_topic0.paper)

# %%
tfidf_topic3_fit = vectorizer.fit(df_topic3.paper)
feature_names3 = tfidf_topic3_fit.get_feature_names()
tfidf_topic3 = tfidf_topic3_fit.transform(df_topic3.paper)

# %% [markdown]
# ### NFM topic 0

# %%
nmf_sub0 = NMF(n_components=6)
nmf_sub0.fit(tfidf_topic0)
transformed_sub0 = nmf_sub0.transform(tfidf_topic0)

# %%
words = [(i, v) for i, v in enumerate(feature_names0)]
relevant_words0 = []
for r in nmf_sub0.components_:
    a = sorted([(v, i) for i,v in enumerate(r)])[-20:]
    print([words[j[1]] for j in a])
    print('\n')
    relevant_words0.append([words[j[1]] for j in a])
# Out:
# [(30126, 'syntax'), (23759, 'phase_head'), (7908, 'cp'), (30107, 'syntactic'), (8895, 'derivation'), (5799, 'case'), (6227, 'chomsky'), (5479, 'c'), (32707, 'verb'), (22573, 'operation'), (29017, 'spell'), (9825, 'dp'), (33108, 'vp'), (20818, 'movement'), (29526, 'structure'), (14304, 'head'), (12033, 'feature'), (20117, 'merge'), (23755, 'phase'), (32457, 'v')]
#
#
# [(27145, 'rule'), (17857, 'l'), (23831, 'phonetic'), (21068, 'n'), (7358, 'conjugation'), (18496, 'level'), (11588, 'experiment'), (12461, 'form'), (30787, 'theory'), (29284, 'stem'), (9964, 'duration'), (30057, 'syllable'), (27036, 'root'), (32994, 'voice'), (25755, 'r'), (33776, 'word'), (23854, 'phonological'), (7442, 'consonant'), (23883, 'phonology'), (33087, 'vowel')]
#
#
# [(23326, 'past'), (19963, 'meaning'), (32707, 'verb'), (16187, 'interpretation'), (26991, 'role_shift'), (29214, 'state'), (5902, 'causation'), (28891, 'speaker'), (27461, 'say'), (7537, 'context'), (20959, 'mwangi'), (18673, 'like'), (32399, 'use'), (25736, 'quotation'), (30962, 'time'), (30590, 'tense'), (31471, 'trm'), (27926, 'sentence'), (27844, 'semantic'), (11355, 'event')]
#
#
# [(2046, 'accusative'), (18673, 'like'), (8402, 'dat'), (13174, 'genitive'), (24132, 'plural'), (12033, 'feature'), (15150, 'icelandic'), (32707, 'verb'), (2469, 'agree'), (13107, 'gender'), (21720, 'nom'), (3356, 'argument'), (30750, 'theme'), (21766, 'nominative'), (29643, 'subject'), (9825, 'dp'), (26197, 'reflexive'), (8420, 'dative'), (5799, 'case'), (2478, 'agreement')]
#
#
# [(22576, 'operator'), (21776, 'non'), (22092, 'null_subject'), (27612, 'scope'), (4937, 'book'), (5479, 'c'), (7104, 'complement'), (32707, 'verb'), (7908, 'cp'), (24342, 'position'), (24636, 'predicate'), (31182, 'topicalization'), (12346, 'focus'), (20818, 'movement'), (33515, 'wh'), (21370, 'negation'), (20483, 'modal'), (6625, 'clause'), (31168, 'topic'), (29643, 'subject')]
#
#
# [(13214, 'georgian'), (33108, 'vp'), (33115, 'vp_ellipsis'), (8725, 'delete'), (22740, 'ossetic'), (12990, 'gapping'), (10461, 'elided'), (8726, 'deletion'), (29481, 'strip'), (28820, 'soslan'), (33005, 'voice_mismatch'), (22032, 'npe'), (10458, 'elide'), (16483, 'island_violation'), (10501, 'elliptical_repair'), (3089, 'antecedent'), (28604, 'sluicing'), (20108, 'merchant'), (28601, 'sluice'), (10493, 'ellipsis')]

# %%
doc_topic0 = assign_topic(df_topic0, transformed_sub0, nmf_sub0)
topic_assignment0 = []
for i, title in enumerate(df_topic0.title):
    topic_assignment0.append([title]+ list(doc_topic0[i])) 
topi0c_df = pd.DataFrame(topic_assignment0, columns = ['title']+ ['topic'+str(n) for n in range(doc_topic0.shape[1])])

# %%
topi0c_df
# Out:
#                                                  title    topic0    topic1  \
# 0               Strong Pronominals ASL and LSF (squib)  0.242146  0.000000
# 1                 Two disjunctions in Mandarin Chinese  0.080660  0.137321
# 2    Strict and non-strict negative concord in Hung...  0.000000  0.158650
# 3    On the unavailability of argument ellipsis in ...  0.018527  0.000000
# 4                                     Nominal ellipses  0.000000  0.000000
# 5    The loi de position and the acoustics of Frenc...  0.730148  0.000000
# 6    An Argument for Zwart’s Merge. Quotation as a ...  0.033654  0.134698
# 7    Why the null complementizer is special in the ...  0.000000  0.000000
# 8    Events, States and Times. An essay on narrativ...  0.000000  0.056454
# 9         On the (un)interpretability of phi-agreement  0.633239  0.000000
# 10   Vocabulary insertion and locality: Verb supple...  0.000000  0.000000
# 11   Memorization and the morphology-syntax divide:...  0.103078  0.000000
# 12                         How to be kind with prosody  0.090555  0.000000
# 13    Realizing morphemes in the Icelandic noun phrase  0.000000  0.000000
# 14   Variation and change in the Romance faire-par ...  0.061068  0.001055
# 15   The Reduplicative System of Ancient Greek and ...  0.110818  0.452870
# 16   Minimalism and the Design of the Language Faculty  0.612347  0.000000
# 17                     (De)-constructing Evidentiality  0.526922  0.000000
# 18   Theories of causation should inform linguistic...  0.642209  0.000000
# 19   How Nature Meets Nurture: Universal Grammar an...  0.000000  0.000000
# 20   From non-finite to finite subordination. The h...  0.200756  0.131007
# 21                                             Rubbish  0.010772  0.894057
# 22                     Chomsky's Methodological Fakery  0.000000  0.000000
# 23        On the similarity between syntax and actions  0.000000  0.016031
# 24   Constraining argument structure in nominalizat...  0.093095  0.000000
# 25   Assessing Unaccusativity and Reflexivity: Usin...  0.172556  0.142165
# 26                                 What is an adjunct?  0.000000  0.155676
# 27      On directionality of phrase structure building  0.465109  0.137524
# 28   Sapir, Harris and Chomsky in the twentieth cen...  0.392864  0.000000
# 29                           Binary Tense and Modality  0.015166  0.961254
# ..                                                 ...       ...       ...
# 147  Embedded Questions and Sluicing in Georgian an...  0.000000  1.000000
# 148  The Tlingit Decessive and 'Discontinuous Past'...  0.000000  0.000000
# 149                                     About pronouns  0.000000  0.540293
# 150  Topicalization as Predication: The Syntax-Sema...  0.001065  0.000000
# 151  Asymmetries in the representation of categoric...  0.030121  0.010904
# 152                       Nominals and Event Structure  0.036786  0.000000
# 153  Gender features on n & the root: An account of...  0.048259  0.082404
# 154  It's not just what you say, it's how you say i...  0.000000  0.000000
# 155                           How to get off an island  0.000000  0.968356
# 156  Verb doubling and the order of operations at P...  0.000000  0.000000
# 157  Locality constraints on θ –theory: Evidence fr...  0.078785  0.000000
# 158  Clause Structure in Contact Contexts: the Case...  0.019772  0.000000
# 159  Implicatures from Silence: A remark on Chung's...  0.406644  0.321833
# 160  “Some Thoughts on One and Two and Other Numerals”  0.347872  0.000000
# 161                            A plea against monsters  0.599275  0.206724
# 162  We do not need structuralist morphemes, but we...  0.000000  0.087015
# 163     Specification as an inter-taxonomic phenomenon  0.319966  0.000000
# 164  AGREE and Spec-Head: Each inadequate, both nec...  1.000000  0.000000
# 165                       The pursuit of word meanings  0.418668  0.096261
# 166  When 'you' isn't you: The attraction of self-a...  0.067097  0.060993
# 167                                Spurious vs. Dative  0.117004  0.795303
# 168             'Default' case in gapping reconsidered  0.251068  0.000000
# 169  Quotation, Demonstration, and Attraction in Si...  0.445364  0.257998
# 170                             On an Impossible Affix  0.344442  0.000000
# 171  Properties of the Extended VP in Spanish: Agre...  0.538603  0.000000
# 172  Processing Tenses for the Living and the Dead:...  0.000000  0.088765
# 173  Interpreting Plural Predication: Homogeneity a...  0.072956  0.036578
# 174  The theory of argument formation—A view from M...  0.071761  0.000000
# 175          Ellipsis in the languages of the Caucasus  0.070360  0.863074
# 176  Within Distributed Morphology, the 3-5-Consona...  0.055867  0.072262
#
#        topic2    topic3    topic4    topic5
# 0    0.000000  0.418682  0.060101  0.279070
# 1    0.099223  0.569188  0.075028  0.038580
# 2    0.104324  0.026457  0.674073  0.036495
# 3    0.000000  0.137416  0.048819  0.795239
# 4    0.000000  0.422454  0.577546  0.000000
# 5    0.000000  0.000000  0.269852  0.000000
# 6    0.337066  0.224740  0.161457  0.108385
# 7    0.000000  1.000000  0.000000  0.000000
# 8    0.000000  0.000000  0.943546  0.000000
# 9    0.000000  0.000000  0.329882  0.036879
# 10   1.000000  0.000000  0.000000  0.000000
# 11   0.000000  0.736119  0.160803  0.000000
# 12   0.468081  0.330011  0.091907  0.019447
# 13   0.000000  0.692655  0.307345  0.000000
# 14   0.111315  0.826563  0.000000  0.000000
# 15   0.000000  0.299758  0.136555  0.000000
# 16   0.320256  0.000000  0.000000  0.067397
# 17   0.000000  0.473078  0.000000  0.000000
# 18   0.000000  0.276614  0.081177  0.000000
# 19   0.147283  0.713776  0.000000  0.138941
# 20   0.187851  0.088831  0.389044  0.002511
# 21   0.019577  0.000000  0.040850  0.034744
# 22   1.000000  0.000000  0.000000  0.000000
# 23   0.857354  0.000000  0.126615  0.000000
# 24   0.000000  0.874187  0.027011  0.005707
# 25   0.608099  0.000000  0.016783  0.060398
# 26   0.115079  0.090651  0.593739  0.044854
# 27   0.091012  0.100418  0.205937  0.000000
# 28   0.339666  0.232294  0.000000  0.035176
# 29   0.000000  0.000000  0.000000  0.023580
# ..        ...       ...       ...       ...
# 147  0.000000  0.000000  0.000000  0.000000
# 148  0.145234  0.250136  0.604630  0.000000
# 149  0.459707  0.000000  0.000000  0.000000
# 150  0.486179  0.156943  0.272093  0.083721
# 151  0.000000  0.000000  0.954453  0.004522
# 152  0.549401  0.191500  0.078865  0.143447
# 153  0.844305  0.025033  0.000000  0.000000
# 154  0.000000  0.340422  0.652187  0.007391
# 155  0.000000  0.000000  0.009443  0.022200
# 156  0.000000  0.000000  1.000000  0.000000
# 157  0.000000  0.921215  0.000000  0.000000
# 158  0.278958  0.000000  0.519670  0.181600
# 159  0.271523  0.000000  0.000000  0.000000
# 160  0.320097  0.245898  0.077328  0.008803
# 161  0.194001  0.000000  0.000000  0.000000
# 162  0.038190  0.343110  0.463632  0.068053
# 163  0.255754  0.017366  0.297342  0.109572
# 164  0.000000  0.000000  0.000000  0.000000
# 165  0.000000  0.485071  0.000000  0.000000
# 166  0.000000  0.015566  0.000000  0.856345
# 167  0.005921  0.081773  0.000000  0.000000
# 168  0.000000  0.000000  0.735631  0.013301
# 169  0.048425  0.138169  0.110044  0.000000
# 170  0.203373  0.040251  0.384056  0.027877
# 171  0.000000  0.000000  0.461397  0.000000
# 172  0.784120  0.127114  0.000000  0.000000
# 173  0.890465  0.000000  0.000000  0.000000
# 174  0.928239  0.000000  0.000000  0.000000
# 175  0.000000  0.066566  0.000000  0.000000
# 176  0.486185  0.173767  0.074078  0.137841
#
# [177 rows x 7 columns]

# %%
joblib.dump(topi0c_df, 'topic_space_topic0')
# Out:
# ['topic_space_topic0']

# %%
nmf_sub3 = NMF(n_components=5)
nmf_sub3.fit(tfidf_topic3)
transformed_sub3 = nmf_sub3.transform(tfidf_topic3)

# %%
words3 = [(i, v) for i, v in enumerate(feature_names3)]
relevant_words3 = []
for r in nmf_sub3.components_:
    a = sorted([(v, i) for i,v in enumerate(r)])[-20:]
    print([words3[j[1]] for j in a])
    print('\n')
    relevant_words3.append([words3[j[1]] for j in a])
# Out:
# [(22846, 'object'), (2275, 'agreement'), (3207, 'argument'), (9773, 'dp'), (7786, 'cp'), (6456, 'clause'), (2720, 'analysis'), (32425, 'tp'), (30549, 'structure'), (5324, 'c'), (12090, 'feature'), (24385, 'phase'), (11815, 'extraction'), (25005, 'position'), (14420, 'head'), (33725, 'v'), (34402, 'vp'), (33996, 'verb'), (30680, 'subject'), (21377, 'movement')]
#
#
# [(18869, 'level'), (25561, 'principle'), (25627, 'probability'), (11449, 'evolution'), (31191, 'syntax'), (6128, 'chomsky'), (18673, 'learning'), (15140, 'human'), (5953, 'change'), (31926, 'theory'), (13684, 'grammar'), (31167, 'syntactic'), (30549, 'structure'), (19172, 'linguistic'), (33638, 'use'), (35157, 'word'), (6084, 'child'), (23745, 'parameter'), (1915, 'acquisition'), (21016, 'model')]
#
#
# [(22740, 'numeral'), (9773, 'dp'), (16989, 'japanese'), (15331, 'icelandic'), (3207, 'argument'), (8284, 'dat'), (12090, 'feature'), (13158, 'gen'), (31154, 'syncretism'), (33725, 'v'), (20156, 'mark'), (2275, 'agreement'), (22317, 'nom'), (1787, 'acc'), (30680, 'subject'), (8304, 'dative'), (13242, 'genitive'), (1853, 'accusative'), (22372, 'nominative'), (5656, 'case')]
#
#
# [(31999, 'think'), (11920, 'fact'), (30680, 'subject'), (6456, 'clause'), (26696, 'reading'), (2720, 'analysis'), (16363, 'interpretation'), (21007, 'modal'), (21960, 'negation'), (20475, 'meaning'), (7410, 'context'), (29853, 'speaker'), (21936, 'neg'), (28463, 'scope'), (5656, 'case'), (19080, 'like'), (25794, 'pronoun'), (28747, 'semantic'), (28832, 'sentence'), (15862, 'indeﬁnite')]
#
#
# [(12090, 'feature'), (10209, 'een'), (6407, 'class'), (6374, 'cl'), (12536, 'form'), (9773, 'dp'), (10015, 'e'), (14474, 'hebrew'), (30549, 'structure'), (22740, 'numeral'), (7017, 'compound'), (14420, 'head'), (22348, 'nominal'), (2275, 'agreement'), (21629, 'n'), (27835, 'root'), (2052, 'adjective'), (22637, 'np'), (13171, 'gender'), (22600, 'noun')]

# %%
doc_topic3 = assign_topic(df_topic3, transformed_sub3, nmf_sub3)
topic_assignment3 = []
for i, title in enumerate(df_topic3.title):
    topic_assignment3.append([title]+ list(doc_topic3[i])) 
topic3_df = pd.DataFrame(topic_assignment3, columns = ['title']+ ['topic'+str(n) for n in range(doc_topic3.shape[1])])
topic3_df
# Out:
#                                                  title    topic0    topic1  \
# 0                           Analytic Passives in Czech  0.780837  0.022183
# 1    Inflectional Dependencies. A study of complex ...  0.102522  0.000000
# 2                                    Iconic Pragmatics  0.338990  0.083755
# 3          Revolutionary New Ideas Appear Infrequently  0.244317  0.201997
# 4    Back to the Future: Non-generation, filtration...  0.053216  0.000000
# 5    AxParts and Case in Complex PPs: Microvariatio...  0.741820  0.000000
# 6    Ma non era rosso? (But wasn’t it red?): On cou...  0.373946  0.133963
# 7                       Modeling syntactic acquisition  0.120584  0.017049
# 8    The scope of alternatives: Indefiniteness and ...  0.165062  0.023044
# 9                                     Iconic Plurality  0.092438  0.017918
# 10    Bangla Negative Polarity Items: A Detailed Study  0.000000  0.000000
# 11   Prosody as an argument for a layered left peri...  0.000000  0.493563
# 12           Empirical evidence in research on meaning  0.220458  0.253277
# 13   The prosodic representation of composite struc...  0.000000  0.930232
# 14   Resumptivity and Two Types of A'-dependencies ...  0.284829  0.083391
# 15                             Finiteness in Sundanese  1.000000  0.000000
# 16   Beyond the Pirahã Controversy - A Review of Da...  0.000000  0.000000
# 17        Morphological case mismatches under sluicing  0.059070  0.000000
# 18             Phase-Head Initiated Structure Building  0.079245  0.260067
# 19                                   Phases and idioms  0.000000  0.055091
# 20   The third reading of the most expensive photo ...  0.155457  0.370649
# 21   Sample chapter of "Syntax of Dutch: Nouns and ...  0.000000  0.000000
# 22   Stuck in the middle: Mandarin medials in artic...  0.000000  0.000000
# 23   Derived Nominals and the Syntactic Domain of C...  0.000000  0.016060
# 24   Parenthetical verb constructions, fragment ans...  0.000000  1.000000
# 25   Prosodic marking of syntactic heads: On post-h...  0.000000  0.068249
# 26               Case variation: viruses and star wars  0.000000  1.000000
# 27   One module, different levels of merge: AN(N) c...  0.000000  0.000000
# 28   The symmetric syntax of Japanese complex verbs...  0.090934  0.000000
# 29   Synchronic and Diachronic Variation of Cantone...  0.000000  0.052540
# ..                                                 ...       ...       ...
# 148        Algorithmic Acquisition of Focus Parameters  0.324807  0.011902
# 149    Feature inheritance versus extended projections  0.000000  0.933262
# 150  How Large Can Elliptical Arguments be in Japan...  0.008062  0.070702
# 151                  Dispelling the Cloud of Unknowing  0.000000  0.000000
# 152                      A view of the morphome debate  0.000000  0.068795
# 153  Proxy control: a new species of obligatory con...  0.496550  0.000000
# 154              The expressive "en maar"-construction  0.000000  0.000000
# 155                    Syntactic ergativity in Gitksan  0.866628  0.000000
# 156                           Many-worlds conditionals  0.841497  0.000000
# 157  The semantic contribution of idiosyncratic roo...  0.218681  0.000000
# 158                       Computational linking theory  0.274559  0.000000
# 159   Not all specificational sentences are reversible  0.160412  0.028772
# 160  Dogs process associations, not lexical or pros...  0.393292  0.000000
# 161                   Negating Comparative Quantifiers  0.000000  0.000000
# 162          Decomposing EPP effects in Greek enclisis  0.000000  0.555991
# 163  'pro' as a minimal NP: towards a unified theor...  0.200617  0.000000
# 164                     Antilocality and Antiagreement  0.000000  0.000000
# 165  Apparent Exemption from Condition A: a Perspec...  0.000000  0.137836
# 166              Antipronominality and E-Type Pronouns  0.416357  0.042151
# 167  What the PCC tells us about "abstract" agreeme...  0.615706  0.000000
# 168  Quotation and the lexicon-pragmatics interface...  1.000000  0.000000
# 169  The Influence of Bilectalism and Non-standardi...  0.000000  0.995639
# 170  The ban on movement out of moved elements in t...  0.219428  0.068694
# 171  Bare nouns, number, and definiteness in Teotit...  0.130661  0.174547
# 172                 Unmarked case in Estonian nominals  0.000000  0.000000
# 173        On a class of figure reflexives in Romanian  0.000000  0.055865
# 174  Rage against the Machine: Evaluation Metrics i...  0.000062  0.984622
# 175                  The Agreement Hierarchy and Agree  0.435363  0.121040
# 176  The position of case markers relative to posse...  0.000000  0.240829
# 177  Bare numerals, collectivity, and genericity: A...  0.368824  0.558302
#
#        topic2    topic3    topic4
# 0    0.005608  0.089887  0.101485
# 1    0.212420  0.387286  0.297772
# 2    0.000000  0.113451  0.463805
# 3    0.129545  0.385048  0.039092
# 4    0.440742  0.310992  0.195050
# 5    0.258180  0.000000  0.000000
# 6    0.018506  0.421879  0.051705
# 7    0.118059  0.639357  0.104951
# 8    0.388935  0.088507  0.334452
# 9    0.142365  0.747279  0.000000
# 10   0.000000  0.888897  0.111103
# 11   0.058957  0.000000  0.447480
# 12   0.003372  0.202788  0.320105
# 13   0.000000  0.018233  0.051534
# 14   0.216585  0.000000  0.415194
# 15   0.000000  0.000000  0.000000
# 16   0.000000  0.527996  0.472004
# 17   0.048270  0.892660  0.000000
# 18   0.033167  0.035037  0.592484
# 19   0.273384  0.384364  0.287161
# 20   0.435148  0.000000  0.038746
# 21   0.013156  0.986844  0.000000
# 22   0.000000  0.809631  0.190369
# 23   0.000000  0.927433  0.056507
# 24   0.000000  0.000000  0.000000
# 25   0.000000  0.000000  0.931751
# 26   0.000000  0.000000  0.000000
# 27   0.000000  0.685496  0.314504
# 28   0.909066  0.000000  0.000000
# 29   0.947460  0.000000  0.000000
# ..        ...       ...       ...
# 148  0.150446  0.000000  0.512845
# 149  0.000000  0.066738  0.000000
# 150  0.005452  0.277324  0.638461
# 151  0.010642  0.210779  0.778578
# 152  0.800746  0.005918  0.124541
# 153  0.503450  0.000000  0.000000
# 154  0.239305  0.036738  0.723957
# 155  0.000000  0.133372  0.000000
# 156  0.158503  0.000000  0.000000
# 157  0.000000  0.688448  0.092872
# 158  0.016872  0.322670  0.385898
# 159  0.000000  0.810816  0.000000
# 160  0.000000  0.606708  0.000000
# 161  0.559642  0.000000  0.440358
# 162  0.000000  0.000000  0.444009
# 163  0.227538  0.571846  0.000000
# 164  0.000000  1.000000  0.000000
# 165  0.000000  0.268581  0.593583
# 166  0.318117  0.002838  0.220538
# 167  0.000000  0.219039  0.165255
# 168  0.000000  0.000000  0.000000
# 169  0.000000  0.004361  0.000000
# 170  0.704685  0.007193  0.000000
# 171  0.050064  0.406081  0.238648
# 172  0.929754  0.000000  0.070246
# 173  0.000000  0.791175  0.152960
# 174  0.015316  0.000000  0.000000
# 175  0.215069  0.000000  0.228527
# 176  0.139514  0.508467  0.111190
# 177  0.072875  0.000000  0.000000
#
# [178 rows x 6 columns]

# %%
joblib.dump(topic3_df, 'topic_space_topic3')
# Out:
# ['topic_space_topic3']

# %% [markdown]
# ### JSON for visualisation: hierarchy

# %%
from collections import defaultdict
def lists_of_words(topic_words):
    out = defaultdict(list)
    for j, topic in enumerate(topic_words):
        out[j] = [topic[i][1] for i in range(len(topic))]
    return out

# %%
words_0 = []
for topic in relevant_words0: 
    new_value = []
    size = 20
    for word in topic:
        di = {'name': word[1], 'size': size}
        size -= 1
        new_value.append(di)
    words_0.append(new_value)

# %%
words_3 = []
for topic in relevant_words3: 
    new_value = []
    size = 20
    for word in topic:
        di = {'name': word[1], 'size': size}
        size -= 1
        new_value.append(di)
    words_3.append(new_value)

# %%
super_words = []
for topic in relevant_words_super: 
    new_value = []
    size = 20
    for word in topic:
        di = {'name': word[1], 'size': size}
        size -= 1
        new_value.append(di)
    super_words.append(new_value)

# %%
word_spaces = {'name': 'topics', 'children': [{'name':'interfaces', 'children': [{'name':'minimalism', 'children': words_0[0]},
                {'name':'experimental phonology', 'children': words_0[1]},
                {'name': 'tense & aspect', 'children': words_0[2]},
                {'name':'case', 'children': words_0[3]},
                {'name': 'quantification', 'children': words_0[4]},
                        {'name': 'ellipsis', 'children': words_0[5]}]},
               {'name':'phonology & phonetics', 'children': super_words[1]},
               {'name':'morphosyntax', 'children': super_words[2]},
               {'name':'syntax', 'children':  [{'name': 'syntax', 'children': words_3[0]},
                          {'name': 'generative framework', 'children': words_3[1]},
                          {'name':'nanosyntax', 'children': words_3[2]},
                          {'name':'semantics', 'children': words_3[3]},
                          {'name':'DP', 'children': words_3[4]}]},
               {'name':'distributed morphology', 'children': super_words[4]},
               {'name':'morphology', 'children': super_words[5]}]}

# %%
word_spaces
# Out:
# {'children': [{'children': [{'children': [{'name': 'syntax', 'size': 20},
#       {'name': 'phase_head', 'size': 19},
#       {'name': 'cp', 'size': 18},
#       {'name': 'syntactic', 'size': 17},
#       {'name': 'derivation', 'size': 16},
#       {'name': 'case', 'size': 15},
#       {'name': 'chomsky', 'size': 14},
#       {'name': 'c', 'size': 13},
#       {'name': 'verb', 'size': 12},
#       {'name': 'operation', 'size': 11},
#       {'name': 'spell', 'size': 10},
#       {'name': 'dp', 'size': 9},
#       {'name': 'vp', 'size': 8},
#       {'name': 'movement', 'size': 7},
#       {'name': 'structure', 'size': 6},
#       {'name': 'head', 'size': 5},
#       {'name': 'feature', 'size': 4},
#       {'name': 'merge', 'size': 3},
#       {'name': 'phase', 'size': 2},
#       {'name': 'v', 'size': 1}],
#      'name': 'minimalism'},
#     {'children': [{'name': 'rule', 'size': 20},
#       {'name': 'l', 'size': 19},
#       {'name': 'phonetic', 'size': 18},
#       {'name': 'n', 'size': 17},
#       {'name': 'conjugation', 'size': 16},
#       {'name': 'level', 'size': 15},
#       {'name': 'experiment', 'size': 14},
#       {'name': 'form', 'size': 13},
#       {'name': 'theory', 'size': 12},
#       {'name': 'stem', 'size': 11},
#       {'name': 'duration', 'size': 10},
#       {'name': 'syllable', 'size': 9},
#       {'name': 'root', 'size': 8},
#       {'name': 'voice', 'size': 7},
#       {'name': 'r', 'size': 6},
#       {'name': 'word', 'size': 5},
#       {'name': 'phonological', 'size': 4},
#       {'name': 'consonant', 'size': 3},
#       {'name': 'phonology', 'size': 2},
#       {'name': 'vowel', 'size': 1}],
#      'name': 'experimental phonology'},
#     {'children': [{'name': 'past', 'size': 20},
#       {'name': 'meaning', 'size': 19},
#       {'name': 'verb', 'size': 18},
#       {'name': 'interpretation', 'size': 17},
#       {'name': 'role_shift', 'size': 16},
#       {'name': 'state', 'size': 15},
#       {'name': 'causation', 'size': 14},
#       {'name': 'speaker', 'size': 13},
#       {'name': 'say', 'size': 12},
#       {'name': 'context', 'size': 11},
#       {'name': 'mwangi', 'size': 10},
#       {'name': 'like', 'size': 9},
#       {'name': 'use', 'size': 8},
#       {'name': 'quotation', 'size': 7},
#       {'name': 'time', 'size': 6},
#       {'name': 'tense', 'size': 5},
#       {'name': 'trm', 'size': 4},
#       {'name': 'sentence', 'size': 3},
#       {'name': 'semantic', 'size': 2},
#       {'name': 'event', 'size': 1}],
#      'name': 'tense & aspect'},
#     {'children': [{'name': 'accusative', 'size': 20},
#       {'name': 'like', 'size': 19},
#       {'name': 'dat', 'size': 18},
#       {'name': 'genitive', 'size': 17},
#       {'name': 'plural', 'size': 16},
#       {'name': 'feature', 'size': 15},
#       {'name': 'icelandic', 'size': 14},
#       {'name': 'verb', 'size': 13},
#       {'name': 'agree', 'size': 12},
#       {'name': 'gender', 'size': 11},
#       {'name': 'nom', 'size': 10},
#       {'name': 'argument', 'size': 9},
#       {'name': 'theme', 'size': 8},
#       {'name': 'nominative', 'size': 7},
#       {'name': 'subject', 'size': 6},
#       {'name': 'dp', 'size': 5},
#       {'name': 'reflexive', 'size': 4},
#       {'name': 'dative', 'size': 3},
#       {'name': 'case', 'size': 2},
#       {'name': 'agreement', 'size': 1}],
#      'name': 'case'},
#     {'children': [{'name': 'operator', 'size': 20},
#       {'name': 'non', 'size': 19},
#       {'name': 'null_subject', 'size': 18},
#       {'name': 'scope', 'size': 17},
#       {'name': 'book', 'size': 16},
#       {'name': 'c', 'size': 15},
#       {'name': 'complement', 'size': 14},
#       {'name': 'verb', 'size': 13},
#       {'name': 'cp', 'size': 12},
#       {'name': 'position', 'size': 11},
#       {'name': 'predicate', 'size': 10},
#       {'name': 'topicalization', 'size': 9},
#       {'name': 'focus', 'size': 8},
#       {'name': 'movement', 'size': 7},
#       {'name': 'wh', 'size': 6},
#       {'name': 'negation', 'size': 5},
#       {'name': 'modal', 'size': 4},
#       {'name': 'clause', 'size': 3},
#       {'name': 'topic', 'size': 2},
#       {'name': 'subject', 'size': 1}],
#      'name': 'quantification'},
#     {'children': [{'name': 'georgian', 'size': 20},
#       {'name': 'vp', 'size': 19},
#       {'name': 'vp_ellipsis', 'size': 18},
#       {'name': 'delete', 'size': 17},
#       {'name': 'ossetic', 'size': 16},
#       {'name': 'gapping', 'size': 15},
#       {'name': 'elided', 'size': 14},
#       {'name': 'deletion', 'size': 13},
#       {'name': 'strip', 'size': 12},
#       {'name': 'soslan', 'size': 11},
#       {'name': 'voice_mismatch', 'size': 10},
#       {'name': 'npe', 'size': 9},
#       {'name': 'elide', 'size': 8},
#       {'name': 'island_violation', 'size': 7},
#       {'name': 'elliptical_repair', 'size': 6},
#       {'name': 'antecedent', 'size': 5},
#       {'name': 'sluicing', 'size': 4},
#       {'name': 'merchant', 'size': 3},
#       {'name': 'sluice', 'size': 2},
#       {'name': 'ellipsis', 'size': 1}],
#      'name': 'ellipsis'}],
#    'name': 'interfaces'},
#   {'children': [{'name': 'e', 'size': 20},
#     {'name': 'stem', 'size': 19},
#     {'name': 'n', 'size': 18},
#     {'name': 'form', 'size': 17},
#     {'name': 'theory', 'size': 16},
#     {'name': 'constraint', 'size': 15},
#     {'name': 'model', 'size': 14},
#     {'name': 'tone', 'size': 13},
#     {'name': 'japanese', 'size': 12},
#     {'name': 'voice', 'size': 11},
#     {'name': 'phonetic', 'size': 10},
#     {'name': 'r', 'size': 9},
#     {'name': 'experiment', 'size': 8},
#     {'name': 'stress', 'size': 7},
#     {'name': 'consonant', 'size': 6},
#     {'name': 'phonological', 'size': 5},
#     {'name': 'syllable', 'size': 4},
#     {'name': 'phonology', 'size': 3},
#     {'name': 'word', 'size': 2},
#     {'name': 'vowel', 'size': 1}],
#    'name': 'phonology & phonetics'},
#   {'children': [{'name': 'person', 'size': 20},
#     {'name': 'verb', 'size': 19},
#     {'name': 'dp', 'size': 18},
#     {'name': 'acc', 'size': 17},
#     {'name': 'argument', 'size': 16},
#     {'name': 'dat', 'size': 15},
#     {'name': 'object', 'size': 14},
#     {'name': 'v', 'size': 13},
#     {'name': 'agree', 'size': 12},
#     {'name': 'nom', 'size': 11},
#     {'name': 'ergative', 'size': 10},
#     {'name': 'genitive', 'size': 9},
#     {'name': 'feature', 'size': 8},
#     {'name': 'icelandic', 'size': 7},
#     {'name': 'accusative', 'size': 6},
#     {'name': 'dative', 'size': 5},
#     {'name': 'nominative', 'size': 4},
#     {'name': 'agreement', 'size': 3},
#     {'name': 'subject', 'size': 2},
#     {'name': 'case', 'size': 1}],
#    'name': 'morphosyntax'},
#   {'children': [{'children': [{'name': 'object', 'size': 20},
#       {'name': 'agreement', 'size': 19},
#       {'name': 'argument', 'size': 18},
#       {'name': 'dp', 'size': 17},
#       {'name': 'cp', 'size': 16},
#       {'name': 'clause', 'size': 15},
#       {'name': 'analysis', 'size': 14},
#       {'name': 'tp', 'size': 13},
#       {'name': 'structure', 'size': 12},
#       {'name': 'c', 'size': 11},
#       {'name': 'feature', 'size': 10},
#       {'name': 'phase', 'size': 9},
#       {'name': 'extraction', 'size': 8},
#       {'name': 'position', 'size': 7},
#       {'name': 'head', 'size': 6},
#       {'name': 'v', 'size': 5},
#       {'name': 'vp', 'size': 4},
#       {'name': 'verb', 'size': 3},
#       {'name': 'subject', 'size': 2},
#       {'name': 'movement', 'size': 1}],
#      'name': 'syntax'},
#     {'children': [{'name': 'level', 'size': 20},
#       {'name': 'principle', 'size': 19},
#       {'name': 'probability', 'size': 18},
#       {'name': 'evolution', 'size': 17},
#       {'name': 'syntax', 'size': 16},
#       {'name': 'chomsky', 'size': 15},
#       {'name': 'learning', 'size': 14},
#       {'name': 'human', 'size': 13},
#       {'name': 'change', 'size': 12},
#       {'name': 'theory', 'size': 11},
#       {'name': 'grammar', 'size': 10},
#       {'name': 'syntactic', 'size': 9},
#       {'name': 'structure', 'size': 8},
#       {'name': 'linguistic', 'size': 7},
#       {'name': 'use', 'size': 6},
#       {'name': 'word', 'size': 5},
#       {'name': 'child', 'size': 4},
#       {'name': 'parameter', 'size': 3},
#       {'name': 'acquisition', 'size': 2},
#       {'name': 'model', 'size': 1}],
#      'name': 'generative framework'},
#     {'children': [{'name': 'numeral', 'size': 20},
#       {'name': 'dp', 'size': 19},
#       {'name': 'japanese', 'size': 18},
#       {'name': 'icelandic', 'size': 17},
#       {'name': 'argument', 'size': 16},
#       {'name': 'dat', 'size': 15},
#       {'name': 'feature', 'size': 14},
#       {'name': 'gen', 'size': 13},
#       {'name': 'syncretism', 'size': 12},
#       {'name': 'v', 'size': 11},
#       {'name': 'mark', 'size': 10},
#       {'name': 'agreement', 'size': 9},
#       {'name': 'nom', 'size': 8},
#       {'name': 'acc', 'size': 7},
#       {'name': 'subject', 'size': 6},
#       {'name': 'dative', 'size': 5},
#       {'name': 'genitive', 'size': 4},
#       {'name': 'accusative', 'size': 3},
#       {'name': 'nominative', 'size': 2},
#       {'name': 'case', 'size': 1}],
#      'name': 'nanosyntax'},
#     {'children': [{'name': 'think', 'size': 20},
#       {'name': 'fact', 'size': 19},
#       {'name': 'subject', 'size': 18},
#       {'name': 'clause', 'size': 17},
#       {'name': 'reading', 'size': 16},
#       {'name': 'analysis', 'size': 15},
#       {'name': 'interpretation', 'size': 14},
#       {'name': 'modal', 'size': 13},
#       {'name': 'negation', 'size': 12},
#       {'name': 'meaning', 'size': 11},
#       {'name': 'context', 'size': 10},
#       {'name': 'speaker', 'size': 9},
#       {'name': 'neg', 'size': 8},
#       {'name': 'scope', 'size': 7},
#       {'name': 'case', 'size': 6},
#       {'name': 'like', 'size': 5},
#       {'name': 'pronoun', 'size': 4},
#       {'name': 'semantic', 'size': 3},
#       {'name': 'sentence', 'size': 2},
#       {'name': 'indeﬁnite', 'size': 1}],
#      'name': 'semantics'},
#     {'children': [{'name': 'feature', 'size': 20},
#       {'name': 'een', 'size': 19},
#       {'name': 'class', 'size': 18},
#       {'name': 'cl', 'size': 17},
#       {'name': 'form', 'size': 16},
#       {'name': 'dp', 'size': 15},
#       {'name': 'e', 'size': 14},
#       {'name': 'hebrew', 'size': 13},
#       {'name': 'structure', 'size': 12},
#       {'name': 'numeral', 'size': 11},
#       {'name': 'compound', 'size': 10},
#       {'name': 'head', 'size': 9},
#       {'name': 'nominal', 'size': 8},
#       {'name': 'agreement', 'size': 7},
#       {'name': 'n', 'size': 6},
#       {'name': 'root', 'size': 5},
#       {'name': 'adjective', 'size': 4},
#       {'name': 'np', 'size': 3},
#       {'name': 'gender', 'size': 2},
#       {'name': 'noun', 'size': 1}],
#      'name': 'DP'}],
#    'name': 'syntax'},
#   {'children': [{'name': 'unaccusative', 'size': 20},
#     {'name': 'meaning', 'size': 19},
#     {'name': 'lexical', 'size': 18},
#     {'name': 'compound', 'size': 17},
#     {'name': 'form', 'size': 16},
#     {'name': 'theme', 'size': 15},
#     {'name': 'state', 'size': 14},
#     {'name': 'result', 'size': 13},
#     {'name': 'semantic', 'size': 12},
#     {'name': 'head', 'size': 11},
#     {'name': 'syntactic', 'size': 10},
#     {'name': 'nominal', 'size': 9},
#     {'name': 'causative', 'size': 8},
#     {'name': 'v', 'size': 7},
#     {'name': 'prefix', 'size': 6},
#     {'name': 'argument', 'size': 5},
#     {'name': 'structure', 'size': 4},
#     {'name': 'event', 'size': 3},
#     {'name': 'root', 'size': 2},
#     {'name': 'verb', 'size': 1}],
#    'name': 'distributed morphology'},
#   {'children': [{'name': 'singular', 'size': 20},
#     {'name': 'case', 'size': 19},
#     {'name': 'number', 'size': 18},
#     {'name': 'like', 'size': 17},
#     {'name': 'structure', 'size': 16},
#     {'name': 'classifier', 'size': 15},
#     {'name': 'determiner', 'size': 14},
#     {'name': 'class', 'size': 13},
#     {'name': 'nominal', 'size': 12},
#     {'name': 'feature', 'size': 11},
#     {'name': 'dp', 'size': 10},
#     {'name': 'head', 'size': 9},
#     {'name': 'plural', 'size': 8},
#     {'name': 'np', 'size': 7},
#     {'name': 'agreement', 'size': 6},
#     {'name': 'n', 'size': 5},
#     {'name': 'numeral', 'size': 4},
#     {'name': 'adjective', 'size': 3},
#     {'name': 'noun', 'size': 2},
#     {'name': 'gender', 'size': 1}],
#    'name': 'morphology'}],
#  'name': 'topics'}

# %%
import json
with open('words_per_topic.json', 'w') as f:
    json.dump(word_spaces, f)
